# %%
import dask.array as da
import napari
import btrack
from tqdm.auto import tqdm
from skimage.io import imshow,  imsave
import matplotlib.pyplot as plt
import numpy as np
import itertools
import json
from skimage.morphology import remove_small_objects
plt.rcParams["figure.figsize"] = (15,7)

# %% [markdown]
# # Conclusion from previous parameter search
#
# The segmentation and objects identification is where the quality lies
#
# ... what if I could interpolate the intermediate segment shapes?

# %% [markdown]
# ### Load images from zarr and compress into max projections

# %%
gfp = da.from_zarr('/mnt/DATA/sandbox/pierre_live_cell_data/outputs/Replication_IPSDM_GFP/zarr/tzxy_stack_ch1.zarr/')
rfp = da.from_zarr('/mnt/DATA/sandbox/pierre_live_cell_data/outputs/Replication_IPSDM_GFP/zarr/tzxy_stack_ch2.zarr/')
gfp = da.sum(gfp, axis = 1, dtype='u2')
rfp = da.sum(rfp, axis = 1, dtype='u2')
masks = da.from_zarr(f'/mnt/DATA/sandbox/pierre_live_cell_data/outputs/Replication_IPSDM_GFP/zarr/tzxy_stack_ch99.zarr/',)# chunks = gfp.chunks)

# %%
masks
# Out:
# dask.array<from-zarr, shape=(75, 6048, 6048), dtype=uint16, chunksize=(1, 2160, 2160), chunktype=numpy.ndarray>

# %% [markdown]
# ### Sanity check: can I track a model data set on this new set up

# %%
from btrack import datasets

# %%
segmentation = datasets.example_segmentation()

# %%
imshow(segmentation[0])

# %%
segmentation.shape
# Out:
# (500, 1200, 1600)

# %%
viewer = napari.Viewer()
viewer.add_labels(segmentation)
# Out:
# /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/napari_tools_menu/__init__.py:179: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Labels layer 'segmentation' at 0x7f89a7e00fd0>
# mode is cell:  True
# [INFO][2022/08/09 11:12:16 am] Loaded btrack: /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/btrack/libs/libtracker.so
# [INFO][2022/08/09 11:12:16 am] btrack (v0.4.5) library imported
# [INFO][2022/08/09 11:12:16 am] Starting BayesianTracker session
# [INFO][2022/08/09 11:12:16 am] Localizing objects from segmentation...
# [INFO][2022/08/09 11:14:18 am] Objects are of type: <class 'dict'>
# [INFO][2022/08/09 11:14:19 am] ...Found 34804 objects in 75 frames.
# [INFO][2022/08/09 11:14:19 am] Objects are of type: <class 'list'>
# [INFO][2022/08/09 11:14:19 am] Starting tracking...
# [INFO][2022/08/09 11:14:19 am] Tracking objects in frames 0 to 75 (of 75)...
# [INFO][2022/08/09 11:14:43 am]  - Timing (Bayesian updates: 11.59ms, Linking: 0.94ms)
# [INFO][2022/08/09 11:14:43 am]  - Probabilities (Link: 0.91317, Lost: 1.00000)
# [INFO][2022/08/09 11:14:43 am] SUCCESS.
# [INFO][2022/08/09 11:14:43 am]  - Found 18214 tracks in 75 frames (in 0.0s)
# [INFO][2022/08/09 11:14:44 am]  - Inserted 13486 dummy objects to fill tracking gaps
# [INFO][2022/08/09 11:14:44 am] Loading hypothesis model: cell_hypothesis
# [INFO][2022/08/09 11:14:44 am] Calculating hypotheses (relax: True)...
# [INFO][2022/08/09 11:14:44 am] Setting up constraints matrix for global optimisation...
# [INFO][2022/08/09 11:14:44 am] Using GLPK options: {'tm_lim': 60000}...
# [INFO][2022/08/09 11:14:52 am] Optimizing...
# [WARNING][2022/08/09 11:15:53 am] Optimizer returned status: undefined
# [WARNING][2022/08/09 11:15:53 am] Optimization failed.
# GLPK Integer Optimizer 5.0
# 72856 rows, 142179 columns, 247930 non-zeros
# 142179 integer variables, all of which are binary
# Preprocessing...
# 36428 rows, 142179 columns, 247930 non-zeros
# 142179 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 36428
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 36428 rows, 142179 columns, 247930 non-zeros
# *     0: obj =   2.168253622e+05 inf =   0.000e+00 (102564)
# Perturbing LP to avoid stalling [1834]...
# *  2761: obj =   1.854853841e+05 inf =   0.000e+00 (98074)
# *  5146: obj =   1.627410096e+05 inf =   0.000e+00 (92555)
# *  7266: obj =   1.465954918e+05 inf =   0.000e+00 (86270)
# *  9221: obj =   1.340954025e+05 inf =   0.000e+00 (79557)
# * 11045: obj =   1.240237794e+05 inf =   0.000e+00 (73267) 1
# * 12746: obj =   1.167159216e+05 inf =   0.000e+00 (67406) 1
# * 14397: obj =   1.099687322e+05 inf =   0.000e+00 (61858) 2
# * 15980: obj =   1.044870303e+05 inf =   0.000e+00 (57088) 2
# * 17544: obj =   9.936649317e+04 inf =   0.000e+00 (52849) 3
# * 19074: obj =   9.485099001e+04 inf =   0.000e+00 (48737) 3
# * 20578: obj =   9.084228660e+04 inf =   0.000e+00 (45314) 2
# Removing LP perturbation [22228]...
# * 22228: obj =   8.399322626e+04 inf =   0.000e+00 (42775) 1
# TIME LIMIT EXCEEDED; SEARCH TERMINATED
# [INFO][2022/08/09 11:15:54 am] Ending BayesianTracker session
# [INFO][2022/08/09 11:17:58 am] Loaded btrack: /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/btrack/libs/libtracker.so
# [INFO][2022/08/09 11:17:58 am] btrack (v0.4.5) library imported
# [INFO][2022/08/09 11:17:58 am] Starting BayesianTracker session
# [INFO][2022/08/09 11:17:58 am] Localizing objects from segmentation...
# [INFO][2022/08/09 11:20:01 am] Objects are of type: <class 'dict'>
# [INFO][2022/08/09 11:20:01 am] ...Found 34804 objects in 75 frames.
# [INFO][2022/08/09 11:20:01 am] Objects are of type: <class 'list'>
# [INFO][2022/08/09 11:20:01 am] Starting tracking...
# [INFO][2022/08/09 11:20:01 am] Tracking objects in frames 0 to 75 (of 75)...
# [INFO][2022/08/09 11:20:26 am]  - Timing (Bayesian updates: 11.88ms, Linking: 0.88ms)
# [INFO][2022/08/09 11:20:26 am]  - Probabilities (Link: 0.91317, Lost: 1.00000)
# [INFO][2022/08/09 11:20:26 am] SUCCESS.
# [INFO][2022/08/09 11:20:26 am]  - Found 18211 tracks in 75 frames (in 0.0s)
# [INFO][2022/08/09 11:20:26 am]  - Inserted 13533 dummy objects to fill tracking gaps
# [INFO][2022/08/09 11:20:26 am] Loading hypothesis model: cell_hypothesis
# [INFO][2022/08/09 11:20:26 am] Calculating hypotheses (relax: True)...
# [INFO][2022/08/09 11:20:27 am] Setting up constraints matrix for global optimisation...
# [INFO][2022/08/09 11:20:27 am] Using GLPK options: {'tm_lim': 60000}...
# [INFO][2022/08/09 11:20:37 am] Optimizing...
# [WARNING][2022/08/09 11:21:37 am] Optimizer returned status: undefined
# [WARNING][2022/08/09 11:21:37 am] Optimization failed.
# GLPK Integer Optimizer 5.0
# 72844 rows, 142121 columns, 247820 non-zeros
# 142121 integer variables, all of which are binary
# Preprocessing...
# 36422 rows, 142121 columns, 247820 non-zeros
# 142121 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 36422
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 36422 rows, 142121 columns, 247820 non-zeros
# *     0: obj =   2.167851345e+05 inf =   0.000e+00 (102511)
# Perturbing LP to avoid stalling [1830]...
# *  2025: obj =   1.932557864e+05 inf =   0.000e+00 (99404)
# *  4351: obj =   1.701337036e+05 inf =   0.000e+00 (94506)
# *  6515: obj =   1.519024800e+05 inf =   0.000e+00 (88650)
# *  8457: obj =   1.388950443e+05 inf =   0.000e+00 (82145)
# * 10284: obj =   1.281060980e+05 inf =   0.000e+00 (75931) 1
# * 11977: obj =   1.199196224e+05 inf =   0.000e+00 (70026) 1
# * 13606: obj =   1.130433590e+05 inf =   0.000e+00 (64424) 1
# * 15188: obj =   1.072000165e+05 inf =   0.000e+00 (59469) 2
# * 16732: obj =   1.018667439e+05 inf =   0.000e+00 (54836) 2
# * 18230: obj =   9.734702922e+04 inf =   0.000e+00 (51029) 3
# * 19741: obj =   9.307765442e+04 inf =   0.000e+00 (46979) 3
# Removing LP perturbation [21318]...
# * 21318: obj =   8.768252639e+04 inf =   0.000e+00 (44114) 1
# TIME LIMIT EXCEEDED; SEARCH TERMINATED
# [INFO][2022/08/09 11:21:39 am] Ending BayesianTracker session
# [INFO][2022/08/09 11:22:43 am] Loaded btrack: /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/btrack/libs/libtracker.so
# [INFO][2022/08/09 11:22:43 am] btrack (v0.4.5) library imported
# [INFO][2022/08/09 11:22:43 am] Starting BayesianTracker session
# [INFO][2022/08/09 11:22:43 am] Localizing objects from segmentation...
# [INFO][2022/08/09 11:24:46 am] Objects are of type: <class 'dict'>
# [INFO][2022/08/09 11:24:46 am] ...Found 34804 objects in 75 frames.
# [INFO][2022/08/09 11:24:46 am] Objects are of type: <class 'list'>
# [INFO][2022/08/09 11:24:46 am] Starting tracking...
# [INFO][2022/08/09 11:24:46 am] Tracking objects in frames 0 to 75 (of 75)...
# [INFO][2022/08/09 11:25:11 am]  - Timing (Bayesian updates: 11.88ms, Linking: 0.98ms)
# [INFO][2022/08/09 11:25:11 am]  - Probabilities (Link: 0.91317, Lost: 1.00000)
# [INFO][2022/08/09 11:25:11 am] SUCCESS.
# [INFO][2022/08/09 11:25:11 am]  - Found 18211 tracks in 75 frames (in 0.0s)
# [INFO][2022/08/09 11:25:11 am]  - Inserted 13533 dummy objects to fill tracking gaps
# [INFO][2022/08/09 11:25:11 am] Loading hypothesis model: cell_hypothesis
# [INFO][2022/08/09 11:25:11 am] Calculating hypotheses (relax: True)...
# [INFO][2022/08/09 11:25:12 am] Setting up constraints matrix for global optimisation...
# [INFO][2022/08/09 11:25:12 am] Using GLPK options: {'tm_lim': 60000}...
# [INFO][2022/08/09 11:25:23 am] Optimizing...
# [WARNING][2022/08/09 11:26:23 am] Optimizer returned status: undefined
# [WARNING][2022/08/09 11:26:23 am] Optimization failed.
# GLPK Integer Optimizer 5.0
# 72844 rows, 142121 columns, 247820 non-zeros
# 142121 integer variables, all of which are binary
# Preprocessing...
# 36422 rows, 142121 columns, 247820 non-zeros
# 142121 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 36422
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 36422 rows, 142121 columns, 247820 non-zeros
# *     0: obj =   2.167851345e+05 inf =   0.000e+00 (102688)
# Perturbing LP to avoid stalling [1828]...
# *  2026: obj =   1.930830761e+05 inf =   0.000e+00 (99579)
# *  4377: obj =   1.692309368e+05 inf =   0.000e+00 (94651)
# *  6496: obj =   1.510484285e+05 inf =   0.000e+00 (88857)
# *  8445: obj =   1.375318046e+05 inf =   0.000e+00 (82344)
# * 10246: obj =   1.264950603e+05 inf =   0.000e+00 (76210) 1
# * 11942: obj =   1.178963514e+05 inf =   0.000e+00 (70307) 1
# * 13574: obj =   1.106770952e+05 inf =   0.000e+00 (64620) 1
# * 15143: obj =   1.045520543e+05 inf =   0.000e+00 (59708) 2
# * 16680: obj =   9.905842588e+04 inf =   0.000e+00 (55097) 2
# * 18184: obj =   9.412382784e+04 inf =   0.000e+00 (51315) 3
# * 19688: obj =   8.940822479e+04 inf =   0.000e+00 (47272) 3
# Removing LP perturbation [21160]...
# * 21160: obj =   8.548698669e+04 inf =   0.000e+00 (44015) 3
# TIME LIMIT EXCEEDED; SEARCH TERMINATED
# [INFO][2022/08/09 11:26:24 am] Ending BayesianTracker session

# %% [markdown]
# ### Tracking does work on example data set, now testing resizing dataset so that its smaller

# %% [markdown]
# ####  Remove small objects

# %%
masks_post_process = []
for mask in tqdm(masks):
    mask = remove_small_objects(mask.compute(), min_size = 2000)
    masks_post_process.append(mask)
masks_pp = da.stack(masks_post_process, axis = 0)
# Out:
#   0%|          | 0/75 [00:00<?, ?it/s]

# %% [markdown]
# #### Resize example segmentation for a quick test

# %%
import cv2

# %%
segmentation.shape
# Out:
# (500, 1200, 1600)

# %%
seg_post_process = []
for seg in tqdm(segmentation):
    seg = cv2.resize(seg, dsize = (1600*5, 1200*5), interpolation = cv2.INTER_NEAREST_EXACT)
    seg_post_process.append(seg)
segmentation = da.stack(seg_post_process, axis = 0)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
segmentation
# Out:
# dask.array<stack, shape=(500, 6000, 8000), dtype=uint8, chunksize=(1, 6000, 8000), chunktype=numpy.ndarray>

# %%
imshow(seg)

# %%
viewer = napari.Viewer()
viewer.add_labels(segmentation)
# Out:
# /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/napari_tools_menu/__init__.py:179: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Labels layer 'segmentation' at 0x7f0c2c64c610>
# [INFO][2022/08/09 03:34:34 pm] Loading configuration file: /home/dayn/.cache/btrack-examples/examples/cell_config.json
# [INFO][2022/08/09 03:34:42 pm] Loaded btrack: /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/btrack/libs/libtracker.so
# [INFO][2022/08/09 03:34:42 pm] btrack (v0.4.5) library imported
# [INFO][2022/08/09 03:34:42 pm] Starting BayesianTracker session
# [INFO][2022/08/09 03:34:42 pm] Localizing objects from segmentation...
# [INFO][2022/08/09 03:43:51 pm] Objects are of type: <class 'dict'>
# [INFO][2022/08/09 03:43:52 pm] ...Found 52890 objects in 500 frames.
# [INFO][2022/08/09 03:43:52 pm] Objects are of type: <class 'list'>
# [INFO][2022/08/09 03:43:52 pm] Starting tracking...
# [INFO][2022/08/09 03:43:52 pm] Tracking objects in frames 0 to 99 (of 500)...
# [INFO][2022/08/09 03:43:52 pm]  - Timing (Bayesian updates: 1.51ms, Linking: 0.33ms)
# [INFO][2022/08/09 03:43:52 pm]  - Probabilities (Link: 1.00000, Lost: 0.54881)
# [INFO][2022/08/09 03:43:52 pm]  - Stats (Active: 138, Lost: 13348, Conflicts resolved: 1283)
# [INFO][2022/08/09 03:43:52 pm] Tracking objects in frames 100 to 199 (of 500)...
# [INFO][2022/08/09 03:43:52 pm]  - Timing (Bayesian updates: 1.94ms, Linking: 0.40ms)
# [INFO][2022/08/09 03:43:52 pm]  - Probabilities (Link: 0.99984, Lost: 0.99997)
# [INFO][2022/08/09 03:43:52 pm]  - Stats (Active: 157, Lost: 19622, Conflicts resolved: 2889)
# [INFO][2022/08/09 03:43:52 pm] Tracking objects in frames 200 to 299 (of 500)...
# [INFO][2022/08/09 03:43:53 pm]  - Timing (Bayesian updates: 4.90ms, Linking: 0.59ms)
# [INFO][2022/08/09 03:43:53 pm]  - Probabilities (Link: 0.99925, Lost: 0.99873)
# [INFO][2022/08/09 03:43:53 pm]  - Stats (Active: 273, Lost: 28379, Conflicts resolved: 4863)
# [INFO][2022/08/09 03:43:53 pm] Tracking objects in frames 300 to 399 (of 500)...
# [INFO][2022/08/09 03:43:53 pm]  - Timing (Bayesian updates: 5.66ms, Linking: 0.58ms)
# [INFO][2022/08/09 03:43:53 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2022/08/09 03:43:53 pm]  - Stats (Active: 247, Lost: 39497, Conflicts resolved: 7436)
# [INFO][2022/08/09 03:43:53 pm] Tracking objects in frames 400 to 499 (of 500)...
# [INFO][2022/08/09 03:43:54 pm]  - Timing (Bayesian updates: 9.12ms, Linking: 0.87ms)
# [INFO][2022/08/09 03:43:54 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2022/08/09 03:43:54 pm] SUCCESS.
# [INFO][2022/08/09 03:43:54 pm]  - Found 9403 tracks in 500 frames (in 0.0s)
# [INFO][2022/08/09 03:43:55 pm]  - Inserted 6537 dummy objects to fill tracking gaps
# [INFO][2022/08/09 03:43:55 pm] Loading hypothesis model: particle_hypothesis
# [INFO][2022/08/09 03:43:55 pm] Calculating hypotheses (relax: True)...
# [INFO][2022/08/09 03:43:55 pm] Setting up constraints matrix for global optimisation...
# [INFO][2022/08/09 03:43:55 pm] Using GLPK options: {'tm_lim': 60000}...
# [INFO][2022/08/09 03:43:56 pm] Optimizing...
# [INFO][2022/08/09 03:44:17 pm] Optimization complete. (Solution: optimal)
# [INFO][2022/08/09 03:44:17 pm]  - Fates.FALSE_POSITIVE: 2765 (of 9403)
# [INFO][2022/08/09 03:44:17 pm]  - Fates.LINK: 5460 (of 7385)
# [INFO][2022/08/09 03:44:17 pm]  - Fates.DIVIDE: 32 (of 228)
# [INFO][2022/08/09 03:44:17 pm]  - Fates.INITIALIZE_BORDER: 55 (of 136)
# [INFO][2022/08/09 03:44:17 pm]  - Fates.INITIALIZE_FRONT: 65 (of 180)
# [INFO][2022/08/09 03:44:17 pm]  - Fates.INITIALIZE_LAZY: 994 (of 9087)
# [INFO][2022/08/09 03:44:17 pm]  - Fates.TERMINATE_BORDER: 55 (of 136)
# [INFO][2022/08/09 03:44:17 pm]  - Fates.TERMINATE_BACK: 190 (of 256)
# [INFO][2022/08/09 03:44:17 pm]  - Fates.TERMINATE_LAZY: 901 (of 9011)
# [INFO][2022/08/09 03:44:17 pm]  - TOTAL: 35822 hypotheses
# GLPK Integer Optimizer 5.0
# 37612 rows, 35822 columns, 53066 non-zeros
# 35822 integer variables, all of which are binary
# Preprocessing...
# 18806 rows, 35822 columns, 53066 non-zeros
# 35822 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 18806
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 18806 rows, 35822 columns, 53066 non-zeros
# *     0: obj =   1.219130642e+05 inf =   0.000e+00 (13399)
# Perturbing LP to avoid stalling [1921]...
# *  5990: obj =   6.184582924e+04 inf =   0.000e+00 (7147)
# * 11300: obj =   4.094979977e+04 inf =   0.000e+00 (2561) 3
# Removing LP perturbation [14369]...
# * 14369: obj =   3.514821623e+04 inf =   0.000e+00 (0) 5
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# + 14369: mip =     not found yet >=              -inf        (1; 0)
# + 14386: >>>>>   3.517050903e+04 >=   3.515219644e+04 < 0.1% (13; 0)
# + 14483: mip =   3.517050903e+04 >=   3.516436450e+04 < 0.1% (31; 24)
# + 14534: mip =   3.517050903e+04 >=     tree is empty   0.0% (0; 107)
# INTEGER OPTIMAL SOLUTION FOUND
# [INFO][2022/08/09 03:44:17 pm] Completed optimization with 3943 tracks
# [INFO][2022/08/09 03:44:17 pm] Ending BayesianTracker session

# %% [markdown]
# ## Conclusion from that:
#
# Tracking works fine on larger segmentation, so it is something about my data, not the implementation over a larger size, that is the issue here.
#
# #### What is the mean square displacement per frame for cells?

# %%
segmentation
# Out:
# dask.array<stack, shape=(500, 6000, 8000), dtype=uint8, chunksize=(1, 6000, 8000), chunktype=numpy.ndarray>

# %%
# load your segmentation data
# create btrack objects (with properties) from the segmentation data
# (you can also calculate properties, based on scikit-image regionprops)
objects = btrack.utils.segmentation_to_objects(
  segmentation, properties=('area', 'centroid', 'centroid_local')
)

# initialise a tracker session using a context manager
with btrack.BayesianTracker() as tracker:

  # configure the tracker using a config file
  tracker.configure('/home/dayn/analysis/BayesianTracker/models/particle_config.json')

  # append the objects to be tracked
  tracker.append(objects)

  # set the volume (Z axis volume limits default to [-1e5, 1e5] for 2D data)
  tracker.volume = ((0, 1200), (0, 1600))

  # track them (in interactive mode)
  tracker.track_interactive(step_size=100)

  # generate hypotheses and run the global optimizer
  tracker.optimize()

  # get the tracks as a python list
  tracks = tracker.tracks

  # optional: get the data in a format for napari
  data, properties, graph = tracker.to_napari()
# Out:
# [INFO][2022/08/09 04:35:49 pm] Localizing objects from segmentation...
# [INFO][2022/08/09 04:36:08 pm] Objects are of type: <class 'dict'>
# [INFO][2022/08/09 04:36:09 pm] ...Found 52890 objects in 500 frames.
# [INFO][2022/08/09 04:36:09 pm] Loaded btrack: /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/btrack/libs/libtracker.so
# [INFO][2022/08/09 04:36:09 pm] btrack (v0.4.5) library imported
# [INFO][2022/08/09 04:36:09 pm] Starting BayesianTracker session
# [INFO][2022/08/09 04:36:09 pm] Loading configuration file: /home/dayn/analysis/BayesianTracker/models/particle_config.json
# [INFO][2022/08/09 04:36:09 pm] Objects are of type: <class 'list'>
# [INFO][2022/08/09 04:36:09 pm] Starting tracking...
# [INFO][2022/08/09 04:36:09 pm] Tracking objects in frames 0 to 99 (of 500)...
# [INFO][2022/08/09 04:36:09 pm]  - Timing (Bayesian updates: 0.75ms, Linking: 0.17ms)
# [INFO][2022/08/09 04:36:09 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2022/08/09 04:36:09 pm]  - Stats (Active: 64, Lost: 83, Conflicts resolved: 105)
# [INFO][2022/08/09 04:36:09 pm] Tracking objects in frames 100 to 199 (of 500)...
# [INFO][2022/08/09 04:36:09 pm]  - Timing (Bayesian updates: 0.84ms, Linking: 0.18ms)
# [INFO][2022/08/09 04:36:09 pm]  - Probabilities (Link: 1.00000, Lost: 0.99997)
# [INFO][2022/08/09 04:36:09 pm]  - Stats (Active: 67, Lost: 115, Conflicts resolved: 136)
# [INFO][2022/08/09 04:36:09 pm] Tracking objects in frames 200 to 299 (of 500)...
# [INFO][2022/08/09 04:36:09 pm]  - Timing (Bayesian updates: 1.77ms, Linking: 0.28ms)
# [INFO][2022/08/09 04:36:09 pm]  - Probabilities (Link: 1.00000, Lost: 0.99998)
# [INFO][2022/08/09 04:36:09 pm]  - Stats (Active: 92, Lost: 171, Conflicts resolved: 243)
# [INFO][2022/08/09 04:36:09 pm] Tracking objects in frames 300 to 399 (of 500)...
# [INFO][2022/08/09 04:36:10 pm]  - Timing (Bayesian updates: 2.74ms, Linking: 0.32ms)
# [INFO][2022/08/09 04:36:10 pm]  - Probabilities (Link: 1.00000, Lost: 0.98716)
# [INFO][2022/08/09 04:36:10 pm]  - Stats (Active: 111, Lost: 334, Conflicts resolved: 419)
# [INFO][2022/08/09 04:36:10 pm] Tracking objects in frames 400 to 499 (of 500)...
# [INFO][2022/08/09 04:36:10 pm]  - Timing (Bayesian updates: 5.13ms, Linking: 0.46ms)
# [INFO][2022/08/09 04:36:10 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2022/08/09 04:36:10 pm] SUCCESS.
# [INFO][2022/08/09 04:36:10 pm]  - Found 10970 tracks in 500 frames (in 0.0s)
# [INFO][2022/08/09 04:36:10 pm]  - Inserted 129 dummy objects to fill tracking gaps
# [INFO][2022/08/09 04:36:10 pm] Loading hypothesis model: particle_hypothesis
# [INFO][2022/08/09 04:36:10 pm] Calculating hypotheses (relax: True)...
# [INFO][2022/08/09 04:36:11 pm] Setting up constraints matrix for global optimisation...
# [INFO][2022/08/09 04:36:11 pm] Using GLPK options: {'tm_lim': 60000}...
# [INFO][2022/08/09 04:36:13 pm] Optimizing...
# [INFO][2022/08/09 04:36:14 pm] Optimization complete. (Solution: optimal)
# [INFO][2022/08/09 04:36:14 pm]  - Fates.FALSE_POSITIVE: 34 (of 10970)
# [INFO][2022/08/09 04:36:14 pm]  - Fates.LINK: 97 (of 33089)
# [INFO][2022/08/09 04:36:14 pm]  - Fates.INITIALIZE_BORDER: 10687 (of 10705)
# [INFO][2022/08/09 04:36:14 pm]  - Fates.INITIALIZE_FRONT: 54 (of 55)
# [INFO][2022/08/09 04:36:14 pm]  - Fates.INITIALIZE_LAZY: 98 (of 210)
# [INFO][2022/08/09 04:36:14 pm]  - Fates.TERMINATE_BORDER: 10680 (of 10700)
# [INFO][2022/08/09 04:36:14 pm]  - Fates.TERMINATE_BACK: 141 (of 144)
# [INFO][2022/08/09 04:36:14 pm]  - Fates.TERMINATE_LAZY: 18 (of 126)
# [INFO][2022/08/09 04:36:14 pm]  - TOTAL: 65999 hypotheses
# [INFO][2022/08/09 04:36:14 pm] Completed optimization with 10873 tracks
# GLPK Integer Optimizer 5.0
# 43880 rows, 65999 columns, 110058 non-zeros
# 65999 integer variables, all of which are binary
# Preprocessing...
# 21940 rows, 65999 columns, 110058 non-zeros
# 65999 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 21940
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 21940 rows, 65999 columns, 110058 non-zeros
# *     0: obj =  -8.661713941e+05 inf =   0.000e+00 (196)
# *   197: obj =  -8.674194841e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   197: mip =     not found yet >=              -inf        (1; 0)
# +   197: >>>>>  -8.674194841e+05 >=  -8.674194841e+05   0.0% (1; 0)
# +   197: mip =  -8.674194841e+05 >=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# [INFO][2022/08/09 04:36:15 pm] Ending BayesianTracker session

# %%
viewer = napari.Viewer()
viewer.add_tracks(data)
# Out:
# /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/napari_tools_menu/__init__.py:179: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Tracks layer 'data' at 0x7fcf5c505250>

# %%
def euc_dist(x1, y1, x2, y2):
    if x2 == None:
        return None
    return np.sqrt((x1-x2)**2+(y1-y2)**2)

# %%
msd_pf_ = []
for track in tqdm(tracks):
    if len(track) > 20:
        d = []
        coords_t1 = None, None
        for coords in zip(track.x, track.y):
            x1, y1 = coords
            x2, y2 = coords_t1
            d.append(euc_dist(x1, y1, x2, y2))
            coords_t1 = coords
        msd_pf = np.mean(d[1:])
        msd_pf_.append(msd_pf)
print('Average MSD per frame for example dataset is:',np.mean(msd_pf_))
# Out:
#   0%|          | 0/10873 [00:00<?, ?it/s]
# Average MSD per frame for example dataset is: 2.2333777483425976

# %% [markdown]
# Average MSD per frame for example dataset is: 2.2333777483425976

# %% [markdown]
# # MSD pf for actual data
#
# Take notes on location with a points layer

# %%
masks
# Out:
# dask.array<from-zarr, shape=(75, 6048, 6048), dtype=uint16, chunksize=(1, 2160, 2160), chunktype=numpy.ndarray>

# %%
import napari
import numpy as np

# %%
points = []

# %%
gfp
# Out:
# dask.array<sum-aggregate, shape=(75, 6048, 6048), dtype=uint16, chunksize=(1, 2160, 2160), chunktype=numpy.ndarray>

# %%
viewer = napari.Viewer()

points = viewer.add_points()
viewer.add_labels(masks)
viewer.add_image(gfp, blending = 'additive', colormap = 'green')
# Out:
# /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/napari_tools_menu/__init__.py:179: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Image layer 'gfp' at 0x7f4b24a45580>

# %% [markdown]
# ### This points data is my visual assessment of where the centroid lies, not exactly very accurate.

# %%
points.data
# Out:
# array([[2883.65196822, 2262.94590514],
#        [2872.74372278, 2287.18645055],
#        [2882.43994095, 2305.36685961],
#        [2835.17087739, 2289.61050509],
#        [2821.83857741, 2281.1263142 ],
#        [2798.81005927, 2252.0376597 ],
#        [2801.23411381, 2264.15793241],
#        [2798.81005927, 2283.55036874],
#        [2809.71830471, 2310.21496869],
#        [2803.65816835, 2220.52495067],
#        [2790.32586838, 2187.80021436],
#        [2796.38600473, 2193.86035071],
#        [2790.32586838, 2233.85725064],
#        [2791.53789565, 2216.88886885],
#        [2796.38600473, 2219.31292339]])

# %%
msd_pf_2 = []
d_2 = []
coords_t1 = None, None
for coords in points.data:
    x1, y1 = coords
    x2, y2 = coords_t1
    d_2.append(euc_dist(x1, y1, x2, y2))
    coords_t1 = coords
msd_pf2 = np.mean(d_2[1:])
msd_pf_2.append(msd_pf2)
print('Average MSD per frame for example dataset is:',np.mean(msd_pf_2))
# Out:
# Average MSD per frame for example dataset is: 29.093975527769402

# %% [markdown]
# ### Using the points data to pull the label value from an individual segment and then using that to find the centroid and MSD

# %%
viewer = napari.Viewer()

points_1 = viewer.add_points()
points_2 = viewer.add_points()
points_3 = viewer.add_points()

viewer.add_labels(masks)
viewer.add_image(gfp, blending = 'additive', colormap = 'green')
# Out:
# /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/napari_tools_menu/__init__.py:179: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Image layer 'gfp' at 0x7f4b0da99670>

# %%
for points_i in [points_1, points_2, points_3]:
    points = points_i.data
    msd_pf_list = []
    coords_t1 = None, None
    d_i = []
    for coords in points:
        x1, y1 = coords
        x2, y2 = coords_t1
        d_i.append(euc_dist(x1, y1, x2, y2))
        coords_t1 = coords
    msd_pf = np.mean(d_i[1:])
    msd_pf_list.append(msd_pf)
    print('Average MSD per frame for example dataset is:',np.mean(msd_pf))
# Out:
# Average MSD per frame for example dataset is: 7.992505680028197
# Average MSD per frame for example dataset is: 66.59435440537037
# Average MSD per frame for example dataset is: 30.894417725330047

# %% [markdown]
# # Now calculate actual centroid from segmentation map

# %%
for points_i in [points_1, points_2, points_3]:
    points = points_i.data
    msd_pf_list = []
    coords_t1 = None, None
    d_i = []
    for coords in points:
        find_centroid_coords
        
        
        x1, y1 = coords
        x2, y2 = coords_t1
        d_i.append(euc_dist(x1, y1, x2, y2))
        coords_t1 = coords
    msd_pf = np.mean(d_i[1:])
    msd_pf_list.append(msd_pf)
    print('Average MSD per frame for example dataset is:',np.mean(msd_pf))

# %%
def find_centroid_coords(x1, y1)

# %%
points_1.ndim
# Out:
# 2

# %%
for coords in points_1.data:
# Out:
# array([[5106.14276438, 3926.09810005],
#        [5121.8991189 , 3937.00634549],
#        [5194.62075514, 3932.15823641],
#        [5227.34549145, 3921.24999097],
#        [5266.13036411, 3912.76580008],
#        [5249.16198232, 3927.31012732],
#        [5257.64617322, 3932.15823641],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5270.97847319, 3926.09810005],
#        [5295.21901861, 3944.27850911],
#        [5312.1874004 , 3956.39878182],
#        [5321.88361856, 3956.39878182],
#        [5332.791864  , 3961.2468909 ],
#        [5332.791864  , 3961.2468909 ],
#        [5332.791864  , 3961.2468909 ],
#        [5336.42794581, 3962.45891817],
#        [5334.00389127, 3949.12661819],
#        [5334.00389127, 3946.70256365],
#        [5334.00389127, 3946.70256365],
#        [5321.88361856, 3933.37026368],
#        [5321.88361856, 3933.37026368],
#        [5321.88361856, 3933.37026368],
#        [5279.46266409, 3944.27850911],
#        [5279.46266409, 3944.27850911],
#        [5268.55441865, 3970.94310907],
#        [5268.55441865, 3970.94310907],
#        [5272.19050046, 3969.7310818 ],
#        [5272.19050046, 3969.7310818 ],
#        [5269.76644592, 3969.7310818 ],
#        [5269.76644592, 3969.7310818 ],
#        [5285.52280044, 3955.18675455],
#        [5285.52280044, 3961.2468909 ],
#        [5273.40252773, 3967.30702725],
#        [5273.40252773, 3967.30702725],
#        [5273.40252773, 3967.30702725],
#        [5280.67469136, 3966.09499998],
#        [5280.67469136, 3966.09499998],
#        [5275.82658228, 3977.00324542],
#        [5267.34239138, 3964.88297271],
#        [5267.34239138, 3964.88297271],
#        [5267.34239138, 3964.88297271],
#        [5267.34239138, 3964.88297271],
#        [5267.34239138, 3964.88297271],
#        [5267.34239138, 3964.88297271],
#        [5269.76644592, 3950.33864547],
#        [5269.76644592, 3950.33864547],
#        [5269.76644592, 3950.33864547],
#        [5269.76644592, 3950.33864547],
#        [5284.31077317, 3941.85445457],
#        [5302.49118223, 3944.27850911],
#        [5302.49118223, 3944.27850911],
#        [5302.49118223, 3944.27850911],
#        [5301.27915496, 3944.27850911],
#        [5301.27915496, 3944.27850911],
#        [5301.27915496, 3944.27850911],
#        [5301.27915496, 3944.27850911],
#        [5301.27915496, 3944.27850911],
#        [5301.27915496, 3944.27850911],
#        [5301.27915496, 3944.27850911],
#        [5281.88671863, 3943.06648184],
#        [5281.88671863, 3943.06648184],
#        [5281.88671863, 3943.06648184],
#        [5281.88671863, 3943.06648184],
#        [5281.88671863, 3943.06648184],
#        [5272.19050046, 3956.39878182],
#        [5272.19050046, 3974.57919088],
#        [5275.82658228, 3962.45891817],
#        [5275.82658228, 3962.45891817],
#        [5260.07022776, 3943.06648184],
#        [5262.4942823 , 3941.85445457],
#        [5262.4942823 , 3941.85445457],
#        [5278.25063682, 3945.49053638]])

# %%
viewer = napari.Viewer()

points_5 = viewer.add_points(ndim=3)
points_4 = viewer.add_points(ndim=3)
points_3 = viewer.add_points(ndim=3)
points_2 = viewer.add_points(ndim=3)
points_1 = viewer.add_points(ndim=3)

viewer.add_labels(masks)
viewer.add_image(gfp, blending = 'additive', colormap = 'green')

# %% [markdown]
# #### Changing data to pandas format

# %%
import pandas as pd

# %%
points_5

# %%
for n, points in enumerate([points_1, points_2, points_3, points_4, points_5]):
    print(n, points.data)
# Out:
# 0 [[0.00000000e+00 1.56780930e+03 2.73646022e+03]
#  [1.00000000e+00 1.56239114e+03 2.75406922e+03]
#  [2.00000000e+00 1.57187291e+03 2.74729653e+03]
#  [3.00000000e+00 1.57729107e+03 2.76558280e+03]
#  [4.00000000e+00 1.43032361e+03 2.92609565e+03]
#  [5.00000000e+00 1.39781468e+03 2.94370466e+03]
#  [6.00000000e+00 1.38494656e+03 2.96470001e+03]
#  [7.00000000e+00 1.37343298e+03 3.00533617e+03]
#  [8.00000000e+00 1.43709630e+03 2.90916392e+03]
#  [9.00000000e+00 1.44725535e+03 2.92203203e+03]
#  [1.00000000e+01 1.47570066e+03 2.89561853e+03]
#  [1.10000000e+01 1.47908701e+03 2.86717321e+03]
#  [1.20000000e+01 1.47434612e+03 2.88884583e+03]
#  [1.30000000e+01 1.43912811e+03 2.95183189e+03]
#  [1.40000000e+01 1.41271461e+03 2.95860458e+03]
#  [1.50000000e+01 1.41745549e+03 2.95250916e+03]
#  [1.60000000e+01 1.43641903e+03 2.92135477e+03]
#  [1.70000000e+01 1.51972317e+03 2.84482332e+03]
#  [1.80000000e+01 1.50753232e+03 2.88342768e+03]
#  [1.90000000e+01 1.46554162e+03 2.90103668e+03]
#  [2.00000000e+01 1.48653697e+03 2.89765034e+03]
#  [2.10000000e+01 1.48044155e+03 2.88613676e+03]
#  [2.20000000e+01 1.48382789e+03 2.87936406e+03]
#  [2.30000000e+01 1.42490545e+03 2.92135477e+03]
#  [2.40000000e+01 1.46892797e+03 2.89290945e+03]
#  [2.50000000e+01 1.57119565e+03 2.79335085e+03]
#  [2.60000000e+01 1.66845069e+03 2.76002642e+03]
#  [2.70000000e+01 1.71382774e+03 2.76747638e+03]
#  [2.80000000e+01 1.69147785e+03 2.72413114e+03]
#  [2.90000000e+01 1.45918812e+03 2.62662939e+03]
#  [3.00000000e+01 1.36391959e+03 2.56749719e+03]
#  [3.10000000e+01 1.37459623e+03 2.36710476e+03]
#  [3.20000000e+01 1.37788135e+03 2.33671738e+03]
#  [3.30000000e+01 1.34667270e+03 2.35314299e+03]
#  [3.40000000e+01 1.36227702e+03 2.36464092e+03]
#  [3.50000000e+01 1.36227702e+03 2.44759024e+03]
#  [3.60000000e+01 1.37213239e+03 2.39174317e+03]
#  [3.70000000e+01 1.36391959e+03 2.41556030e+03]
#  [3.80000000e+01 1.33024709e+03 2.32193433e+03]
#  [3.90000000e+01 1.35488550e+03 2.43855616e+03]
#  [4.00000000e+01 1.35160038e+03 2.43691360e+03]
#  [4.10000000e+01 1.36227702e+03 2.40241982e+03]
#  [4.20000000e+01 1.35817062e+03 2.38435165e+03]
#  [4.30000000e+01 1.36802599e+03 2.36135579e+03]
#  [4.40000000e+01 1.37788135e+03 2.40159854e+03]
#  [4.50000000e+01 1.36720471e+03 2.38599421e+03]
#  [4.60000000e+01 1.40744745e+03 2.40981134e+03]
#  [4.70000000e+01 1.44358379e+03 2.41884543e+03]
#  [4.80000000e+01 1.43126458e+03 2.47222866e+03]]
# 1 [[7.40000000e+01 7.63741520e+02 3.50427099e+03]
#  [7.30000000e+01 7.64770791e+02 3.50632953e+03]
#  [7.20000000e+01 7.46243914e+02 3.49603682e+03]
#  [7.10000000e+01 7.73004959e+02 3.51353442e+03]
#  [7.00000000e+01 7.82268397e+02 3.49603682e+03]
#  [6.90000000e+01 7.84326939e+02 3.48677338e+03]
#  [6.80000000e+01 7.82268397e+02 3.49500755e+03]
#  [6.70000000e+01 7.91531835e+02 3.50118317e+03]
#  [6.60000000e+01 7.79180584e+02 3.49294901e+03]
#  [6.20000000e+01 7.68887875e+02 3.50324172e+03]
#  [6.00000000e+01 8.04912358e+02 3.50118317e+03]
#  [5.90000000e+01 8.03883087e+02 3.53103203e+03]
#  [5.80000000e+01 8.10058712e+02 3.51044661e+03]
#  [5.70000000e+01 8.39907569e+02 3.50530026e+03]
#  [5.60000000e+01 8.23439234e+02 3.50118317e+03]
#  [5.50000000e+01 8.73873510e+02 3.48574411e+03]
#  [5.40000000e+01 8.40936840e+02 3.48780265e+03]
#  [5.30000000e+01 8.48141737e+02 3.47853921e+03]
#  [5.20000000e+01 8.34761214e+02 3.46824650e+03]
#  [5.10000000e+01 8.68727155e+02 3.48265630e+03]
#  [5.00000000e+01 8.55346633e+02 3.46721723e+03]
#  [4.90000000e+01 8.48141737e+02 3.47133432e+03]
#  [4.80000000e+01 8.28585589e+02 3.48265630e+03]
#  [4.70000000e+01 8.06970899e+02 3.51868078e+03]
#  [4.60000000e+01 7.89473294e+02 3.53103203e+03]
#  [4.50000000e+01 7.96678190e+02 3.50735880e+03]
#  [4.40000000e+01 8.22409963e+02 3.50221244e+03]
#  [4.30000000e+01 8.18292880e+02 3.49089046e+03]
#  [4.20000000e+01 7.86385481e+02 3.49397828e+03]
#  [4.10000000e+01 7.83297668e+02 3.48780265e+03]
#  [4.00000000e+01 7.80209855e+02 3.49191974e+03]
#  [3.90000000e+01 7.63741520e+02 3.50324172e+03]
#  [3.80000000e+01 7.59624437e+02 3.51147588e+03]
#  [3.70000000e+01 7.52419540e+02 3.50118317e+03]
#  [3.60000000e+01 7.66829333e+02 3.50015390e+03]
#  [3.50000000e+01 7.56536624e+02 3.49809536e+03]
#  [3.40000000e+01 7.59624437e+02 3.48368557e+03]
#  [3.30000000e+01 7.65800062e+02 3.48368557e+03]
#  [3.20000000e+01 7.76092771e+02 3.47545140e+03]
#  [3.10000000e+01 8.25497776e+02 3.47853921e+03]
#  [3.00000000e+01 7.81239126e+02 3.50530026e+03]
#  [2.90000000e+01 8.00795274e+02 3.48986119e+03]
#  [2.80000000e+01 7.52419540e+02 3.53823693e+03]
#  [2.70000000e+01 6.85516930e+02 3.58558339e+03]
#  [2.60000000e+01 6.55668073e+02 3.61852006e+03]
#  [2.50000000e+01 6.52580260e+02 3.63498839e+03]
#  [2.40000000e+01 6.30965570e+02 3.65660308e+03]
#  [2.30000000e+01 6.30965570e+02 3.65351527e+03]
#  [2.20000000e+01 6.50521718e+02 3.63910548e+03]
#  [2.10000000e+01 6.31994841e+02 3.64733965e+03]
#  [2.00000000e+01 6.10380152e+02 3.65557381e+03]
#  [1.90000000e+01 6.16555777e+02 3.66689579e+03]
#  [1.80000000e+01 6.36111925e+02 3.63910548e+03]
#  [1.70000000e+01 6.46404634e+02 3.63704694e+03]
#  [1.70000000e+01 6.56697344e+02 3.62366641e+03]
#  [1.50000000e+01 6.78312033e+02 3.59690537e+03]
#  [1.40000000e+01 6.91692555e+02 3.58764193e+03]
#  [1.30000000e+01 6.39199738e+02 3.62469569e+03]
#  [1.20000000e+01 6.71107137e+02 3.61440298e+03]
#  [1.10000000e+01 6.07292339e+02 3.62057860e+03]
#  [1.00000000e+01 6.34053383e+02 3.61954933e+03]
#  [9.00000000e+00 6.68019324e+02 3.59484683e+03]
#  [8.00000000e+00 6.38170467e+02 3.62572496e+03]
#  [7.00000000e+00 6.09350881e+02 3.62263714e+03]
#  [6.00000000e+00 5.99058171e+02 3.63498839e+03]
#  [5.00000000e+00 6.31994841e+02 3.61954933e+03]
#  [4.00000000e+00 6.44346092e+02 3.60719808e+03]
#  [3.00000000e+00 6.94780368e+02 3.57426141e+03]
#  [2.00000000e+00 6.69048595e+02 3.56602724e+03]
#  [1.00000000e+00 6.69048595e+02 3.56396870e+03]
#  [0.00000000e+00 6.44346092e+02 3.55058818e+03]
#  [0.00000000e+00 6.58755885e+02 3.52794422e+03]]
# 2 [[0.00000000e+00 4.91045436e+02 2.40145977e+03]
#  [1.00000000e+00 5.06908943e+02 2.48411699e+03]
#  [2.00000000e+00 4.81026380e+02 2.48829160e+03]
#  [3.00000000e+00 4.55978738e+02 2.48161223e+03]
#  [4.00000000e+00 4.35105703e+02 2.48161223e+03]
#  [5.00000000e+00 4.45959681e+02 2.46908840e+03]
#  [6.00000000e+00 4.70172402e+02 2.51166940e+03]
#  [7.00000000e+00 4.68502559e+02 2.49914557e+03]
#  [8.00000000e+00 4.89375594e+02 2.51166940e+03]
#  [9.00000000e+00 4.70172402e+02 2.52836782e+03]
#  [1.00000000e+01 4.56813659e+02 2.51584400e+03]
#  [1.10000000e+01 4.46794603e+02 2.51834877e+03]
#  [1.20000000e+01 4.53473974e+02 2.51166940e+03]
#  [1.30000000e+01 4.60988266e+02 2.51834877e+03]
#  [1.40000000e+01 4.70172402e+02 2.52920274e+03]
#  [1.50000000e+01 4.71842244e+02 2.53087259e+03]
#  [1.70000000e+01 4.84366065e+02 2.54172657e+03]
#  [1.50000000e+01 4.82696222e+02 2.53838688e+03]
#  [1.70000000e+01 4.68502559e+02 2.53337735e+03]
#  [1.80000000e+01 4.71842244e+02 2.54840594e+03]
#  [1.90000000e+01 4.65997795e+02 2.54339641e+03]
#  [2.00000000e+01 4.89375594e+02 2.54339641e+03]
#  [2.10000000e+01 5.01899414e+02 2.54172657e+03]
#  [2.20000000e+01 5.19432764e+02 2.55007578e+03]
#  [2.30000000e+01 4.96054965e+02 2.54506625e+03]
#  [2.40000000e+01 4.90210515e+02 2.54506625e+03]
#  [2.50000000e+01 4.69337480e+02 2.54590117e+03]
#  [2.60000000e+01 4.61823188e+02 2.54005672e+03]
#  [2.70000000e+01 4.73512087e+02 2.53671704e+03]
#  [2.80000000e+01 4.78521615e+02 2.53337735e+03]
#  [2.90000000e+01 4.84366065e+02 2.52586306e+03]
#  [3.00000000e+01 4.99394650e+02 2.52001861e+03]
#  [3.10000000e+01 4.73512087e+02 2.51333924e+03]
#  [3.20000000e+01 4.56813659e+02 2.53838688e+03]
#  [3.30000000e+01 4.44289838e+02 2.52419322e+03]
#  [3.40000000e+01 4.36775546e+02 2.54339641e+03]
#  [3.50000000e+01 4.35940625e+02 2.56510436e+03]
#  [3.60000000e+01 4.55978738e+02 2.56092976e+03]
#  [3.70000000e+01 4.48464445e+02 2.56927897e+03]
#  [3.80000000e+01 4.60153345e+02 2.57261866e+03]
#  [3.90000000e+01 4.46794603e+02 2.59265677e+03]
#  [4.00000000e+01 4.40950153e+02 2.58096787e+03]
#  [4.10000000e+01 4.61823188e+02 2.61937425e+03]
#  [4.20000000e+01 4.35940625e+02 2.59015201e+03]
#  [4.30000000e+01 4.29261253e+02 2.59599646e+03]
#  [4.40000000e+01 4.29261253e+02 2.59599646e+03]
#  [4.50000000e+01 4.26756489e+02 2.59182185e+03]
#  [4.60000000e+01 4.18407275e+02 2.59015201e+03]
#  [4.70000000e+01 4.31766018e+02 2.59015201e+03]
#  [4.80000000e+01 4.17572354e+02 2.59182185e+03]
#  [4.90000000e+01 4.07553297e+02 2.58764724e+03]
#  [5.00000000e+01 4.11727904e+02 2.58931708e+03]
#  [5.10000000e+01 4.14232668e+02 2.59265677e+03]
#  [5.20000000e+01 4.25086646e+02 2.60434567e+03]
#  [5.30000000e+01 4.21746961e+02 2.60518059e+03]
#  [5.40000000e+01 4.12562826e+02 2.59432661e+03]
#  [5.50000000e+01 4.31766018e+02 2.60184091e+03]
#  [5.60000000e+01 4.34270782e+02 2.60017106e+03]
#  [5.70000000e+01 4.45959681e+02 2.60100598e+03]
#  [5.80000000e+01 4.41785074e+02 2.60434567e+03]
#  [5.90000000e+01 4.52639052e+02 2.60601551e+03]
#  [6.00000000e+01 4.59318423e+02 2.60518059e+03]
#  [6.10000000e+01 4.68502559e+02 2.61019012e+03]
#  [6.20000000e+01 4.72677166e+02 2.59349169e+03]
#  [6.30000000e+01 4.83531144e+02 2.59265677e+03]
#  [6.40000000e+01 4.77686694e+02 2.59516153e+03]
#  [6.50000000e+01 4.81026380e+02 2.59349169e+03]
#  [6.60000000e+01 4.80191458e+02 2.59683138e+03]
#  [6.70000000e+01 4.73512087e+02 2.60434567e+03]
#  [6.80000000e+01 4.67667637e+02 2.58931708e+03]
#  [6.90000000e+01 4.83531144e+02 2.58931708e+03]
#  [7.00000000e+01 4.80191458e+02 2.58347263e+03]
#  [7.10000000e+01 4.70172402e+02 2.58430756e+03]
#  [7.20000000e+01 4.71842244e+02 2.58263771e+03]
#  [7.30000000e+01 4.64327952e+02 2.58263771e+03]
#  [7.40000000e+01 4.60153345e+02 2.57345358e+03]
#  [7.40000000e+01 4.64327952e+02 2.56844405e+03]
#  [7.40000000e+01 4.61823188e+02 2.57428850e+03]]
# 3 [[0.00000000e+00 3.53406515e+03 1.54571901e+03]
#  [1.00000000e+00 3.53677422e+03 1.59109606e+03]
#  [2.00000000e+00 3.49749260e+03 1.57010070e+03]
#  [3.00000000e+00 3.49275171e+03 1.55858712e+03]
#  [4.00000000e+00 3.49071991e+03 1.55655532e+03]
#  [5.00000000e+00 3.48259267e+03 1.55181443e+03]
#  [6.00000000e+00 3.44195651e+03 1.54504174e+03]
#  [7.00000000e+00 3.43586108e+03 1.53149635e+03]
#  [8.00000000e+00 3.41622027e+03 1.52066004e+03]
#  [9.00000000e+00 3.41012485e+03 1.51185554e+03]
#  [1.00000000e+01 3.41080212e+03 1.51659642e+03]
#  [1.10000000e+01 3.41215665e+03 1.51524188e+03]
#  [1.20000000e+01 3.40538396e+03 1.52066004e+03]
#  [1.30000000e+01 3.40741577e+03 1.52404639e+03]
#  [1.40000000e+01 3.40064308e+03 1.51321007e+03]
#  [1.50000000e+01 3.39522492e+03 1.50034196e+03]
#  [1.60000000e+01 3.38303407e+03 1.50914646e+03]
#  [1.70000000e+01 3.37693865e+03 1.50101923e+03]
#  [1.80000000e+01 3.36068418e+03 1.48882838e+03]
#  [1.90000000e+01 3.36948868e+03 1.50237376e+03]
#  [2.00000000e+01 3.36677961e+03 1.51930550e+03]
#  [2.10000000e+01 3.34917060e+03 1.55249170e+03]
#  [2.20000000e+01 3.29634359e+03 1.56535982e+03]
#  [2.30000000e+01 3.30921171e+03 1.57077797e+03]
#  [2.40000000e+01 3.30582536e+03 1.56603709e+03]
#  [2.50000000e+01 3.34307518e+03 1.56061893e+03]
#  [2.60000000e+01 3.35594329e+03 1.56603709e+03]
#  [2.70000000e+01 3.30921171e+03 1.55858712e+03]
#  [2.80000000e+01 3.29431178e+03 1.57145524e+03]
#  [2.90000000e+01 3.34172064e+03 1.54978262e+03]
#  [3.00000000e+01 3.31666167e+03 1.54775081e+03]
#  [3.10000000e+01 3.34307518e+03 1.64866395e+03]
#  [3.20000000e+01 3.30447082e+03 1.50237376e+03]
#  [3.30000000e+01 3.28483001e+03 1.46986483e+03]
#  [3.40000000e+01 3.28686182e+03 1.48205568e+03]
#  [3.50000000e+01 3.30243901e+03 1.49492380e+03]
#  [3.60000000e+01 3.29160270e+03 1.47596026e+03]
#  [3.70000000e+01 3.30785717e+03 1.48950565e+03]
#  [3.80000000e+01 3.31869348e+03 1.51524188e+03]
#  [3.90000000e+01 3.27670277e+03 1.54571901e+03]
#  [4.00000000e+01 3.27534824e+03 1.53894631e+03]
#  [4.10000000e+01 3.28008912e+03 1.49898742e+03]
#  [4.20000000e+01 3.29227997e+03 1.47596026e+03]
#  [4.30000000e+01 3.27738004e+03 1.49831015e+03]
#  [4.40000000e+01 3.29905267e+03 1.49086018e+03]
#  [4.50000000e+01 3.30311628e+03 1.50237376e+03]
#  [4.60000000e+01 3.30514809e+03 1.50372830e+03]
#  [4.70000000e+01 3.30514809e+03 1.50711465e+03]
#  [4.80000000e+01 3.33223887e+03 1.54233266e+03]
#  [4.90000000e+01 3.34849333e+03 1.55045989e+03]
#  [5.00000000e+01 3.35187968e+03 1.52201458e+03]
#  [5.10000000e+01 3.36136145e+03 1.51591915e+03]
#  [5.20000000e+01 3.33901156e+03 1.50779192e+03]
#  [5.30000000e+01 3.39928854e+03 1.53759177e+03]
#  [5.40000000e+01 3.34172064e+03 1.50034196e+03]
#  [5.50000000e+01 3.31801621e+03 1.52675546e+03]
#  [5.60000000e+01 3.30243901e+03 1.51998277e+03]
#  [5.70000000e+01 3.31598440e+03 1.51117827e+03]
#  [5.80000000e+01 3.32411163e+03 1.52540092e+03]
#  [5.90000000e+01 3.30853444e+03 1.51388734e+03]
#  [6.00000000e+01 3.30447082e+03 1.51795096e+03]
#  [6.10000000e+01 3.29769813e+03 1.50237376e+03]
#  [6.20000000e+01 3.28957089e+03 1.49763288e+03]
#  [6.30000000e+01 3.29227997e+03 1.51253281e+03]
#  [6.50000000e+01 3.31124351e+03 1.53149635e+03]
#  [6.40000000e+01 3.32207982e+03 1.52066004e+03]
#  [6.60000000e+01 3.31530713e+03 1.49356926e+03]
#  [6.70000000e+01 3.31937075e+03 1.51862823e+03]
#  [6.80000000e+01 3.32207982e+03 1.51862823e+03]
#  [6.90000000e+01 3.32343436e+03 1.51862823e+03]
#  [7.00000000e+01 3.33156160e+03 1.52269185e+03]
#  [7.10000000e+01 3.33427067e+03 1.52201458e+03]
#  [7.20000000e+01 3.32207982e+03 1.52878727e+03]
#  [7.30000000e+01 3.32546617e+03 1.54233266e+03]
#  [7.40000000e+01 3.33088433e+03 1.52878727e+03]]
# 4 [[0.00000000e+00 2.88218451e+03 2.26609035e+03]
#  [1.00000000e+00 2.89556503e+03 2.28152941e+03]
#  [2.00000000e+00 2.87703816e+03 2.29182212e+03]
#  [3.00000000e+00 2.86365763e+03 2.29696848e+03]
#  [4.00000000e+00 2.83483805e+03 2.29696848e+03]
#  [5.00000000e+00 2.79984284e+03 2.26506108e+03]
#  [6.00000000e+00 2.80601846e+03 2.24653420e+03]
#  [7.00000000e+00 2.79572575e+03 2.27123670e+03]
#  [8.00000000e+00 2.79366721e+03 2.24653420e+03]
#  [9.00000000e+00 2.80190138e+03 2.22286097e+03]
#  [1.00000000e+01 2.79572575e+03 2.20742190e+03]
#  [1.10000000e+01 2.79366721e+03 2.21256826e+03]
#  [1.20000000e+01 2.79675502e+03 2.23418295e+03]
#  [1.30000000e+01 2.79057940e+03 2.21462680e+03]
#  [1.40000000e+01 2.78234523e+03 2.20948045e+03]
#  [1.50000000e+01 2.78337450e+03 2.19712920e+03]
#  [1.60000000e+01 2.78852086e+03 2.18580722e+03]
#  [1.70000000e+01 2.79366721e+03 2.18066086e+03]
#  [1.80000000e+01 2.78337450e+03 2.18271940e+03]
#  [1.90000000e+01 2.78852086e+03 2.16830961e+03]
#  [2.00000000e+01 2.79263794e+03 2.17654378e+03]
#  [2.10000000e+01 2.78646231e+03 2.18889503e+03]
#  [2.20000000e+01 2.78749159e+03 2.19301211e+03]
#  [2.30000000e+01 2.79263794e+03 2.18889503e+03]
#  [2.40000000e+01 2.79675502e+03 2.19095357e+03]
#  [2.50000000e+01 2.79675502e+03 2.19198284e+03]
#  [2.60000000e+01 2.78955013e+03 2.19712920e+03]
#  [2.70000000e+01 2.79469648e+03 2.19198284e+03]
#  [2.80000000e+01 2.80087211e+03 2.18889503e+03]
#  [2.90000000e+01 2.78337450e+03 2.18683649e+03]
#  [3.00000000e+01 2.78543304e+03 2.22800732e+03]
#  [3.10000000e+01 2.79469648e+03 2.20845118e+03]
#  [3.20000000e+01 2.80498919e+03 2.27535379e+03]
#  [3.30000000e+01 2.78852086e+03 2.27432452e+03]
#  [3.40000000e+01 2.76793544e+03 2.32887587e+03]
#  [3.50000000e+01 2.75970127e+03 2.31652462e+03]
#  [3.60000000e+01 2.78440377e+03 2.36284182e+03]
#  [3.70000000e+01 2.76484763e+03 2.32578806e+03]
#  [3.80000000e+01 2.77205252e+03 2.35049056e+03]
#  [3.90000000e+01 2.70206210e+03 2.42665661e+03]
#  [4.00000000e+01 2.71235481e+03 2.41636390e+03]
#  [4.10000000e+01 2.73911585e+03 2.38651505e+03]
#  [4.20000000e+01 2.73808658e+03 2.38239796e+03]
#  [4.30000000e+01 2.68456449e+03 2.52546662e+03]
#  [4.40000000e+01 2.70926699e+03 2.52649589e+03]
#  [4.50000000e+01 2.73705731e+03 2.49458849e+03]
#  [4.60000000e+01 2.72985241e+03 2.52340808e+03]
#  [4.70000000e+01 2.68456449e+03 2.55119840e+03]
#  [4.80000000e+01 2.66397907e+03 2.58207652e+03]
#  [4.90000000e+01 2.67015470e+03 2.58516434e+03]
#  [5.00000000e+01 2.65574491e+03 2.59031069e+03]
#  [5.10000000e+01 2.63104240e+03 2.74573060e+03]
#  [5.20000000e+01 2.64030584e+03 2.62942299e+03]
#  [5.30000000e+01 2.62898386e+03 2.66441820e+03]
#  [5.40000000e+01 2.61766188e+03 2.66441820e+03]
#  [5.50000000e+01 2.62589605e+03 2.65206695e+03]
#  [5.60000000e+01 2.63207168e+03 2.68397435e+03]
#  [5.70000000e+01 2.62589605e+03 2.66853528e+03]
#  [5.80000000e+01 2.62280824e+03 2.68809143e+03]
#  [5.90000000e+01 2.63515949e+03 2.64897913e+03]
#  [6.00000000e+01 2.63104240e+03 2.62736444e+03]
#  [6.10000000e+01 2.63618876e+03 2.61398392e+03]
#  [6.20000000e+01 2.64030584e+03 2.62221809e+03]
#  [6.30000000e+01 2.63104240e+03 2.61089611e+03]
#  [6.40000000e+01 2.64648147e+03 2.61089611e+03]
#  [6.50000000e+01 2.64030584e+03 2.60060340e+03]
#  [6.60000000e+01 2.64236438e+03 2.60060340e+03]
#  [6.70000000e+01 2.65265709e+03 2.60163267e+03]
#  [6.80000000e+01 2.64030584e+03 2.61192538e+03]
#  [6.90000000e+01 2.64956928e+03 2.61398392e+03]
#  [7.00000000e+01 2.65162782e+03 2.61089611e+03]]

# %%
df_list = []
for n, points in enumerate([points_1, points_2, points_3, points_4, points_5]):
    df = pd.DataFrame(points.data, columns = [f't_{n}', f'x_{n}', f'y_{n}'])
    df.sort_values(by = f't_{n}', axis=0, ignore_index=True, inplace=True)
    df_list.append(df)
    if n ==1:
        break
pd.concat(df_list)
# Out:
#     t_0          x_0          y_0   t_1         x_1          y_1
# 0   0.0  1567.809298  2736.460219   NaN         NaN          NaN
# 1   1.0  1562.391143  2754.069224   NaN         NaN          NaN
# 2   2.0  1571.872915  2747.296530   NaN         NaN          NaN
# 3   3.0  1577.291070  2765.582803   NaN         NaN          NaN
# 4   4.0  1430.323610  2926.095651   NaN         NaN          NaN
# ..  ...          ...          ...   ...         ...          ...
# 67  NaN          NaN          NaN  70.0  782.268397  3496.036819
# 68  NaN          NaN          NaN  71.0  773.004959  3513.534425
# 69  NaN          NaN          NaN  72.0  746.243914  3496.036819
# 70  NaN          NaN          NaN  73.0  764.770791  3506.329528
# 71  NaN          NaN          NaN  74.0  763.741520  3504.270986
#
# [121 rows x 6 columns]

# %%
df
# Out:
#      t_1         x_1          y_1
# 0    0.0  658.755885  3527.944218
# 1    0.0  644.346092  3550.588178
# 2    1.0  669.048595  3563.968700
# 3    2.0  669.048595  3566.027242
# 4    3.0  694.780368  3574.261410
# ..   ...         ...          ...
# 67  70.0  782.268397  3496.036819
# 68  71.0  773.004959  3513.534425
# 69  72.0  746.243914  3496.036819
# 70  73.0  764.770791  3506.329528
# 71  74.0  763.741520  3504.270986
#
# [72 rows x 3 columns]

# %%
df.sort_values(by = f't_{n}', axis=0, ignore_index=True, inplace=True)
# Out:
#      t_1         x_1          y_1
# 0    0.0  658.755885  3527.944218
# 1    0.0  644.346092  3550.588178
# 2    1.0  669.048595  3563.968700
# 3    2.0  669.048595  3566.027242
# 4    3.0  694.780368  3574.261410
# ..   ...         ...          ...
# 67  70.0  782.268397  3496.036819
# 68  71.0  773.004959  3513.534425
# 69  72.0  746.243914  3496.036819
# 70  73.0  764.770791  3506.329528
# 71  74.0  763.741520  3504.270986
#
# [72 rows x 3 columns]

# %%
df.set_index(f't_{n}', verify_integrity=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 df.set_index(f't_{n}', verify_integrity=True)
#
# File ~/miniconda3/envs/aero/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/aero/lib/python3.9/site-packages/pandas/core/frame.py:5559, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5557 if verify_integrity and not index.is_unique:
#    5558     duplicates = index[index.duplicated()].unique()
# -> 5559     raise ValueError(f"Index has duplicate keys: {duplicates}")
#    5561 # use set to handle duplicate column names gracefully in case of drop
#    5562 for c in set(to_remove):
#
# ValueError: Index has duplicate keys: Float64Index([0.0, 17.0], dtype='float64', name='t_1')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df)
# Out:
#      t_1         x_1          y_1
# 0    0.0  658.755885  3527.944218
# 1    0.0  644.346092  3550.588178
# 2    1.0  669.048595  3563.968700
# 3    2.0  669.048595  3566.027242
# 4    3.0  694.780368  3574.261410
# 5    4.0  644.346092  3607.198079
# 6    5.0  631.994841  3619.549331
# 7    6.0  599.058171  3634.988394
# 8    7.0  609.350881  3622.637143
# 9    8.0  638.170467  3625.724956
# 10   9.0  668.019324  3594.846828
# 11  10.0  634.053383  3619.549331
# 12  11.0  607.292339  3620.578601
# 13  12.0  671.107137  3614.402976
# 14  13.0  639.199738  3624.695685
# 15  14.0  691.692555  3587.641932
# 16  15.0  678.312033  3596.905370
# 17  17.0  646.404634  3637.046936
# 18  17.0  656.697344  3623.666414
# 19  18.0  636.111925  3639.105478
# 20  19.0  616.555777  3666.895793
# 21  20.0  610.380152  3655.573813
# 22  21.0  631.994841  3647.339646
# 23  22.0  650.521718  3639.105478
# 24  23.0  630.965570  3653.515271
# 25  24.0  630.965570  3656.603084
# 26  25.0  652.580260  3634.988394
# 27  26.0  655.668073  3618.520060
# 28  27.0  685.516930  3585.583390
# 29  28.0  752.419540  3538.236927
# 30  29.0  800.795274  3489.861193
# 31  30.0  781.239126  3505.300257
# 32  31.0  825.497776  3478.539213
# 33  32.0  776.092771  3475.451400
# 34  33.0  765.800062  3483.685568
# 35  34.0  759.624437  3483.685568
# 36  35.0  756.536624  3498.095361
# 37  36.0  766.829333  3500.153903
# 38  37.0  752.419540  3501.183174
# 39  38.0  759.624437  3511.475883
# 40  39.0  763.741520  3503.241715
# 41  40.0  780.209855  3491.919735
# 42  41.0  783.297668  3487.802651
# 43  42.0  786.385481  3493.978277
# 44  43.0  818.292880  3490.890464
# 45  44.0  822.409963  3502.212445
# 46  45.0  796.678190  3507.358799
# 47  46.0  789.473294  3531.032031
# 48  47.0  806.970899  3518.680779
# 49  48.0  828.585589  3482.656297
# 50  49.0  848.141737  3471.334317
# 51  50.0  855.346633  3467.217233
# 52  51.0  868.727155  3482.656297
# 53  52.0  834.761214  3468.246504
# 54  53.0  848.141737  3478.539213
# 55  54.0  840.936840  3487.802651
# 56  55.0  873.873510  3485.744110
# 57  56.0  823.439234  3501.183174
# 58  57.0  839.907569  3505.300257
# 59  58.0  810.058712  3510.446612
# 60  59.0  803.883087  3531.032031
# 61  60.0  804.912358  3501.183174
# 62  62.0  768.887875  3503.241715
# 63  66.0  779.180584  3492.949006
# 64  67.0  791.531835  3501.183174
# 65  68.0  782.268397  3495.007548
# 66  69.0  784.326939  3486.773381
# 67  70.0  782.268397  3496.036819
# 68  71.0  773.004959  3513.534425
# 69  72.0  746.243914  3496.036819
# 70  73.0  764.770791  3506.329528
# 71  74.0  763.741520  3504.270986

# %%
points_dict = {1:points_1.data, 2: points_2.data, 3: points_3.data, 4:points_4.data, 5:points_5.data}

# %% [markdown]
# saving out points dict to work at from home

# %%
import pickle

# %%
with open('points.pickle', 'wb') as handle:
    pickle.dump(points_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('points.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
b
# Out:
# {1: array([[0.00000000e+00, 1.56780930e+03, 2.73646022e+03],
#         [1.00000000e+00, 1.56239114e+03, 2.75406922e+03],
#         [2.00000000e+00, 1.57187291e+03, 2.74729653e+03],
#         [3.00000000e+00, 1.57729107e+03, 2.76558280e+03],
#         [4.00000000e+00, 1.43032361e+03, 2.92609565e+03],
#         [5.00000000e+00, 1.39781468e+03, 2.94370466e+03],
#         [6.00000000e+00, 1.38494656e+03, 2.96470001e+03],
#         [7.00000000e+00, 1.37343298e+03, 3.00533617e+03],
#         [8.00000000e+00, 1.43709630e+03, 2.90916392e+03],
#         [9.00000000e+00, 1.44725535e+03, 2.92203203e+03],
#         [1.00000000e+01, 1.47570066e+03, 2.89561853e+03],
#         [1.10000000e+01, 1.47908701e+03, 2.86717321e+03],
#         [1.20000000e+01, 1.47434612e+03, 2.88884583e+03],
#         [1.30000000e+01, 1.43912811e+03, 2.95183189e+03],
#         [1.40000000e+01, 1.41271461e+03, 2.95860458e+03],
#         [1.50000000e+01, 1.41745549e+03, 2.95250916e+03],
#         [1.60000000e+01, 1.43641903e+03, 2.92135477e+03],
#         [1.70000000e+01, 1.51972317e+03, 2.84482332e+03],
#         [1.80000000e+01, 1.50753232e+03, 2.88342768e+03],
#         [1.90000000e+01, 1.46554162e+03, 2.90103668e+03],
#         [2.00000000e+01, 1.48653697e+03, 2.89765034e+03],
#         [2.10000000e+01, 1.48044155e+03, 2.88613676e+03],
#         [2.20000000e+01, 1.48382789e+03, 2.87936406e+03],
#         [2.30000000e+01, 1.42490545e+03, 2.92135477e+03],
#         [2.40000000e+01, 1.46892797e+03, 2.89290945e+03],
#         [2.50000000e+01, 1.57119565e+03, 2.79335085e+03],
#         [2.60000000e+01, 1.66845069e+03, 2.76002642e+03],
#         [2.70000000e+01, 1.71382774e+03, 2.76747638e+03],
#         [2.80000000e+01, 1.69147785e+03, 2.72413114e+03],
#         [2.90000000e+01, 1.45918812e+03, 2.62662939e+03],
#         [3.00000000e+01, 1.36391959e+03, 2.56749719e+03],
#         [3.10000000e+01, 1.37459623e+03, 2.36710476e+03],
#         [3.20000000e+01, 1.37788135e+03, 2.33671738e+03],
#         [3.30000000e+01, 1.34667270e+03, 2.35314299e+03],
#         [3.40000000e+01, 1.36227702e+03, 2.36464092e+03],
#         [3.50000000e+01, 1.36227702e+03, 2.44759024e+03],
#         [3.60000000e+01, 1.37213239e+03, 2.39174317e+03],
#         [3.70000000e+01, 1.36391959e+03, 2.41556030e+03],
#         [3.80000000e+01, 1.33024709e+03, 2.32193433e+03],
#         [3.90000000e+01, 1.35488550e+03, 2.43855616e+03],
#         [4.00000000e+01, 1.35160038e+03, 2.43691360e+03],
#         [4.10000000e+01, 1.36227702e+03, 2.40241982e+03],
#         [4.20000000e+01, 1.35817062e+03, 2.38435165e+03],
#         [4.30000000e+01, 1.36802599e+03, 2.36135579e+03],
#         [4.40000000e+01, 1.37788135e+03, 2.40159854e+03],
#         [4.50000000e+01, 1.36720471e+03, 2.38599421e+03],
#         [4.60000000e+01, 1.40744745e+03, 2.40981134e+03],
#         [4.70000000e+01, 1.44358379e+03, 2.41884543e+03],
#         [4.80000000e+01, 1.43126458e+03, 2.47222866e+03]]),
#  2: array([[7.40000000e+01, 7.63741520e+02, 3.50427099e+03],
#         [7.30000000e+01, 7.64770791e+02, 3.50632953e+03],
#         [7.20000000e+01, 7.46243914e+02, 3.49603682e+03],
#         [7.10000000e+01, 7.73004959e+02, 3.51353442e+03],
#         [7.00000000e+01, 7.82268397e+02, 3.49603682e+03],
#         [6.90000000e+01, 7.84326939e+02, 3.48677338e+03],
#         [6.80000000e+01, 7.82268397e+02, 3.49500755e+03],
#         [6.70000000e+01, 7.91531835e+02, 3.50118317e+03],
#         [6.60000000e+01, 7.79180584e+02, 3.49294901e+03],
#         [6.20000000e+01, 7.68887875e+02, 3.50324172e+03],
#         [6.00000000e+01, 8.04912358e+02, 3.50118317e+03],
#         [5.90000000e+01, 8.03883087e+02, 3.53103203e+03],
#         [5.80000000e+01, 8.10058712e+02, 3.51044661e+03],
#         [5.70000000e+01, 8.39907569e+02, 3.50530026e+03],
#         [5.60000000e+01, 8.23439234e+02, 3.50118317e+03],
#         [5.50000000e+01, 8.73873510e+02, 3.48574411e+03],
#         [5.40000000e+01, 8.40936840e+02, 3.48780265e+03],
#         [5.30000000e+01, 8.48141737e+02, 3.47853921e+03],
#         [5.20000000e+01, 8.34761214e+02, 3.46824650e+03],
#         [5.10000000e+01, 8.68727155e+02, 3.48265630e+03],
#         [5.00000000e+01, 8.55346633e+02, 3.46721723e+03],
#         [4.90000000e+01, 8.48141737e+02, 3.47133432e+03],
#         [4.80000000e+01, 8.28585589e+02, 3.48265630e+03],
#         [4.70000000e+01, 8.06970899e+02, 3.51868078e+03],
#         [4.60000000e+01, 7.89473294e+02, 3.53103203e+03],
#         [4.50000000e+01, 7.96678190e+02, 3.50735880e+03],
#         [4.40000000e+01, 8.22409963e+02, 3.50221244e+03],
#         [4.30000000e+01, 8.18292880e+02, 3.49089046e+03],
#         [4.20000000e+01, 7.86385481e+02, 3.49397828e+03],
#         [4.10000000e+01, 7.83297668e+02, 3.48780265e+03],
#         [4.00000000e+01, 7.80209855e+02, 3.49191974e+03],
#         [3.90000000e+01, 7.63741520e+02, 3.50324172e+03],
#         [3.80000000e+01, 7.59624437e+02, 3.51147588e+03],
#         [3.70000000e+01, 7.52419540e+02, 3.50118317e+03],
#         [3.60000000e+01, 7.66829333e+02, 3.50015390e+03],
#         [3.50000000e+01, 7.56536624e+02, 3.49809536e+03],
#         [3.40000000e+01, 7.59624437e+02, 3.48368557e+03],
#         [3.30000000e+01, 7.65800062e+02, 3.48368557e+03],
#         [3.20000000e+01, 7.76092771e+02, 3.47545140e+03],
#         [3.10000000e+01, 8.25497776e+02, 3.47853921e+03],
#         [3.00000000e+01, 7.81239126e+02, 3.50530026e+03],
#         [2.90000000e+01, 8.00795274e+02, 3.48986119e+03],
#         [2.80000000e+01, 7.52419540e+02, 3.53823693e+03],
#         [2.70000000e+01, 6.85516930e+02, 3.58558339e+03],
#         [2.60000000e+01, 6.55668073e+02, 3.61852006e+03],
#         [2.50000000e+01, 6.52580260e+02, 3.63498839e+03],
#         [2.40000000e+01, 6.30965570e+02, 3.65660308e+03],
#         [2.30000000e+01, 6.30965570e+02, 3.65351527e+03],
#         [2.20000000e+01, 6.50521718e+02, 3.63910548e+03],
#         [2.10000000e+01, 6.31994841e+02, 3.64733965e+03],
#         [2.00000000e+01, 6.10380152e+02, 3.65557381e+03],
#         [1.90000000e+01, 6.16555777e+02, 3.66689579e+03],
#         [1.80000000e+01, 6.36111925e+02, 3.63910548e+03],
#         [1.70000000e+01, 6.46404634e+02, 3.63704694e+03],
#         [1.70000000e+01, 6.56697344e+02, 3.62366641e+03],
#         [1.50000000e+01, 6.78312033e+02, 3.59690537e+03],
#         [1.40000000e+01, 6.91692555e+02, 3.58764193e+03],
#         [1.30000000e+01, 6.39199738e+02, 3.62469569e+03],
#         [1.20000000e+01, 6.71107137e+02, 3.61440298e+03],
#         [1.10000000e+01, 6.07292339e+02, 3.62057860e+03],
#         [1.00000000e+01, 6.34053383e+02, 3.61954933e+03],
#         [9.00000000e+00, 6.68019324e+02, 3.59484683e+03],
#         [8.00000000e+00, 6.38170467e+02, 3.62572496e+03],
#         [7.00000000e+00, 6.09350881e+02, 3.62263714e+03],
#         [6.00000000e+00, 5.99058171e+02, 3.63498839e+03],
#         [5.00000000e+00, 6.31994841e+02, 3.61954933e+03],
#         [4.00000000e+00, 6.44346092e+02, 3.60719808e+03],
#         [3.00000000e+00, 6.94780368e+02, 3.57426141e+03],
#         [2.00000000e+00, 6.69048595e+02, 3.56602724e+03],
#         [1.00000000e+00, 6.69048595e+02, 3.56396870e+03],
#         [0.00000000e+00, 6.44346092e+02, 3.55058818e+03],
#         [0.00000000e+00, 6.58755885e+02, 3.52794422e+03]]),
#  3: array([[0.00000000e+00, 4.91045436e+02, 2.40145977e+03],
#         [1.00000000e+00, 5.06908943e+02, 2.48411699e+03],
#         [2.00000000e+00, 4.81026380e+02, 2.48829160e+03],
#         [3.00000000e+00, 4.55978738e+02, 2.48161223e+03],
#         [4.00000000e+00, 4.35105703e+02, 2.48161223e+03],
#         [5.00000000e+00, 4.45959681e+02, 2.46908840e+03],
#         [6.00000000e+00, 4.70172402e+02, 2.51166940e+03],
#         [7.00000000e+00, 4.68502559e+02, 2.49914557e+03],
#         [8.00000000e+00, 4.89375594e+02, 2.51166940e+03],
#         [9.00000000e+00, 4.70172402e+02, 2.52836782e+03],
#         [1.00000000e+01, 4.56813659e+02, 2.51584400e+03],
#         [1.10000000e+01, 4.46794603e+02, 2.51834877e+03],
#         [1.20000000e+01, 4.53473974e+02, 2.51166940e+03],
#         [1.30000000e+01, 4.60988266e+02, 2.51834877e+03],
#         [1.40000000e+01, 4.70172402e+02, 2.52920274e+03],
#         [1.50000000e+01, 4.71842244e+02, 2.53087259e+03],
#         [1.70000000e+01, 4.84366065e+02, 2.54172657e+03],
#         [1.50000000e+01, 4.82696222e+02, 2.53838688e+03],
#         [1.70000000e+01, 4.68502559e+02, 2.53337735e+03],
#         [1.80000000e+01, 4.71842244e+02, 2.54840594e+03],
#         [1.90000000e+01, 4.65997795e+02, 2.54339641e+03],
#         [2.00000000e+01, 4.89375594e+02, 2.54339641e+03],
#         [2.10000000e+01, 5.01899414e+02, 2.54172657e+03],
#         [2.20000000e+01, 5.19432764e+02, 2.55007578e+03],
#         [2.30000000e+01, 4.96054965e+02, 2.54506625e+03],
#         [2.40000000e+01, 4.90210515e+02, 2.54506625e+03],
#         [2.50000000e+01, 4.69337480e+02, 2.54590117e+03],
#         [2.60000000e+01, 4.61823188e+02, 2.54005672e+03],
#         [2.70000000e+01, 4.73512087e+02, 2.53671704e+03],
#         [2.80000000e+01, 4.78521615e+02, 2.53337735e+03],
#         [2.90000000e+01, 4.84366065e+02, 2.52586306e+03],
#         [3.00000000e+01, 4.99394650e+02, 2.52001861e+03],
#         [3.10000000e+01, 4.73512087e+02, 2.51333924e+03],
#         [3.20000000e+01, 4.56813659e+02, 2.53838688e+03],
#         [3.30000000e+01, 4.44289838e+02, 2.52419322e+03],
#         [3.40000000e+01, 4.36775546e+02, 2.54339641e+03],
#         [3.50000000e+01, 4.35940625e+02, 2.56510436e+03],
#         [3.60000000e+01, 4.55978738e+02, 2.56092976e+03],
#         [3.70000000e+01, 4.48464445e+02, 2.56927897e+03],
#         [3.80000000e+01, 4.60153345e+02, 2.57261866e+03],
#         [3.90000000e+01, 4.46794603e+02, 2.59265677e+03],
#         [4.00000000e+01, 4.40950153e+02, 2.58096787e+03],
#         [4.10000000e+01, 4.61823188e+02, 2.61937425e+03],
#         [4.20000000e+01, 4.35940625e+02, 2.59015201e+03],
#         [4.30000000e+01, 4.29261253e+02, 2.59599646e+03],
#         [4.40000000e+01, 4.29261253e+02, 2.59599646e+03],
#         [4.50000000e+01, 4.26756489e+02, 2.59182185e+03],
#         [4.60000000e+01, 4.18407275e+02, 2.59015201e+03],
#         [4.70000000e+01, 4.31766018e+02, 2.59015201e+03],
#         [4.80000000e+01, 4.17572354e+02, 2.59182185e+03],
#         [4.90000000e+01, 4.07553297e+02, 2.58764724e+03],
#         [5.00000000e+01, 4.11727904e+02, 2.58931708e+03],
#         [5.10000000e+01, 4.14232668e+02, 2.59265677e+03],
#         [5.20000000e+01, 4.25086646e+02, 2.60434567e+03],
#         [5.30000000e+01, 4.21746961e+02, 2.60518059e+03],
#         [5.40000000e+01, 4.12562826e+02, 2.59432661e+03],
#         [5.50000000e+01, 4.31766018e+02, 2.60184091e+03],
#         [5.60000000e+01, 4.34270782e+02, 2.60017106e+03],
#         [5.70000000e+01, 4.45959681e+02, 2.60100598e+03],
#         [5.80000000e+01, 4.41785074e+02, 2.60434567e+03],
#         [5.90000000e+01, 4.52639052e+02, 2.60601551e+03],
#         [6.00000000e+01, 4.59318423e+02, 2.60518059e+03],
#         [6.10000000e+01, 4.68502559e+02, 2.61019012e+03],
#         [6.20000000e+01, 4.72677166e+02, 2.59349169e+03],
#         [6.30000000e+01, 4.83531144e+02, 2.59265677e+03],
#         [6.40000000e+01, 4.77686694e+02, 2.59516153e+03],
#         [6.50000000e+01, 4.81026380e+02, 2.59349169e+03],
#         [6.60000000e+01, 4.80191458e+02, 2.59683138e+03],
#         [6.70000000e+01, 4.73512087e+02, 2.60434567e+03],
#         [6.80000000e+01, 4.67667637e+02, 2.58931708e+03],
#         [6.90000000e+01, 4.83531144e+02, 2.58931708e+03],
#         [7.00000000e+01, 4.80191458e+02, 2.58347263e+03],
#         [7.10000000e+01, 4.70172402e+02, 2.58430756e+03],
#         [7.20000000e+01, 4.71842244e+02, 2.58263771e+03],
#         [7.30000000e+01, 4.64327952e+02, 2.58263771e+03],
#         [7.40000000e+01, 4.60153345e+02, 2.57345358e+03],
#         [7.40000000e+01, 4.64327952e+02, 2.56844405e+03],
#         [7.40000000e+01, 4.61823188e+02, 2.57428850e+03]]),
#  4: array([[0.00000000e+00, 3.53406515e+03, 1.54571901e+03],
#         [1.00000000e+00, 3.53677422e+03, 1.59109606e+03],
#         [2.00000000e+00, 3.49749260e+03, 1.57010070e+03],
#         [3.00000000e+00, 3.49275171e+03, 1.55858712e+03],
#         [4.00000000e+00, 3.49071991e+03, 1.55655532e+03],
#         [5.00000000e+00, 3.48259267e+03, 1.55181443e+03],
#         [6.00000000e+00, 3.44195651e+03, 1.54504174e+03],
#         [7.00000000e+00, 3.43586108e+03, 1.53149635e+03],
#         [8.00000000e+00, 3.41622027e+03, 1.52066004e+03],
#         [9.00000000e+00, 3.41012485e+03, 1.51185554e+03],
#         [1.00000000e+01, 3.41080212e+03, 1.51659642e+03],
#         [1.10000000e+01, 3.41215665e+03, 1.51524188e+03],
#         [1.20000000e+01, 3.40538396e+03, 1.52066004e+03],
#         [1.30000000e+01, 3.40741577e+03, 1.52404639e+03],
#         [1.40000000e+01, 3.40064308e+03, 1.51321007e+03],
#         [1.50000000e+01, 3.39522492e+03, 1.50034196e+03],
#         [1.60000000e+01, 3.38303407e+03, 1.50914646e+03],
#         [1.70000000e+01, 3.37693865e+03, 1.50101923e+03],
#         [1.80000000e+01, 3.36068418e+03, 1.48882838e+03],
#         [1.90000000e+01, 3.36948868e+03, 1.50237376e+03],
#         [2.00000000e+01, 3.36677961e+03, 1.51930550e+03],
#         [2.10000000e+01, 3.34917060e+03, 1.55249170e+03],
#         [2.20000000e+01, 3.29634359e+03, 1.56535982e+03],
#         [2.30000000e+01, 3.30921171e+03, 1.57077797e+03],
#         [2.40000000e+01, 3.30582536e+03, 1.56603709e+03],
#         [2.50000000e+01, 3.34307518e+03, 1.56061893e+03],
#         [2.60000000e+01, 3.35594329e+03, 1.56603709e+03],
#         [2.70000000e+01, 3.30921171e+03, 1.55858712e+03],
#         [2.80000000e+01, 3.29431178e+03, 1.57145524e+03],
#         [2.90000000e+01, 3.34172064e+03, 1.54978262e+03],
#         [3.00000000e+01, 3.31666167e+03, 1.54775081e+03],
#         [3.10000000e+01, 3.34307518e+03, 1.64866395e+03],
#         [3.20000000e+01, 3.30447082e+03, 1.50237376e+03],
#         [3.30000000e+01, 3.28483001e+03, 1.46986483e+03],
#         [3.40000000e+01, 3.28686182e+03, 1.48205568e+03],
#         [3.50000000e+01, 3.30243901e+03, 1.49492380e+03],
#         [3.60000000e+01, 3.29160270e+03, 1.47596026e+03],
#         [3.70000000e+01, 3.30785717e+03, 1.48950565e+03],
#         [3.80000000e+01, 3.31869348e+03, 1.51524188e+03],
#         [3.90000000e+01, 3.27670277e+03, 1.54571901e+03],
#         [4.00000000e+01, 3.27534824e+03, 1.53894631e+03],
#         [4.10000000e+01, 3.28008912e+03, 1.49898742e+03],
#         [4.20000000e+01, 3.29227997e+03, 1.47596026e+03],
#         [4.30000000e+01, 3.27738004e+03, 1.49831015e+03],
#         [4.40000000e+01, 3.29905267e+03, 1.49086018e+03],
#         [4.50000000e+01, 3.30311628e+03, 1.50237376e+03],
#         [4.60000000e+01, 3.30514809e+03, 1.50372830e+03],
#         [4.70000000e+01, 3.30514809e+03, 1.50711465e+03],
#         [4.80000000e+01, 3.33223887e+03, 1.54233266e+03],
#         [4.90000000e+01, 3.34849333e+03, 1.55045989e+03],
#         [5.00000000e+01, 3.35187968e+03, 1.52201458e+03],
#         [5.10000000e+01, 3.36136145e+03, 1.51591915e+03],
#         [5.20000000e+01, 3.33901156e+03, 1.50779192e+03],
#         [5.30000000e+01, 3.39928854e+03, 1.53759177e+03],
#         [5.40000000e+01, 3.34172064e+03, 1.50034196e+03],
#         [5.50000000e+01, 3.31801621e+03, 1.52675546e+03],
#         [5.60000000e+01, 3.30243901e+03, 1.51998277e+03],
#         [5.70000000e+01, 3.31598440e+03, 1.51117827e+03],
#         [5.80000000e+01, 3.32411163e+03, 1.52540092e+03],
#         [5.90000000e+01, 3.30853444e+03, 1.51388734e+03],
#         [6.00000000e+01, 3.30447082e+03, 1.51795096e+03],
#         [6.10000000e+01, 3.29769813e+03, 1.50237376e+03],
#         [6.20000000e+01, 3.28957089e+03, 1.49763288e+03],
#         [6.30000000e+01, 3.29227997e+03, 1.51253281e+03],
#         [6.50000000e+01, 3.31124351e+03, 1.53149635e+03],
#         [6.40000000e+01, 3.32207982e+03, 1.52066004e+03],
#         [6.60000000e+01, 3.31530713e+03, 1.49356926e+03],
#         [6.70000000e+01, 3.31937075e+03, 1.51862823e+03],
#         [6.80000000e+01, 3.32207982e+03, 1.51862823e+03],
#         [6.90000000e+01, 3.32343436e+03, 1.51862823e+03],
#         [7.00000000e+01, 3.33156160e+03, 1.52269185e+03],
#         [7.10000000e+01, 3.33427067e+03, 1.52201458e+03],
#         [7.20000000e+01, 3.32207982e+03, 1.52878727e+03],
#         [7.30000000e+01, 3.32546617e+03, 1.54233266e+03],
#         [7.40000000e+01, 3.33088433e+03, 1.52878727e+03]]),
#  5: array([[0.00000000e+00, 2.88218451e+03, 2.26609035e+03],
#         [1.00000000e+00, 2.89556503e+03, 2.28152941e+03],
#         [2.00000000e+00, 2.87703816e+03, 2.29182212e+03],
#         [3.00000000e+00, 2.86365763e+03, 2.29696848e+03],
#         [4.00000000e+00, 2.83483805e+03, 2.29696848e+03],
#         [5.00000000e+00, 2.79984284e+03, 2.26506108e+03],
#         [6.00000000e+00, 2.80601846e+03, 2.24653420e+03],
#         [7.00000000e+00, 2.79572575e+03, 2.27123670e+03],
#         [8.00000000e+00, 2.79366721e+03, 2.24653420e+03],
#         [9.00000000e+00, 2.80190138e+03, 2.22286097e+03],
#         [1.00000000e+01, 2.79572575e+03, 2.20742190e+03],
#         [1.10000000e+01, 2.79366721e+03, 2.21256826e+03],
#         [1.20000000e+01, 2.79675502e+03, 2.23418295e+03],
#         [1.30000000e+01, 2.79057940e+03, 2.21462680e+03],
#         [1.40000000e+01, 2.78234523e+03, 2.20948045e+03],
#         [1.50000000e+01, 2.78337450e+03, 2.19712920e+03],
#         [1.60000000e+01, 2.78852086e+03, 2.18580722e+03],
#         [1.70000000e+01, 2.79366721e+03, 2.18066086e+03],
#         [1.80000000e+01, 2.78337450e+03, 2.18271940e+03],
#         [1.90000000e+01, 2.78852086e+03, 2.16830961e+03],
#         [2.00000000e+01, 2.79263794e+03, 2.17654378e+03],
#         [2.10000000e+01, 2.78646231e+03, 2.18889503e+03],
#         [2.20000000e+01, 2.78749159e+03, 2.19301211e+03],
#         [2.30000000e+01, 2.79263794e+03, 2.18889503e+03],
#         [2.40000000e+01, 2.79675502e+03, 2.19095357e+03],
#         [2.50000000e+01, 2.79675502e+03, 2.19198284e+03],
#         [2.60000000e+01, 2.78955013e+03, 2.19712920e+03],
#         [2.70000000e+01, 2.79469648e+03, 2.19198284e+03],
#         [2.80000000e+01, 2.80087211e+03, 2.18889503e+03],
#         [2.90000000e+01, 2.78337450e+03, 2.18683649e+03],
#         [3.00000000e+01, 2.78543304e+03, 2.22800732e+03],
#         [3.10000000e+01, 2.79469648e+03, 2.20845118e+03],
#         [3.20000000e+01, 2.80498919e+03, 2.27535379e+03],
#         [3.30000000e+01, 2.78852086e+03, 2.27432452e+03],
#         [3.40000000e+01, 2.76793544e+03, 2.32887587e+03],
#         [3.50000000e+01, 2.75970127e+03, 2.31652462e+03],
#         [3.60000000e+01, 2.78440377e+03, 2.36284182e+03],
#         [3.70000000e+01, 2.76484763e+03, 2.32578806e+03],
#         [3.80000000e+01, 2.77205252e+03, 2.35049056e+03],
#         [3.90000000e+01, 2.70206210e+03, 2.42665661e+03],
#         [4.00000000e+01, 2.71235481e+03, 2.41636390e+03],
#         [4.10000000e+01, 2.73911585e+03, 2.38651505e+03],
#         [4.20000000e+01, 2.73808658e+03, 2.38239796e+03],
#         [4.30000000e+01, 2.68456449e+03, 2.52546662e+03],
#         [4.40000000e+01, 2.70926699e+03, 2.52649589e+03],
#         [4.50000000e+01, 2.73705731e+03, 2.49458849e+03],
#         [4.60000000e+01, 2.72985241e+03, 2.52340808e+03],
#         [4.70000000e+01, 2.68456449e+03, 2.55119840e+03],
#         [4.80000000e+01, 2.66397907e+03, 2.58207652e+03],
#         [4.90000000e+01, 2.67015470e+03, 2.58516434e+03],
#         [5.00000000e+01, 2.65574491e+03, 2.59031069e+03],
#         [5.10000000e+01, 2.63104240e+03, 2.74573060e+03],
#         [5.20000000e+01, 2.64030584e+03, 2.62942299e+03],
#         [5.30000000e+01, 2.62898386e+03, 2.66441820e+03],
#         [5.40000000e+01, 2.61766188e+03, 2.66441820e+03],
#         [5.50000000e+01, 2.62589605e+03, 2.65206695e+03],
#         [5.60000000e+01, 2.63207168e+03, 2.68397435e+03],
#         [5.70000000e+01, 2.62589605e+03, 2.66853528e+03],
#         [5.80000000e+01, 2.62280824e+03, 2.68809143e+03],
#         [5.90000000e+01, 2.63515949e+03, 2.64897913e+03],
#         [6.00000000e+01, 2.63104240e+03, 2.62736444e+03],
#         [6.10000000e+01, 2.63618876e+03, 2.61398392e+03],
#         [6.20000000e+01, 2.64030584e+03, 2.62221809e+03],
#         [6.30000000e+01, 2.63104240e+03, 2.61089611e+03],
#         [6.40000000e+01, 2.64648147e+03, 2.61089611e+03],
#         [6.50000000e+01, 2.64030584e+03, 2.60060340e+03],
#         [6.60000000e+01, 2.64236438e+03, 2.60060340e+03],
#         [6.70000000e+01, 2.65265709e+03, 2.60163267e+03],
#         [6.80000000e+01, 2.64030584e+03, 2.61192538e+03],
#         [6.90000000e+01, 2.64956928e+03, 2.61398392e+03],
#         [7.00000000e+01, 2.65162782e+03, 2.61089611e+03]])}

# %% [markdown]
# ### Just checking it does indeed work on instance segmentation

# %%
from skimage.morphology import label

# %%
# %%time 
instance_segmentation =[]
for frame in tqdm(segmentation):
    instance_segmentation.append(label(frame))
instance_segmentation = da.stack(instance_segmentation, axis = 0)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# CPU times: user 12.5 s, sys: 804 ms, total: 13.3 s
# Wall time: 13.2 s

# %%
viewer = napari.Viewer()
viewer.add_labels(instance_segmentation)
# Out:
# /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/napari_tools_menu/__init__.py:179: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# <Labels layer 'instance_segmentation' at 0x7fd03c45c4f0>
# [INFO][2022/08/09 04:34:32 pm] Loading configuration file: /home/dayn/.cache/btrack-examples/examples/cell_config.json
# [INFO][2022/08/09 04:34:36 pm] Loaded btrack: /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/btrack/libs/libtracker.so
# [INFO][2022/08/09 04:34:36 pm] btrack (v0.4.5) library imported
# [INFO][2022/08/09 04:34:36 pm] Starting BayesianTracker session
# [INFO][2022/08/09 04:34:36 pm] Localizing objects from segmentation...
# [INFO][2022/08/09 04:34:59 pm] Objects are of type: <class 'dict'>
# [INFO][2022/08/09 04:34:59 pm] ...Found 52890 objects in 500 frames.
# [INFO][2022/08/09 04:34:59 pm] Objects are of type: <class 'list'>
# [INFO][2022/08/09 04:35:00 pm] Starting tracking...
# [INFO][2022/08/09 04:35:00 pm] Tracking objects in frames 0 to 99 (of 500)...
# [INFO][2022/08/09 04:35:00 pm]  - Timing (Bayesian updates: 1.27ms, Linking: 0.26ms)
# [INFO][2022/08/09 04:35:00 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2022/08/09 04:35:00 pm]  - Stats (Active: 78, Lost: 123, Conflicts resolved: 158)
# [INFO][2022/08/09 04:35:00 pm] Tracking objects in frames 100 to 199 (of 500)...
# [INFO][2022/08/09 04:35:00 pm]  - Timing (Bayesian updates: 1.37ms, Linking: 0.29ms)
# [INFO][2022/08/09 04:35:00 pm]  - Probabilities (Link: 1.00000, Lost: 0.99997)
# [INFO][2022/08/09 04:35:00 pm]  - Stats (Active: 82, Lost: 168, Conflicts resolved: 245)
# [INFO][2022/08/09 04:35:00 pm] Tracking objects in frames 200 to 299 (of 500)...
# [INFO][2022/08/09 04:35:00 pm]  - Timing (Bayesian updates: 2.68ms, Linking: 0.38ms)
# [INFO][2022/08/09 04:35:00 pm]  - Probabilities (Link: 1.00000, Lost: 0.99998)
# [INFO][2022/08/09 04:35:00 pm]  - Stats (Active: 114, Lost: 229, Conflicts resolved: 377)
# [INFO][2022/08/09 04:35:00 pm] Tracking objects in frames 300 to 399 (of 500)...
# [INFO][2022/08/09 04:35:01 pm]  - Timing (Bayesian updates: 4.52ms, Linking: 0.50ms)
# [INFO][2022/08/09 04:35:01 pm]  - Probabilities (Link: 1.00000, Lost: 0.98716)
# [INFO][2022/08/09 04:35:01 pm]  - Stats (Active: 141, Lost: 413, Conflicts resolved: 613)
# [INFO][2022/08/09 04:35:01 pm] Tracking objects in frames 400 to 499 (of 500)...
# [INFO][2022/08/09 04:35:01 pm]  - Timing (Bayesian updates: 8.16ms, Linking: 0.71ms)
# [INFO][2022/08/09 04:35:01 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2022/08/09 04:35:01 pm] SUCCESS.
# [INFO][2022/08/09 04:35:01 pm]  - Found 408 tracks in 500 frames (in 0.0s)
# [INFO][2022/08/09 04:35:01 pm]  - Inserted 189 dummy objects to fill tracking gaps
# [INFO][2022/08/09 04:35:01 pm] Loading hypothesis model: particle_hypothesis
# [INFO][2022/08/09 04:35:01 pm] Calculating hypotheses (relax: True)...
# [INFO][2022/08/09 04:35:01 pm] Setting up constraints matrix for global optimisation...
# [INFO][2022/08/09 04:35:01 pm] Using GLPK options: {'tm_lim': 60000}...
# [INFO][2022/08/09 04:35:01 pm] Optimizing...
# [INFO][2022/08/09 04:35:01 pm] Optimization complete. (Solution: optimal)
# [INFO][2022/08/09 04:35:01 pm]  - Fates.FALSE_POSITIVE: 40 (of 408)
# [INFO][2022/08/09 04:35:01 pm]  - Fates.LINK: 55 (of 195)
# [INFO][2022/08/09 04:35:01 pm]  - Fates.DIVIDE: 60 (of 67)
# [INFO][2022/08/09 04:35:01 pm]  - Fates.INITIALIZE_BORDER: 48 (of 55)
# [INFO][2022/08/09 04:35:01 pm]  - Fates.INITIALIZE_FRONT: 70 (of 73)
# [INFO][2022/08/09 04:35:01 pm]  - Fates.INITIALIZE_LAZY: 75 (of 280)
# [INFO][2022/08/09 04:35:01 pm]  - Fates.TERMINATE_BORDER: 44 (of 51)
# [INFO][2022/08/09 04:35:01 pm]  - Fates.TERMINATE_BACK: 184 (of 187)
# [INFO][2022/08/09 04:35:01 pm]  - Fates.TERMINATE_LAZY: 25 (of 170)
# [INFO][2022/08/09 04:35:01 pm]  - TOTAL: 1486 hypotheses
# [INFO][2022/08/09 04:35:02 pm] Completed optimization with 353 tracks
# GLPK Integer Optimizer 5.0
# 1632 rows, 1486 columns, 2223 non-zeros
# 1486 integer variables, all of which are binary
# Preprocessing...
# 816 rows, 1486 columns, 2223 non-zeros
# 1486 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 816
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 816 rows, 1486 columns, 2223 non-zeros
# *     0: obj =   3.099981988e+03 inf =   0.000e+00 (307)
# *   243: obj =   9.824504253e+02 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   243: mip =     not found yet >=              -inf        (1; 0)
# +   243: >>>>>   9.824504253e+02 >=   9.824504253e+02   0.0% (1; 0)
# +   243: mip =   9.824504253e+02 >=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# [INFO][2022/08/09 04:35:02 pm] Ending BayesianTracker session

# %% [markdown]
# #### Also test simulated reduced frame rate test set

# %%
masks = masks
