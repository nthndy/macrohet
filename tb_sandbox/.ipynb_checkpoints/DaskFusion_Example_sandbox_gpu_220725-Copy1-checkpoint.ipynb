# %%
import time
from functools import partial
from pathlib import Path
from zipfile import ZipFile

import dask.array as da
from dask.array.core import normalize_chunks
import numpy as np
from shapely.geometry import GeometryCollection, Point
from skimage.transform import AffineTransform

from fuse.fuse import fuse_func
from utils.download_sample import download_from_dropbox
from utils.metadata import extract_coordinates, normalize_coords_to_pixel
from utils.imutils import crop_black_border, load_image, transpose, remove_background
from utils.shapely_and_napari_utils import get_transformed_array_corners, numpy_shape_to_shapely
from utils.chunks import get_chunk_coordinates, get_rect_from_chunk_boundary, find_chunk_tile_intersections

# %%
import pandas as pd
from tqdm.auto import tqdm
import re 
import os
from natsort import natsorted
import enum
import napari
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading own functions to sort files and extract metadata

# %%
@enum.unique
class Channels(enum.Enum):
    BRIGHTFIELD = 0
    GFP = 1
    RFP = 2
    IRFP = 3
    PHASE = 4
    WEIGHTS = 50
    MASK_IRFP = 96
    MASK_RFP = 97
    MASK_GFP = 98
    MASK = 99
    
def parse_filename(filename: os.PathLike) -> dict:
    """Parse an OctopusLite filename and retreive metadata from the file.

    Parameters
    ----------
    filename : PathLike
        The full path to a file to parse.

    Returns
    -------
    metadata : dict
        A dictionary containing the parsed metadata.
    """
    
    OCTOPUSLITE_FILEPATTERN =(
        "r(?P<row>[0-9]+)c(?P<column>[0-9]+)f(?P<fov>[0-9]+)p(?P<plane>[0-9]+)-ch(?P<channel>[0-9]+)"
        "sk(?P<time>[0-9]+)fk(?P<fk>[0-9]+)fl(?P<fl>[0-9]+)"
        )
    
    pth, filename = os.path.split(filename)
    params = re.match(OCTOPUSLITE_FILEPATTERN, filename)

    metadata = {
        "filename": filename,
        "channel": Channels(int(params.group("channel"))),
        "time": params.group("time"),
        "row": params.group("row"), 
        "column": params.group("column"), 
        "fov": params.group("fov"), 
        "plane": params.group("plane"), 
        "time": params.group("time"), 
        "fk": params.group("fk"), 
        "fl": params.group("fl")

    }

    return metadata

# %% [markdown]
# # Define parameters of mosaic compilation

# %%
### array that shows the location of each fov in the scan pattern
fov_scan_pattern = np.array(([2,3,4],
                             [7,6,5],
                             [8,1,9],))
fov_scan_pattern
# Out:
# array([[2, 3, 4],
#        [7, 6, 5],
#        [8, 1, 9]])

# %%
overlap = 0.1
chunk_size = (1080,1080)

# %%
image_dir = Path("/mnt/DATA/sandbox/pierre_live_cell_data/outputs/Replication_IPSDM_GFP/Images/")

# %%
relevant_channels = set([parse_filename(fn)['channel'] for fn in os.listdir(image_dir)])

# %%
import cupy as cp

# %%
cp.asarray
# Out:
# <function cupy._creation.from_data.asarray(a, dtype=None, order=None)>

# %%
#iterate over channels
for ch in tqdm(Channels):#Channels:
    if ch in relevant_channels:
        print('Starting channel', ch.name)
        ### define empty z stack
        da_zt_stack = []
        ### iterate over planes 
        for p in range(1,4):
            ### define empty time series stack
            da_t_stack = []
            ### iterate over frames
            for t in (range(1,76)):
                ### get all files at that time point
                files = list(Path("/mnt/DATA/sandbox/pierre_live_cell_data/outputs/Replication_IPSDM_GFP/Images/").glob(f"r03c03f*p0{p}-ch{ch.value}sk{t}fk*"))
                ### sort using the frame
                files.sort(key=lambda f: int(parse_filename(f)["time"]))
                ### extract tile coordinates from fn 'f' (ie. fov number)
                coords = pd.DataFrame()
                for fn in files:
                    entry = pd.DataFrame([parse_filename(fn)])
                    coords = pd.concat([coords, entry], ignore_index=True)
                ## lazy hack to make the raster scan like the provided fov_scan_pattern
                for i, row in coords.iterrows():
                    (X, Y) = tuple(map(int, np.where(fov_scan_pattern == int(row['fov']))))
                    coords.at[i, 'X'], coords.at[i, 'Y'] = X, Y
                ### lazy hack to register the row/col number as x/y location shifted by the amount of pixels in each image
                coords['um/px'] = 1/(2160*(1-overlap))
                ### turn coords into a np array of transformation amount using the um/px ratio
                normalized_coords = normalize_coords_to_pixel(coords).to_numpy()
                ### apply transforms if required -- could this be a background removal???
                input_transforms = None#[remove_background] #None #[crop_black_border, ]#transpose]
                ### define a function to load a test image and get tile shape from it
                _load_image = partial(load_image, transforms=input_transforms)
                tile_shape=_load_image(str(files[0])).shape
                ### apply the transformation to each tile to correctly mosaic them
                transforms = [AffineTransform(translation=stage_coord).params for stage_coord in normalized_coords]
                tiles = [get_transformed_array_corners(tile_shape, transform) for transform in transforms]
                ### define the bounding boxes of the tiles and overall FOV to determine the dask output shape
                all_bboxes = np.vstack(tiles)
                all_min = all_bboxes.min(axis=0)
                all_max = all_bboxes.max(axis=0)
                stitched_shape=tuple(np.ceil(all_max-all_min).astype(int))
                ### if there is a discrepancy between the top left tile and the origin then shift
                shift_to_origin = AffineTransform(translation=-all_min)
                transforms_with_shift = [t @ shift_to_origin.params for t in transforms]
                shifted_tiles = [get_transformed_array_corners(tile_shape, t) for t in transforms_with_shift]
                tiles_shifted_shapely = [numpy_shape_to_shapely(s) for s in shifted_tiles]
                ### split data into pre-defined chunks             
                chunks = normalize_chunks(chunk_size,shape=tuple(stitched_shape))
                computed_shape = np.array(list(map(sum, chunks)))
                ### check that tiles shape is correct
                assert np.all(np.array(stitched_shape) == computed_shape)
                ## get chunk details and plot as shapes
                chunk_boundaries = list(get_chunk_coordinates(stitched_shape, chunk_size))
                chunk_shapes = list(map(get_rect_from_chunk_boundary, chunk_boundaries))
                chunks_shapely = [numpy_shape_to_shapely(c) for c in chunk_shapes]
                ### iterate over files in an individual frame and attach tile info and transform
                for tile_shifted_shapely, file, transform in zip(tiles_shifted_shapely, 
                                                                 files, 
                                                                 transforms_with_shift):
                    tile_shifted_shapely.fuse_info = {'file':file, 'transform':transform}
                ### iterate over chunks for a single image and attach info
                for chunk_shapely, chunk_boundary  in zip(chunks_shapely, chunk_boundaries):
                    chunk_shapely.fuse_info = {'chunk_boundary': chunk_boundary}
                ### find intersection of tiles and chunks
                chunk_tiles = find_chunk_tile_intersections(tiles_shifted_shapely, chunks_shapely)
                ### define a fuse function to load all tiles for particular chunk
                _fuse_func=partial(fuse_func, 
                                   imload_fn=_load_image,
                                   dtype=np.uint16) 
                ### use map_blocks to calculate the fused image chunk by chunk
                target_array = da.map_blocks(func=_fuse_func,
                                             chunks=chunks, 
                                             input_tile_info=chunk_tiles,
                                             dtype=np.uint16)
                target_array = cp.asarray(target_array)
                ### append the mosaic for that particular frame to a list of mosaics
                da_t_stack.append(target_array)
            ### stack that mosaic in a time series
            da_t_stack = da.stack(da_t_stack, axis = 0)
            ### append the time series for one plane to the z-stack
            da_zt_stack.append(da_t_stack)
        ### stack the z planes together
        da_zt_stack = da.stack(da_zt_stack, axis = 0)
        ### save out as zarr
        da_zt_stack.to_zarr(f"data/zt_stack_ch{ch.value}_108tile.zarr", overwrite=True)
    else:
        print(f'Channel {ch.name} not found in image directory')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Channel BRIGHTFIELD not found in image directory
# Starting channel GFP
# Processing chunk at (0, 0)
# Processing chunk at (1836, 648)
# Processing chunk at (4752, 2484)
# Processing chunk at (2700, 1080)
# Processing chunk at (2592, 4860)
# Processing chunk at (3456, 5292)
# Processing chunk at (1404, 3888)
# Processing chunk at (108, 2700)
# Processing chunk at (972, 3132)
# Processing chunk at (4644, 2376)
# Processing chunk at (2592, 972)
# Processing chunk at (5508, 2808)
# Processing chunk at (3456, 1404)
# Processing chunk at (3348, 5184)
# Processing chunk at (1296, 3780)
# Processing chunk at (4212, 5616)
# Processing chunk at (2160, 4212)
# Processing chunk at (648, 2052)
# Processing chunk at (540, 5832)
# Processing chunk at (4320, 1296)
# Processing chunk at (3780, 4968)
# Processing chunk at (5184, 1728)
# Processing chunk at (3132, 324)
# Processing chunk at (3024, 4104)
# Processing chunk at (3996, 756)
# Processing chunk at (3888, 4536)
# Processing chunk at (1836, 3132)
# Processing chunk at (2700, 3564)
# Processing chunk at (540, 1944)
# Processing chunk at (5076, 1620)
# Processing chunk at (108, 5184)
# Processing chunk at (3024, 216)
# Processing chunk at (5940, 2052)Processing chunk at (972, 5616)
#
# Processing chunk at (3888, 648)
# Processing chunk at (4752, 1080)
# Processing chunk at (4644, 4860)Processing chunk at (2592, 3456)Processing chunk at (5508, 5292)
# Processing chunk at (3456, 3888)
#
#
# Processing chunk at (1404, 2484)Processing chunk at (216, 864)
# Processing chunk at (5508, 1404)
#
# Processing chunk at (1080, 1296)
# Processing chunk at (1944, 1728)Processing chunk at (4212, 4212)Processing chunk at (5616, 972)
#
# Processing chunk at (648, 4536)
# Processing chunk at (4428, 0)
# Processing chunk at (5292, 432)
#
# Processing chunk at (2268, 2376)Processing chunk at (3132, 2808)
# Processing chunk at (5400, 5292)Processing chunk at (1836, 5616)
#
# Processing chunk at (648, 648)
#
# Processing chunk at (540, 4428)
# Processing chunk at (5184, 324)
# Processing chunk at (5076, 4104)Processing chunk at (3024, 2700)
# Processing chunk at (5940, 4536)
#
# Processing chunk at (3888, 3132)
# Processing chunk at (1836, 1728)
# Processing chunk at (4752, 3564)
# Processing chunk at (2700, 2160)
# Processing chunk at (2592, 5940)
# Processing chunk at (1404, 4968)
# Processing chunk at (5940, 648)
# Processing chunk at (1512, 540)
# Processing chunk at (972, 4212)
# Processing chunk at (2376, 972)
# Processing chunk at (4644, 3456)
# Processing chunk at (216, 3348)Processing chunk at (1188, 0)Processing chunk at (5508, 3888)Processing chunk at (1080, 3780)
# Processing chunk at (2160, 5292)
#
#
#
# Processing chunk at (3564, 2052)Processing chunk at (2268, 4860)Processing chunk at (1944, 324)
#
#
# Processing chunk at (648, 3132)
# Processing chunk at (4320, 2376)
# Processing chunk at (2268, 972)Processing chunk at (5184, 2808)
# Processing chunk at (3132, 1404)
# Processing chunk at (3024, 5184)Processing chunk at (3996, 1836)
# Processing chunk at (3888, 5616)
#
#
# Processing chunk at (1836, 4212)
# Processing chunk at (2700, 4644)Processing chunk at (2808, 216)
# Processing chunk at (5076, 2700)
# Processing chunk at (5940, 3132)
#
# Processing chunk at (1512, 3024)
# Processing chunk at (4644, 5940)
# Processing chunk at (4752, 2160)Processing chunk at (324, 2052)
#
# Processing chunk at (2592, 4536)Processing chunk at (3456, 4968)
#
# Processing chunk at (3240, 0)
# Processing chunk at (216, 1944)
# Processing chunk at (1080, 2376)
# Processing chunk at (1944, 2808)
# Processing chunk at (5616, 2052)Processing chunk at (648, 5616)
# Processing chunk at (3564, 648)
# Processing chunk at (4428, 1080)
# Processing chunk at (4320, 4860)Processing chunk at (2268, 3456)Processing chunk at (5292, 1512)
#
#
# Processing chunk at (5184, 5292)Processing chunk at (3132, 3888)
# Processing chunk at (3996, 4320)Processing chunk at (540, 5508)
# Processing chunk at (5076, 5184)
#
#
# Processing chunk at (5184, 1404)
# Processing chunk at (756, 1296)
#
# Processing chunk at (3024, 3780)
# Processing chunk at (5940, 5616)
# Processing chunk at (3888, 4212)
# Processing chunk at (4752, 4644)
# Processing chunk at (432, 756)Processing chunk at (2700, 3240)
#
# Processing chunk at (4104, 0)Processing chunk at (1512, 1620)
#
# Processing chunk at (2376, 2052)Processing chunk at (216, 4428)
#
# Processing chunk at (324, 648)
# Processing chunk at (3240, 2484)
# Processing chunk at (5508, 4968)Processing chunk at (1188, 1080)
#
# Processing chunk at (1080, 4860)
# Processing chunk at (1944, 5292)
# Processing chunk at (4860, 324)Processing chunk at (5724, 756)Processing chunk at (5616, 4536)
# Processing chunk at (3564, 3132)
# Processing chunk at (4428, 3564)
#
# Processing chunk at (5292, 3996)
# Processing chunk at (2268, 5940)Processing chunk at (1944, 1404)
# Processing chunk at (5616, 648)
# Processing chunk at (648, 4212)
#
#
# Processing chunk at (4320, 3456)
# Processing chunk at (5184, 3888)Processing chunk at (5292, 108)Processing chunk at (864, 0)
#
#
# Processing chunk at (3132, 2484)
# Processing chunk at (3996, 2916)
# Processing chunk at (1836, 5292)Processing chunk at (2700, 5724)
#
# Processing chunk at (2808, 1296)
# Processing chunk at (3672, 1728)
# Processing chunk at (5940, 4212)
# Processing chunk at (1620, 324)
# Processing chunk at (1512, 4104)
# Processing chunk at (2484, 756)Processing chunk at (2376, 4536)
#
# Processing chunk at (324, 3132)Processing chunk at (1188, 3564)
#
# Processing chunk at (4860, 2808)
# Processing chunk at (5724, 3240)
# Processing chunk at (3564, 5616)Processing chunk at (4536, 2268)
#
# Processing chunk at (2376, 648)Processing chunk at (216, 3024)Processing chunk at (3240, 1080)
#
# Processing chunk at (1080, 3456)Processing chunk at (1944, 3888)
#
#
# Processing chunk at (5616, 3132)Processing chunk at (3564, 1728)
#
# Processing chunk at (4428, 2160)Processing chunk at (0, 2052)
#
# Processing chunk at (4320, 5940)
# Processing chunk at (5292, 2592)Processing chunk at (2268, 4536)
#
# Processing chunk at (3132, 4968)Processing chunk at (3996, 5400)
#
# Processing chunk at (2916, 0)Processing chunk at (2808, 3780)
# Processing chunk at (756, 2376)Processing chunk at (3780, 432)
#
# Processing chunk at (1620, 2808)
# Processing chunk at (3888, 5292)
# Processing chunk at (2484, 3240)
#
# Processing chunk at (432, 1836)
# Processing chunk at (4752, 5724)Processing chunk at (324, 5616)Processing chunk at (4104, 1080)
#
#
# Processing chunk at (4968, 1512)
# Processing chunk at (3672, 324)
# Processing chunk at (1512, 2700)
# Processing chunk at (2376, 3132)
# Processing chunk at (324, 1728)
# Processing chunk at (3240, 3564)
# Processing chunk at (216, 5508)
# Processing chunk at (1188, 2160)Processing chunk at (1080, 5940)Processing chunk at (4860, 1404)
#
# Processing chunk at (5724, 1836)
# Processing chunk at (5616, 5616)
#
# Processing chunk at (3564, 4212)
# Processing chunk at (4536, 864)Processing chunk at (4428, 4644)Processing chunk at (5292, 5076)
# Processing chunk at (648, 5292)
#
#
# Processing chunk at (2052, 2052)Processing chunk at (0, 648)
#
# Processing chunk at (4320, 4536)
# Processing chunk at (2916, 2484)Processing chunk at (864, 1080)Processing chunk at (5184, 4968)Processing chunk at (756, 4860)Processing chunk at (1728, 1512)
#
# Processing chunk at (3996, 3996)Processing chunk at (5400, 756)
# Processing chunk at (432, 4320)
#
#
#
#
# Processing chunk at (4104, 3564)
# Processing chunk at (2808, 2376)Processing chunk at (756, 972)Processing chunk at (3672, 2808)
#
# Processing chunk at (1620, 1404)
# Processing chunk at (1512, 5184)
# Processing chunk at (2484, 1836)
#
# Processing chunk at (2376, 5616)
# Processing chunk at (432, 432)
# Processing chunk at (324, 4212)
# Processing chunk at (1188, 4644)
# Processing chunk at (4968, 108)
# Processing chunk at (4860, 3888)
# Processing chunk at (5832, 540)Processing chunk at (5724, 4320)Processing chunk at (4536, 3348)Processing chunk at (3240, 2160)Processing chunk at (1080, 4536)Processing chunk at (1944, 4968)
# Processing chunk at (3348, 1728)
#
#
#
# Processing chunk at (1296, 324)Processing chunk at (5616, 4212)
# Processing chunk at (2160, 756)Processing chunk at (4428, 3240)Processing chunk at (0, 3132)
# Processing chunk at (2268, 5616)
# Processing chunk at (5292, 3672)
#
#
#
#
# Processing chunk at (864, 3564)
# Processing chunk at (2052, 648)
# Processing chunk at (2916, 1080)Processing chunk at (2808, 4860)
#
# Processing chunk at (3780, 1512)
# Processing chunk at (756, 3456)Processing chunk at (3672, 5292)
#
#
# Processing chunk at (1728, 108)Processing chunk at (1620, 3888)
# Processing chunk at (2484, 4320)Processing chunk at (432, 2916)
#
#
# Processing chunk at (4104, 2160)
# Processing chunk at (4968, 2592)
# Processing chunk at (5832, 3024)
# Processing chunk at (3672, 1404)
# Processing chunk at (4536, 5832)
# Processing chunk at (1512, 3780)
# Processing chunk at (108, 1728)
# Processing chunk at (2376, 4212)
# Processing chunk at (3240, 4644)
# Processing chunk at (1188, 3240)Processing chunk at (2592, 0)
#
# Processing chunk at (4860, 2484)Processing chunk at (3456, 432)
# Processing chunk at (5724, 2916)
# Processing chunk at (1296, 2808)
# Processing chunk at (3564, 5292)
# Processing chunk at (4536, 1944)
#
# Processing chunk at (4428, 5724)Processing chunk at (3348, 324)
# Processing chunk at (4212, 756)Processing chunk at (2052, 3132)
# Processing chunk at (0, 1728)
# Processing chunk at (2916, 3564)
#
#
# Processing chunk at (756, 5940)Processing chunk at (864, 2160)
# Processing chunk at (3780, 3996)
#
# Processing chunk at (1728, 2592)Processing chunk at (5400, 1836)
#
# Processing chunk at (432, 5400)Processing chunk at (4104, 4644)
# Processing chunk at (4968, 5076)
#
# Processing chunk at (540, 972)
# Processing chunk at (2808, 3456)
# Processing chunk at (3780, 108)
# Processing chunk at (3672, 3888)
# Processing chunk at (1620, 2484)
# Processing chunk at (2484, 2916)
# Processing chunk at (324, 5292)
# Processing chunk at (1188, 5724)
# Processing chunk at (4968, 1188)
# Processing chunk at (4860, 4968)
# Processing chunk at (5724, 5400)
# Processing chunk at (5832, 1620)Processing chunk at (1404, 1512)
# Processing chunk at (4536, 4428)
# Processing chunk at (108, 324)
# Processing chunk at (972, 756)
# Processing chunk at (4644, 0)
#
# Processing chunk at (5508, 432)
# Processing chunk at (3348, 2808)Processing chunk at (5616, 5292)Processing chunk at (1296, 1404)
# Processing chunk at (4212, 3240)
# Processing chunk at (2160, 1836)
#
#
# Processing chunk at (2052, 5616)Processing chunk at (0, 4212)
# Processing chunk at (5292, 4752)
#
# Processing chunk at (864, 4644)Processing chunk at (1728, 5076)
#
# Processing chunk at (5400, 4320)
# Processing chunk at (2052, 1728)
# Processing chunk at (2916, 2160)
# Processing chunk at (2808, 5940)
# Processing chunk at (756, 4536)
# Processing chunk at (3780, 2592)
# Processing chunk at (1728, 1188)
# Processing chunk at (1620, 4968)
# Processing chunk at (2484, 5400)
# Processing chunk at (5400, 432)Processing chunk at (432, 3996)
#
# Processing chunk at (1836, 756)
# Processing chunk at (4104, 3240)Processing chunk at (4968, 3672)Processing chunk at (5832, 4104)
# Processing chunk at (108, 2808)
#
#
# Processing chunk at (972, 3240)Processing chunk at (3240, 5724)
#
# Processing chunk at (4644, 2484)
# Processing chunk at (2592, 1080)
# Processing chunk at (3456, 1512)Processing chunk at (5724, 3996)
# Processing chunk at (1404, 108)
#
# Processing chunk at (1296, 3888)
# Processing chunk at (2160, 4320)
# Processing chunk at (3348, 1404)Processing chunk at (4212, 1836)
#
# Processing chunk at (2160, 432)
# Processing chunk at (2052, 4212)Processing chunk at (0, 2808)
#
# Processing chunk at (2916, 4644)Processing chunk at (864, 3240)Processing chunk at (3780, 5076)
#
# Processing chunk at (1728, 3672)Processing chunk at (2268, 0)
#
# Processing chunk at (5400, 2916)
# Processing chunk at (4104, 5724)
#
# Processing chunk at (540, 2052)
# Processing chunk at (3672, 4968)
# Processing chunk at (5076, 1728)
# Processing chunk at (2484, 3996)
# Processing chunk at (3024, 324)
# Processing chunk at (3888, 756)Processing chunk at (4752, 1188)Processing chunk at (2592, 3564)
#
#
# Processing chunk at (5832, 2700)Processing chunk at (1404, 2592)Processing chunk at (4536, 5508)Processing chunk at (108, 1404)
# Processing chunk at (972, 1836)Processing chunk at (4644, 1080)
#
#
#
# Processing chunk at (5508, 1512)
# Processing chunk at (3456, 108)
# Processing chunk at (3348, 3888)
# Processing chunk at (1296, 2484)
# Processing chunk at (4212, 4320)
#
# Processing chunk at (2160, 2916)
# Processing chunk at (0, 5292)Processing chunk at (864, 5724)Processing chunk at (5400, 5400)
#
# Processing chunk at (648, 756)
# Processing chunk at (2916, 3240)
#
# Processing chunk at (3780, 3672)Processing chunk at (4320, 0)
#
# Processing chunk at (5184, 432)
# Processing chunk at (3024, 2808)
# Processing chunk at (1836, 1836)
# Processing chunk at (2700, 2268)
# Processing chunk at (4968, 4752)
# Processing chunk at (540, 648)
# Processing chunk at (5832, 5184)
# Processing chunk at (5076, 324)
# Processing chunk at (108, 3888)
# Processing chunk at (5940, 756)
# Processing chunk at (972, 4320)Processing chunk at (4644, 3564)
#
# Processing chunk at (2592, 2160)Processing chunk at (5508, 3996)
# Processing chunk at (3456, 2592)Processing chunk at (1404, 1188)
# Processing chunk at (1296, 4968)
#
# Processing chunk at (2160, 5400)
#
# Processing chunk at (5508, 108)
# Processing chunk at (1080, 0)Processing chunk at (3348, 2484)Processing chunk at (1944, 432)
# Processing chunk at (4212, 2916)
#
# Processing chunk at (2052, 5292)Processing chunk at (2916, 5724)Processing chunk at (2268, 1080)
# Processing chunk at (1728, 4752)Processing chunk at (3132, 1512)
#
# Processing chunk at (5400, 3996)Processing chunk at (540, 3132)
#
#
# Processing chunk at (5076, 2808)
# Processing chunk at (3024, 1404)
#
# Processing chunk at (5940, 3240)Processing chunk at (3888, 1836)
#
#
# Processing chunk at (1836, 432)
# Processing chunk at (4752, 2268)
# Processing chunk at (2700, 864)
# Processing chunk at (2592, 4644)
# Processing chunk at (3456, 5076)
# Processing chunk at (1404, 3672)
# Processing chunk at (972, 2916)
# Processing chunk at (4644, 2160)
# Processing chunk at (216, 2052)Processing chunk at (5508, 2592)
#
# Processing chunk at (3456, 1188)
# Processing chunk at (3348, 4968)
# Processing chunk at (4212, 5400)Processing chunk at (2160, 3996)Processing chunk at (3564, 756)
#
#
# Processing chunk at (648, 1836)Processing chunk at (540, 5616)
# Processing chunk at (4320, 1080)
# Processing chunk at (5184, 1512)
#
# Processing chunk at (5076, 5292)Processing chunk at (3132, 108)
#
# Processing chunk at (3024, 3888)
# Processing chunk at (3996, 540)Processing chunk at (3888, 4320)Processing chunk at (1836, 2916)Processing chunk at (2700, 3348)
#
#
# Processing chunk at (5076, 1404)
#
# Processing chunk at (108, 4968)Processing chunk at (5940, 1836)
# Processing chunk at (972, 5400)
#
# Processing chunk at (3888, 432)
# Processing chunk at (4752, 864)
# Processing chunk at (324, 756)
# Processing chunk at (4644, 4644)
# Processing chunk at (2592, 3240)
# Processing chunk at (5508, 5076)
# Processing chunk at (3456, 3672)Processing chunk at (216, 648)
# Processing chunk at (1080, 1080)
#
# Processing chunk at (1944, 1512)Processing chunk at (5616, 756)Processing chunk at (648, 4320)
#
#
# Processing chunk at (4320, 3564)Processing chunk at (5292, 216)
#
# Processing chunk at (2268, 2160)
# Processing chunk at (3132, 2592)
# Processing chunk at (3996, 3024)
# Processing chunk at (1836, 5400)
# Processing chunk at (2700, 5832)Processing chunk at (648, 432)
# Processing chunk at (540, 4212)
#
# Processing chunk at (5184, 108)
# Processing chunk at (756, 0)Processing chunk at (5076, 3888)Processing chunk at (3024, 2484)
#
#
# Processing chunk at (5940, 4320)Processing chunk at (3888, 2916)
# Processing chunk at (1836, 1512)
# Processing chunk at (4752, 3348)
#
# Processing chunk at (2700, 1944)Processing chunk at (2592, 5724)
#
# Processing chunk at (1404, 4752)Processing chunk at (1512, 324)
#
# Processing chunk at (2376, 756)
# Processing chunk at (3240, 1188)
# Processing chunk at (216, 3132)
# Processing chunk at (5508, 3672)
# Processing chunk at (1080, 3564)
# Processing chunk at (1944, 3996)Processing chunk at (3564, 1836)
# Processing chunk at (4428, 2268)
#
# Processing chunk at (2268, 4644)Processing chunk at (3132, 5076)
# Processing chunk at (1944, 108)
# Processing chunk at (648, 2916)
#
# Processing chunk at (4320, 2160)
# Processing chunk at (2268, 756)
# Processing chunk at (5184, 2592)
# Processing chunk at (3132, 1188)
# Processing chunk at (3024, 4968)
# Processing chunk at (3996, 1620)
# Processing chunk at (3888, 5400)
# Processing chunk at (1836, 3996)Processing chunk at (4752, 5832)
#
# Processing chunk at (2700, 4428)
# Processing chunk at (2808, 0)
# Processing chunk at (3672, 432)Processing chunk at (5940, 2916)
# Processing chunk at (1512, 2808)Processing chunk at (4644, 5724)
#
#
# Processing chunk at (324, 1836)
# Processing chunk at (216, 5616)
# Processing chunk at (1188, 2268)
# Processing chunk at (3456, 4752)Processing chunk at (4860, 1512)
#
# Processing chunk at (3564, 4320)
# Processing chunk at (4536, 972)
# Processing chunk at (216, 1728)
# Processing chunk at (1080, 2160)
# Processing chunk at (1944, 2592)
# Processing chunk at (5616, 1836)
# Processing chunk at (648, 5400)
# Processing chunk at (3564, 432)Processing chunk at (4428, 864)
# Processing chunk at (4320, 4644)
# Processing chunk at (2268, 3240)
# Processing chunk at (5292, 1296)
# Processing chunk at (5184, 5076)
# Processing chunk at (3132, 3672)
# Processing chunk at (3996, 4104)
# Processing chunk at (540, 5292)Processing chunk at (5076, 4968)
#
# Processing chunk at (756, 1080)
# Processing chunk at (5940, 5400)
# Processing chunk at (1620, 1512)Processing chunk at (3888, 3996)
#
# Processing chunk at (4752, 4428)Processing chunk at (432, 540)
#
# Processing chunk at (324, 4320)Processing chunk at (4968, 216)Processing chunk at (1404, 5832)
#
#
# Processing chunk at (1512, 1404)Processing chunk at (2376, 1836)
#
# Processing chunk at (216, 4212)
# Processing chunk at (324, 432)
# Processing chunk at (3240, 2268)
# Processing chunk at (1188, 864)Processing chunk at (1080, 4644)
#
# Processing chunk at (1944, 5076)
# Processing chunk at (4860, 108)Processing chunk at (5724, 540)
# Processing chunk at (5616, 4320)
#
# Processing chunk at (3564, 2916)Processing chunk at (4428, 3348)Processing chunk at (5292, 3780)
#
# Processing chunk at (2268, 5724)Processing chunk at (5616, 432)
#
#
# Processing chunk at (648, 3996)
# Processing chunk at (2052, 756)
# Processing chunk at (4320, 3240)
# Processing chunk at (5184, 3672)
# Processing chunk at (756, 3564)
# Processing chunk at (1728, 216)
# Processing chunk at (3996, 2700)Processing chunk at (1836, 5076)
# Processing chunk at (432, 3024)
#
# Processing chunk at (2700, 5508)
# Processing chunk at (2808, 1080)Processing chunk at (3672, 1512)Processing chunk at (1620, 108)Processing chunk at (1512, 3888)
# Processing chunk at (2484, 540)
# Processing chunk at (2376, 4320)
#
#
# Processing chunk at (324, 2916)Processing chunk at (3240, 4752)
# Processing chunk at (1188, 3348)
# Processing chunk at (4860, 2592)
# Processing chunk at (5724, 3024)
#
# Processing chunk at (3564, 5400)
#
# Processing chunk at (4536, 2052)Processing chunk at (4428, 5832)Processing chunk at (3240, 864)
#
#
# Processing chunk at (1080, 3240)
# Processing chunk at (1944, 3672)
# Processing chunk at (5616, 2916)
# Processing chunk at (4428, 1944)
# Processing chunk at (0, 1836)
# Processing chunk at (4320, 5724)Processing chunk at (5292, 2376)
#
# Processing chunk at (2268, 4320)
# Processing chunk at (864, 2268)Processing chunk at (3132, 4752)
#
# Processing chunk at (3996, 5184)Processing chunk at (2808, 3564)
# Processing chunk at (756, 2160)
# Processing chunk at (3780, 216)
#
# Processing chunk at (3672, 3996)Processing chunk at (1620, 2592)Processing chunk at (2484, 3024)
# Processing chunk at (432, 1620)Processing chunk at (4752, 5508)
#
# Processing chunk at (324, 5400)Processing chunk at (1188, 5832)Processing chunk at (4104, 864)
# Processing chunk at (4968, 1296)Processing chunk at (4860, 5076)
# Processing chunk at (5832, 1728)
#
# Processing chunk at (3672, 108)
#
#
#
#
# Processing chunk at (1512, 2484)
# Processing chunk at (4536, 4536)
# Processing chunk at (2376, 2916)Processing chunk at (3240, 3348)
#
# Processing chunk at (216, 5292)Processing chunk at (1188, 1944)
# Processing chunk at (1080, 5724)
# Processing chunk at (4860, 1188)
# Processing chunk at (5724, 1620)
#
# Processing chunk at (1296, 1512)
# Processing chunk at (5616, 5400)
# Processing chunk at (3564, 3996)
# Processing chunk at (4536, 648)
# Processing chunk at (4428, 4428)
# Processing chunk at (5292, 4860)
# Processing chunk at (2052, 1836)Processing chunk at (0, 432)Processing chunk at (2916, 2268)
#
#
# Processing chunk at (864, 864)
# Processing chunk at (3780, 2700)
# Processing chunk at (5184, 4752)
# Processing chunk at (756, 4644)Processing chunk at (1728, 1296)Processing chunk at (1620, 5076)Processing chunk at (5400, 540)Processing chunk at (432, 4104)
#
#
#
# Processing chunk at (4104, 3348)
# Processing chunk at (4968, 3780)Processing chunk at (2808, 2160)
#
#
# Processing chunk at (3672, 2592)Processing chunk at (1620, 1188)
#
# Processing chunk at (1512, 4968)Processing chunk at (2484, 1620)Processing chunk at (2376, 5400)
#
# Processing chunk at (324, 3996)Processing chunk at (3240, 5832)
#
#
# Processing chunk at (1188, 4428)Processing chunk at (4860, 3672)
# Processing chunk at (5832, 324)
#
# Processing chunk at (5724, 4104)
# Processing chunk at (4536, 3132)
# Processing chunk at (1944, 4752)
# Processing chunk at (3348, 1512)
# Processing chunk at (1296, 108)
# Processing chunk at (5616, 3996)
# Processing chunk at (4212, 1944)Processing chunk at (2160, 540)Processing chunk at (2052, 4320)
#
# Processing chunk at (0, 2916)
#
# Processing chunk at (5292, 3456)Processing chunk at (864, 3348)Processing chunk at (3132, 5832)Processing chunk at (1728, 3780)Processing chunk at (5400, 3024)
#
# Processing chunk at (2052, 432)
# Processing chunk at (2916, 864)
# Processing chunk at (2808, 4644)
#
#
#
# Processing chunk at (3780, 1296)
# Processing chunk at (756, 3240)Processing chunk at (3672, 5076)
# Processing chunk at (1620, 3672)
# Processing chunk at (2484, 4104)Processing chunk at (432, 2700)
#
# Processing chunk at (4104, 1944)
# Processing chunk at (4968, 2376)
#
# Processing chunk at (5832, 2808)Processing chunk at (4536, 5616)
# Processing chunk at (108, 1512)
#
# Processing chunk at (2376, 3996)
# Processing chunk at (972, 1944)
# Processing chunk at (3240, 4428)
# Processing chunk at (4644, 1188)
# Processing chunk at (3456, 216)
# Processing chunk at (5724, 2700)Processing chunk at (1296, 2592)
#
# Processing chunk at (3564, 5076)
# Processing chunk at (2160, 3024)
# Processing chunk at (4428, 5508)
# Processing chunk at (0, 5400)Processing chunk at (5292, 5940)Processing chunk at (3348, 108)Processing chunk at (4212, 540)
#
# Processing chunk at (2052, 2916)Processing chunk at (0, 1512)Processing chunk at (2916, 3348)
#
# Processing chunk at (756, 5724)
# Processing chunk at (864, 1944)
# Processing chunk at (3780, 3780)
# Processing chunk at (1728, 2376)Processing chunk at (5400, 1620)
# Processing chunk at (432, 5184)
# Processing chunk at (4104, 4428)Processing chunk at (4968, 4860)
#
#
#
#
# Processing chunk at (540, 756)Processing chunk at (2808, 3240)Processing chunk at (5832, 5292)
# Processing chunk at (3672, 3672)Processing chunk at (5076, 432)
# Processing chunk at (2484, 2700)
#
# Processing chunk at (324, 5076)
#
#
#
# Processing chunk at (1188, 5508)
# Processing chunk at (2592, 2268)
# Processing chunk at (4860, 4752)
# Processing chunk at (5724, 5184)
# Processing chunk at (5832, 1404)
# Processing chunk at (1404, 1296)
# Processing chunk at (4536, 4212)
# Processing chunk at (108, 108)Processing chunk at (972, 540)Processing chunk at (5508, 216)Processing chunk at (3348, 2592)
#
#
#
# Processing chunk at (1296, 1188)Processing chunk at (4212, 3024)Processing chunk at (2160, 1620)Processing chunk at (2052, 5400)
#
#
# Processing chunk at (0, 3996)
# Processing chunk at (2916, 5832)
# Processing chunk at (864, 4428)
#
# Processing chunk at (1728, 4860)Processing chunk at (5400, 4104)
# Processing chunk at (2916, 1944)Processing chunk at (2808, 5724)
# Processing chunk at (756, 4320)
# Processing chunk at (3780, 2376)
# Processing chunk at (1620, 4752)Processing chunk at (2484, 5184)
# Processing chunk at (3024, 1512)
#
# Processing chunk at (432, 3780)
# Processing chunk at (1836, 540)
#
#
# Processing chunk at (4104, 3024)Processing chunk at (2700, 972)
#
# Processing chunk at (4968, 3456)
# Processing chunk at (5832, 3888)
# Processing chunk at (108, 2592)Processing chunk at (972, 3024)
#
# Processing chunk at (4644, 2268)
# Processing chunk at (2592, 864)
# Processing chunk at (5508, 2700)
# Processing chunk at (3456, 1296)
# Processing chunk at (3348, 5076)Processing chunk at (1296, 3672)Processing chunk at (2160, 4104)
#
# Processing chunk at (3348, 1188)
#
# Processing chunk at (4212, 1620)Processing chunk at (2052, 3996)
# Processing chunk at (2916, 4428)
# Processing chunk at (864, 3024)Processing chunk at (3780, 4860)
# Processing chunk at (1728, 3456)
#
#
# Processing chunk at (3132, 216)
# Processing chunk at (5400, 2700)Processing chunk at (4104, 5508)Processing chunk at (4968, 5940)
# Processing chunk at (540, 1836)
#
# Processing chunk at (3672, 4752)
# Processing chunk at (5076, 1512)
#
# Processing chunk at (108, 5076)Processing chunk at (3024, 108)
#
# Processing chunk at (5940, 1944)Processing chunk at (3888, 540)
# Processing chunk at (4752, 972)
# Processing chunk at (2592, 3348)
#
# Processing chunk at (3456, 3780)
# Processing chunk at (1404, 2376)
# Processing chunk at (4536, 5292)
# Processing chunk at (108, 1188)Processing chunk at (972, 1620)
# Processing chunk at (4644, 864)
#
# Processing chunk at (216, 756)Processing chunk at (5508, 1296)Processing chunk at (3348, 3672)
# Processing chunk at (1296, 2268)Processing chunk at (4212, 4104)
# Processing chunk at (2160, 2700)
#
# Processing chunk at (0, 5076)Processing chunk at (864, 5508)
#
# Processing chunk at (1728, 5940)
#
# Processing chunk at (5400, 5184)
#
# Processing chunk at (648, 540)Processing chunk at (540, 4320)
# Processing chunk at (3780, 3456)
#
# Processing chunk at (5184, 216)Processing chunk at (3024, 2592)
#
# Processing chunk at (3888, 3024)Processing chunk at (1836, 1620)Processing chunk at (2700, 2052)
#
#
# Processing chunk at (4968, 4536)
# Processing chunk at (540, 432)Processing chunk at (5832, 4968)Processing chunk at (1404, 4860)
#
# Processing chunk at (5076, 108)
# Processing chunk at (108, 3672)
# Processing chunk at (5940, 540)
#
# Processing chunk at (972, 4104)
# Processing chunk at (4644, 3348)
# Processing chunk at (2592, 1944)
# Processing chunk at (5508, 3780)
# Processing chunk at (3456, 2376)
# Processing chunk at (1404, 972)
# Processing chunk at (1296, 4752)Processing chunk at (2160, 5184)
# Processing chunk at (1944, 216)Processing chunk at (4212, 2700)Processing chunk at (648, 3024)
# Processing chunk at (2916, 5508)Processing chunk at (4320, 2268)Processing chunk at (3780, 5940)
# Processing chunk at (2268, 864)
#
#
# Processing chunk at (3132, 1296)
# Processing chunk at (5400, 3780)
#
# Processing chunk at (3996, 1728)
#
# Processing chunk at (1836, 4104)Processing chunk at (540, 2916)
# Processing chunk at (5076, 2592)
# Processing chunk at (3024, 1188)Processing chunk at (5940, 3024)
#
#
#
# Processing chunk at (3888, 1620)
# Processing chunk at (1836, 216)
# Processing chunk at (4752, 2052)
# Processing chunk at (4644, 5832)
# Processing chunk at (2700, 648)
# Processing chunk at (2592, 4428)Processing chunk at (3456, 4860)
#
# Processing chunk at (1404, 3456)Processing chunk at (972, 2700)
#
# Processing chunk at (4644, 1944)
# Processing chunk at (216, 1836)
# Processing chunk at (5508, 2376)
# Processing chunk at (1080, 2268)Processing chunk at (3348, 4752)
# Processing chunk at (4212, 5184)
# Processing chunk at (3564, 540)Processing chunk at (4428, 972)
#
# Processing chunk at (2268, 3348)
# Processing chunk at (648, 1620)
#
# Processing chunk at (540, 5400)
# Processing chunk at (4320, 864)
# Processing chunk at (5184, 1296)Processing chunk at (5076, 5076)
# Processing chunk at (3024, 3672)
# Processing chunk at (3996, 324)Processing chunk at (3888, 4104)Processing chunk at (1836, 2700)
# Processing chunk at (4752, 4536)
#
#
# Processing chunk at (2700, 3132)
# Processing chunk at (1404, 5940)
#
# Processing chunk at (5076, 1188)Processing chunk at (108, 4752)Processing chunk at (5940, 1620)
#
#
# Processing chunk at (1512, 1512)Processing chunk at (972, 5184)
# Processing chunk at (4752, 648)
#
# Processing chunk at (324, 540)
# Processing chunk at (4644, 4428)
# Processing chunk at (1188, 972)
# Processing chunk at (5508, 4860)
# Processing chunk at (3456, 3456)
# Processing chunk at (4860, 216)Processing chunk at (1296, 5832)
#
# Processing chunk at (216, 432)
# Processing chunk at (1080, 864)Processing chunk at (1944, 1296)Processing chunk at (5616, 540)
# Processing chunk at (648, 4104)Processing chunk at (4320, 3348)
# Processing chunk at (5292, 0)
#
#
# Processing chunk at (2268, 1944)
# Processing chunk at (5184, 3780)
#
# Processing chunk at (3132, 2376)Processing chunk at (3996, 2808)Processing chunk at (1836, 5184)
#
# Processing chunk at (2700, 5616)
# Processing chunk at (540, 3996)
# Processing chunk at (5076, 3672)
# Processing chunk at (1620, 216)
# Processing chunk at (3024, 2268)
# Processing chunk at (5940, 4104)Processing chunk at (3888, 2700)Processing chunk at (4752, 3132)Processing chunk at (2700, 1728)
#
# Processing chunk at (2592, 5508)
#
# Processing chunk at (3456, 5940)
# Processing chunk at (1404, 4536)Processing chunk at (1512, 108)
#
#
# Processing chunk at (2376, 540)Processing chunk at (3240, 972)
#
#
# Processing chunk at (216, 2916)
# Processing chunk at (1080, 3348)
# Processing chunk at (1944, 3780)
# Processing chunk at (5616, 3024)
# Processing chunk at (3564, 1620)
# Processing chunk at (4428, 2052)
# Processing chunk at (4320, 5832)
# Processing chunk at (2268, 4428)
# Processing chunk at (5292, 2484)
# Processing chunk at (3132, 4860)
# Processing chunk at (3996, 5292)
# Processing chunk at (648, 2700)
# Processing chunk at (4320, 1944)
# Processing chunk at (5184, 2376)Processing chunk at (3132, 972)
# Processing chunk at (3024, 4752)
#
# Processing chunk at (3996, 1404)Processing chunk at (3888, 5184)
# Processing chunk at (1836, 3780)
# Processing chunk at (4752, 5616)Processing chunk at (2700, 4212)Processing chunk at (3672, 216)
#
#
#
# Processing chunk at (1512, 2592)
# Processing chunk at (2376, 3024)Processing chunk at (4644, 5508)Processing chunk at (324, 1620)
#
#
# Processing chunk at (216, 5400)
# Processing chunk at (5508, 5940)
# Processing chunk at (1188, 2052)
# Processing chunk at (1080, 5832)Processing chunk at (4860, 1296)Processing chunk at (5724, 1728)
#
#
# Processing chunk at (3564, 4104)
# Processing chunk at (4536, 756)
# Processing chunk at (1080, 1944)
# Processing chunk at (1944, 2376)
# Processing chunk at (5616, 1620)
# Processing chunk at (648, 5184)
# Processing chunk at (3564, 216)
# Processing chunk at (4320, 4428)
# Processing chunk at (4428, 648)
# Processing chunk at (0, 540)
# Processing chunk at (2268, 3024)Processing chunk at (5292, 1080)
# Processing chunk at (5184, 4860)Processing chunk at (3132, 3456)
#
#
# Processing chunk at (3996, 3888)Processing chunk at (2808, 2268)
# Processing chunk at (5076, 4752)
# Processing chunk at (756, 864)
#
# Processing chunk at (5940, 5184)Processing chunk at (1620, 1296)
#
# Processing chunk at (1512, 5076)Processing chunk at (2484, 1728)Processing chunk at (4752, 4212)
#
#
# Processing chunk at (432, 324)
# Processing chunk at (324, 4104)Processing chunk at (1188, 4536)
#
# Processing chunk at (4968, 0)Processing chunk at (5832, 432)Processing chunk at (1512, 1188)
#
#
# Processing chunk at (2376, 1620)
# Processing chunk at (216, 3996)
# Processing chunk at (324, 216)
# Processing chunk at (3240, 2052)
# Processing chunk at (1188, 648)
# Processing chunk at (1080, 4428)
# Processing chunk at (1944, 4860)
# Processing chunk at (5724, 324)
# Processing chunk at (5616, 4104)Processing chunk at (3564, 2700)
#
# Processing chunk at (4428, 3132)
# Processing chunk at (5292, 3564)
# Processing chunk at (2268, 5508)
# Processing chunk at (3132, 5940)Processing chunk at (2052, 540)
# Processing chunk at (2916, 972)Processing chunk at (5184, 3456)
#
# Processing chunk at (756, 3348)
# Processing chunk at (3024, 5832)Processing chunk at (1728, 0)
#
# Processing chunk at (1620, 3780)Processing chunk at (432, 2808)Processing chunk at (2700, 5292)Processing chunk at (4104, 2052)Processing chunk at (2808, 864)
#
#
#
# Processing chunk at (3672, 1296)
# Processing chunk at (1512, 3672)Processing chunk at (2484, 324)
#
# Processing chunk at (2376, 4104)
#
#
# Processing chunk at (324, 2700)Processing chunk at (3240, 4536)
# Processing chunk at (1188, 3132)
#
# Processing chunk at (4860, 2376)
# Processing chunk at (5724, 2808)
# Processing chunk at (3564, 5184)
# Processing chunk at (4536, 1836)
# Processing chunk at (4428, 5616)
# Processing chunk at (1944, 3456)
# Processing chunk at (3348, 216)
# Processing chunk at (5616, 2700)
# Processing chunk at (2052, 3024)
# Processing chunk at (0, 1620)
# Processing chunk at (4320, 5508)Processing chunk at (5292, 2160)Processing chunk at (864, 2052)
#
# Processing chunk at (5184, 5940)
# Processing chunk at (3132, 4536)
#
# Processing chunk at (3996, 4968)
# Processing chunk at (2808, 3348)Processing chunk at (756, 1944)
#
# Processing chunk at (3780, 0)Processing chunk at (3672, 3780)
#
# Processing chunk at (1620, 2376)Processing chunk at (2484, 2808)Processing chunk at (432, 1404)Processing chunk at (324, 5184)
# Processing chunk at (1188, 5616)Processing chunk at (4104, 648)
#
#
#
# Processing chunk at (4968, 1080)Processing chunk at (4860, 4860)
# Processing chunk at (5832, 1512)Processing chunk at (5724, 5292)
# Processing chunk at (4536, 4320)
# Processing chunk at (108, 216)
#
# Processing chunk at (2376, 2700)
#
#
# Processing chunk at (3240, 3132)
# Processing chunk at (216, 5076)
# Processing chunk at (1080, 5508)
# Processing chunk at (1944, 5940)
# Processing chunk at (5724, 1404)
# Processing chunk at (1296, 1296)Processing chunk at (5616, 5184)
# Processing chunk at (3564, 3780)
#
# Processing chunk at (4536, 432)Processing chunk at (4428, 4212)
#
# Processing chunk at (0, 4104)Processing chunk at (5292, 4644)
# Processing chunk at (2052, 1620)Processing chunk at (0, 216)
# Processing chunk at (2916, 2052)
# Processing chunk at (864, 648)
# Processing chunk at (2808, 5832)
# Processing chunk at (3780, 2484)
#
# Processing chunk at (756, 4428)Processing chunk at (1728, 1080)
#
# Processing chunk at (1620, 4860)
# Processing chunk at (2484, 5292)Processing chunk at (5400, 324)
# Processing chunk at (432, 3888)
# Processing chunk at (4104, 3132)
#
#
# Processing chunk at (4968, 3564)Processing chunk at (2808, 1944)Processing chunk at (5832, 3996)
# Processing chunk at (3672, 2376)
#
# Processing chunk at (1512, 4752)
# Processing chunk at (2484, 1404)
#
# Processing chunk at (2376, 5184)
# Processing chunk at (324, 3780)
# Processing chunk at (3240, 5616)
# Processing chunk at (4860, 3456)
# Processing chunk at (1188, 4212)
# Processing chunk at (5832, 108)
# Processing chunk at (1404, 0)
# Processing chunk at (5724, 3888)
# Processing chunk at (4536, 2916)
# Processing chunk at (3348, 1296)
# Processing chunk at (4212, 1728)Processing chunk at (2160, 324)
#
# Processing chunk at (2052, 4104)
# Processing chunk at (0, 2700)
# Processing chunk at (2916, 4536)Processing chunk at (864, 3132)Processing chunk at (1728, 3564)
# Processing chunk at (5400, 2808)Processing chunk at (4104, 5616)
#
#
# Processing chunk at (2916, 648)
#
# Processing chunk at (2808, 4428)Processing chunk at (3780, 1080)Processing chunk at (756, 3024)
# Processing chunk at (3672, 4860)
# Processing chunk at (1620, 3456)
#
# Processing chunk at (2484, 3888)
# Processing chunk at (432, 2484)
# Processing chunk at (4104, 1728)Processing chunk at (4968, 2160)
#
#
# Processing chunk at (4860, 5940)Processing chunk at (5832, 2592)Processing chunk at (4536, 5400)
#
#
# Processing chunk at (108, 1296)
# Processing chunk at (972, 1728)
# Processing chunk at (3240, 4212)Processing chunk at (4644, 972)
# Processing chunk at (3456, 0)
#
# Processing chunk at (3348, 3780)Processing chunk at (1296, 2376)
#
# Processing chunk at (2160, 2808)
# Processing chunk at (4428, 5292)Processing chunk at (0, 5184)
# Processing chunk at (5292, 5724)
# Processing chunk at (864, 5616)
# Processing chunk at (4212, 324)Processing chunk at (2052, 2700)
# Processing chunk at (2916, 3132)
# Processing chunk at (756, 5508)
#
#
# Processing chunk at (864, 1728)Processing chunk at (3780, 3564)
#
# Processing chunk at (1728, 2160)Processing chunk at (1620, 5940)
#
# Processing chunk at (5400, 1404)
# Processing chunk at (432, 4968)
# Processing chunk at (4104, 4212)
# Processing chunk at (4968, 4644)Processing chunk at (540, 540)Processing chunk at (5832, 5076)
# Processing chunk at (3672, 3456)
#
#
# Processing chunk at (5076, 216)
# Processing chunk at (1512, 5832)Processing chunk at (108, 3780)
#
# Processing chunk at (1188, 5292)
# Processing chunk at (2592, 2052)
# Processing chunk at (4860, 4536)
# Processing chunk at (3456, 2484)
# Processing chunk at (5724, 4968)
# Processing chunk at (1404, 1080)
# Processing chunk at (1296, 4860)Processing chunk at (4536, 3996)
#
# Processing chunk at (972, 324)
# Processing chunk at (5508, 0)
# Processing chunk at (3348, 2376)Processing chunk at (1296, 972)
#
# Processing chunk at (4212, 2808)
# Processing chunk at (2160, 1404)
# Processing chunk at (2052, 5184)Processing chunk at (0, 3780)
#
# Processing chunk at (2916, 5616)Processing chunk at (864, 4212)
# Processing chunk at (1728, 4644)Processing chunk at (5400, 3888)
# Processing chunk at (540, 3024)
#
#
# Processing chunk at (2808, 5508)
# Processing chunk at (3780, 2160)Processing chunk at (3672, 5940)
# Processing chunk at (1620, 4536)
# Processing chunk at (2484, 4968)Processing chunk at (3024, 1296)
# Processing chunk at (3888, 1728)
# Processing chunk at (1836, 324)
#
# Processing chunk at (2700, 756)
#
# Processing chunk at (4968, 3240)
# Processing chunk at (5832, 3672)
# Processing chunk at (1404, 3564)
# Processing chunk at (108, 2376)
# Processing chunk at (972, 2808)
# Processing chunk at (4644, 2052)
# Processing chunk at (2592, 648)
# Processing chunk at (5508, 2484)
# Processing chunk at (3456, 1080)Processing chunk at (3348, 4860)
#
# Processing chunk at (1296, 3456)
# Processing chunk at (4212, 5292)Processing chunk at (2160, 3888)
#
# Processing chunk at (4212, 1404)Processing chunk at (2052, 3780)
#
# Processing chunk at (648, 1728)Processing chunk at (2916, 4212)
#
# Processing chunk at (3780, 4644)
# Processing chunk at (4320, 972)
# Processing chunk at (1728, 3240)
# Processing chunk at (3132, 0)
# Processing chunk at (5400, 2484)Processing chunk at (3996, 432)
#
# Processing chunk at (1836, 2808)
# Processing chunk at (4104, 5292)
# Processing chunk at (4968, 5724)
# Processing chunk at (540, 1620)Processing chunk at (5076, 1296)
# Processing chunk at (108, 4860)
# Processing chunk at (5940, 1728)
# Processing chunk at (972, 5292)Processing chunk at (3888, 324)
#
#
# Processing chunk at (4752, 756)Processing chunk at (4644, 4536)
#
# Processing chunk at (2592, 3132)
# Processing chunk at (3456, 3564)
# Processing chunk at (1404, 2160)
# Processing chunk at (1296, 5940)
# Processing chunk at (972, 1404)
# Processing chunk at (4644, 648)
# Processing chunk at (216, 540)
# Processing chunk at (5508, 1080)Processing chunk at (1080, 972)
#
# Processing chunk at (3348, 3456)
# Processing chunk at (4212, 3888)
# Processing chunk at (2160, 2484)
# Processing chunk at (0, 4860)
# Processing chunk at (864, 5292)
# Processing chunk at (2268, 2052)
# Processing chunk at (1728, 5724)
# Processing chunk at (5400, 4968)
# Processing chunk at (648, 324)Processing chunk at (540, 4104)
#
# Processing chunk at (5184, 0)
# Processing chunk at (5076, 3780)
# Processing chunk at (3024, 2376)Processing chunk at (3888, 2808)
# Processing chunk at (1836, 1404)Processing chunk at (4752, 3240)
#
# Processing chunk at (2700, 1836)
#
# Processing chunk at (2592, 5616)Processing chunk at (5832, 4752)
# Processing chunk at (1404, 4644)
# Processing chunk at (108, 3456)
#
# Processing chunk at (972, 3888)
# Processing chunk at (5940, 324)
# Processing chunk at (1512, 216)
# Processing chunk at (4644, 3132)
# Processing chunk at (2592, 1728)
# Processing chunk at (5508, 3564)
# Processing chunk at (3456, 2160)Processing chunk at (3348, 5940)
# Processing chunk at (1296, 4536)
# Processing chunk at (2160, 4968)
#
# Processing chunk at (1944, 0)
# Processing chunk at (648, 2808)
# Processing chunk at (4320, 2052)
# Processing chunk at (3780, 5724)
# Processing chunk at (2268, 648)
# Processing chunk at (5184, 2484)
# Processing chunk at (3132, 1080)Processing chunk at (3024, 4860)
# Processing chunk at (3996, 1512)Processing chunk at (1836, 3888)
#
# Processing chunk at (2700, 4320)Processing chunk at (540, 2700)
#
# Processing chunk at (5076, 2376)Processing chunk at (108, 5940)Processing chunk at (3024, 972)
# Processing chunk at (5940, 2808)
#
#
#
# Processing chunk at (3888, 1404)
# Processing chunk at (4752, 1836)Processing chunk at (4644, 5616)
# Processing chunk at (2700, 432)Processing chunk at (2592, 4212)
#
#
# Processing chunk at (3456, 4644)Processing chunk at (1404, 3240)
# Processing chunk at (216, 1620)
#
# Processing chunk at (5508, 2160)
# Processing chunk at (1080, 2052)
# Processing chunk at (1944, 2484)
# Processing chunk at (4212, 4968)
# Processing chunk at (5616, 1728)
# Processing chunk at (3564, 324)
# Processing chunk at (4428, 756)
# Processing chunk at (5292, 1188)
# Processing chunk at (2268, 3132)Processing chunk at (3132, 3564)
#
# Processing chunk at (648, 1404)
# Processing chunk at (540, 5184)
# Processing chunk at (4320, 648)Processing chunk at (5184, 1080)Processing chunk at (5076, 4860)Processing chunk at (3024, 3456)
#
#
# Processing chunk at (5940, 5292)
# Processing chunk at (3996, 108)
# Processing chunk at (3888, 3888)
#
# Processing chunk at (1836, 2484)Processing chunk at (4752, 4320)
#
# Processing chunk at (2700, 2916)Processing chunk at (1404, 5724)Processing chunk at (5940, 1404)
#
#
# Processing chunk at (1512, 1296)
# Processing chunk at (972, 4968)
# Processing chunk at (2376, 1728)
# Processing chunk at (324, 324)Processing chunk at (4644, 4212)
#
# Processing chunk at (216, 4104)
# Processing chunk at (1188, 756)
# Processing chunk at (5508, 4644)
# Processing chunk at (3456, 3240)
# Processing chunk at (4860, 0)
# Processing chunk at (5724, 432)Processing chunk at (3564, 2808)
#
# Processing chunk at (216, 216)
# Processing chunk at (1080, 648)
# Processing chunk at (1944, 1080)
# Processing chunk at (5616, 324)
# Processing chunk at (648, 3888)
# Processing chunk at (4320, 3132)Processing chunk at (2268, 1728)
# Processing chunk at (5184, 3564)
#
# Processing chunk at (3132, 2160)Processing chunk at (3024, 5940)
# Processing chunk at (3996, 2592)Processing chunk at (1836, 4968)Processing chunk at (2700, 5400)
# Processing chunk at (2808, 972)
# Processing chunk at (5076, 3456)
#
# Processing chunk at (1620, 0)
#
#
# Processing chunk at (5940, 3888)Processing chunk at (3888, 2484)
# Processing chunk at (2484, 432)
#
# Processing chunk at (4752, 2916)Processing chunk at (324, 2808)
# Processing chunk at (2592, 5292)
#
# Processing chunk at (3456, 5724)Processing chunk at (2376, 324)
# Processing chunk at (3240, 756)
#
# Processing chunk at (216, 2700)
# Processing chunk at (1080, 3132)
# Processing chunk at (1944, 3564)
# Processing chunk at (5616, 2808)
# Processing chunk at (3564, 1404)Processing chunk at (4428, 1836)
#
# Processing chunk at (4320, 5616)
# Processing chunk at (2268, 4212)
# Processing chunk at (5292, 2268)
# Processing chunk at (3132, 4644)
# Processing chunk at (3996, 5076)
# Processing chunk at (4320, 1728)Processing chunk at (5076, 5940)
# Processing chunk at (5184, 2160)
#
# Processing chunk at (756, 2052)
# Processing chunk at (3024, 4536)
# Processing chunk at (3996, 1188)
# Processing chunk at (3888, 4968)
# Processing chunk at (4752, 5400)Processing chunk at (432, 1512)
# Processing chunk at (2700, 3996)
# Processing chunk at (4104, 756)
#
# Processing chunk at (3672, 0)
# Processing chunk at (1512, 2376)
# Processing chunk at (2376, 2808)Processing chunk at (216, 5184)
#
# Processing chunk at (324, 1404)
# Processing chunk at (3240, 3240)Processing chunk at (5508, 5724)Processing chunk at (1188, 1836)
# Processing chunk at (1080, 5616)
#
#
# Processing chunk at (4860, 1080)
# Processing chunk at (5724, 1512)
# Processing chunk at (3564, 3888)
# Processing chunk at (4536, 540)
# Processing chunk at (4428, 4320)Processing chunk at (1080, 1728)
#
# Processing chunk at (1944, 2160)
# Processing chunk at (5616, 1404)
# Processing chunk at (648, 4968)
# Processing chunk at (4320, 4212)
# Processing chunk at (4428, 432)
# Processing chunk at (0, 324)
# Processing chunk at (5184, 4644)
# Processing chunk at (5292, 864)
# Processing chunk at (864, 756)Processing chunk at (3132, 3240)Processing chunk at (3996, 3672)
# Processing chunk at (2808, 2052)Processing chunk at (756, 648)
#
#
#
# Processing chunk at (3672, 2484)Processing chunk at (5940, 4968)
# Processing chunk at (1620, 1080)Processing chunk at (1512, 4860)
#
# Processing chunk at (2484, 1512)Processing chunk at (2376, 5292)
# Processing chunk at (432, 108)
#
# Processing chunk at (324, 3888)Processing chunk at (1188, 4320)Processing chunk at (4860, 3564)
# Processing chunk at (5832, 216)
# Processing chunk at (1512, 972)
#
#
# Processing chunk at (4536, 3024)
#
# Processing chunk at (2376, 1404)
# Processing chunk at (216, 3780)Processing chunk at (3240, 1836)
#
# Processing chunk at (1188, 432)
# Processing chunk at (1080, 4212)
# Processing chunk at (1944, 4644)
# Processing chunk at (5724, 108)
# Processing chunk at (5616, 3888)Processing chunk at (1296, 0)
#
# Processing chunk at (3564, 2484)
# Processing chunk at (4428, 2916)
# Processing chunk at (5292, 3348)
# Processing chunk at (2268, 5292)
# Processing chunk at (3132, 5724)
# Processing chunk at (2052, 324)Processing chunk at (2916, 756)Processing chunk at (2808, 4536)Processing chunk at (3780, 1188)
#
# Processing chunk at (756, 3132)
# Processing chunk at (1620, 3564)
#
# Processing chunk at (432, 2592)
#
# Processing chunk at (4104, 1836)Processing chunk at (4968, 2268)
#
# Processing chunk at (2808, 648)Processing chunk at (3672, 1080)Processing chunk at (1512, 3456)
# Processing chunk at (2484, 108)Processing chunk at (2376, 3888)
#
# Processing chunk at (324, 2484)Processing chunk at (3240, 4320)
#
# Processing chunk at (1188, 2916)
#
# Processing chunk at (4860, 2160)Processing chunk at (5724, 2592)
# Processing chunk at (3564, 4968)
#
# Processing chunk at (4536, 1620)
#
# Processing chunk at (4428, 5400)
# Processing chunk at (5292, 5832)
# Processing chunk at (3348, 0)Processing chunk at (4212, 432)
# Processing chunk at (2052, 2808)
# Processing chunk at (4320, 5292)
#
# Processing chunk at (0, 1404)
# Processing chunk at (5184, 5724)
# Processing chunk at (864, 1836)
# Processing chunk at (756, 5616)
# Processing chunk at (1728, 2268)
# Processing chunk at (3996, 4752)Processing chunk at (5400, 1512)Processing chunk at (432, 5076)
# Processing chunk at (4104, 4320)
# Processing chunk at (2808, 3132)
# Processing chunk at (756, 1728)
# Processing chunk at (3672, 3564)Processing chunk at (1620, 2160)
# Processing chunk at (1512, 5940)
#
#
# Processing chunk at (2484, 2592)Processing chunk at (432, 1188)Processing chunk at (324, 4968)
# Processing chunk at (1188, 5400)
#
# Processing chunk at (4104, 432)
# Processing chunk at (4968, 864)
#
# Processing chunk at (4860, 4644)Processing chunk at (5832, 1296)
#
# Processing chunk at (5724, 5076)
# Processing chunk at (4536, 4104)Processing chunk at (108, 0)
#
# Processing chunk at (972, 432)
# Processing chunk at (3240, 2916)
#
# Processing chunk at (1080, 5292)Processing chunk at (1944, 5724)
#
# Processing chunk at (5724, 1188)
# Processing chunk at (5616, 4968)
# Processing chunk at (1296, 1080)
# Processing chunk at (2160, 1512)
# Processing chunk at (4428, 3996)
# Processing chunk at (0, 3888)
# Processing chunk at (5292, 4428)
# Processing chunk at (864, 4320)
# Processing chunk at (2052, 1404)
# Processing chunk at (3780, 2268)
# Processing chunk at (2916, 1836)
# Processing chunk at (2808, 5616)Processing chunk at (864, 432)
# Processing chunk at (756, 4212)
# Processing chunk at (1728, 864)
# Processing chunk at (1620, 4644)
# Processing chunk at (2484, 5076)
# Processing chunk at (5400, 108)Processing chunk at (432, 3672)
#
# Processing chunk at (4104, 2916)Processing chunk at (4968, 3348)
# Processing chunk at (5832, 3780)
#
#
# Processing chunk at (3672, 2160)Processing chunk at (1512, 4536)Processing chunk at (108, 2484)
#
#
# Processing chunk at (2376, 4968)Processing chunk at (3240, 5400)
# Processing chunk at (1188, 3996)
#
# Processing chunk at (2592, 756)
# Processing chunk at (4860, 3240)
# Processing chunk at (5724, 3672)
# Processing chunk at (1296, 3564)
# Processing chunk at (4536, 2700)
# Processing chunk at (3348, 1080)
# Processing chunk at (4212, 1512)
# Processing chunk at (2160, 108)
# Processing chunk at (2052, 3888)
# Processing chunk at (0, 2484)
# Processing chunk at (2916, 4320)
# Processing chunk at (864, 2916)Processing chunk at (3780, 4752)Processing chunk at (1728, 3348)Processing chunk at (5400, 2592)Processing chunk at (4104, 5400)
# ...
# Processing chunk at (2808, 4536)
# Processing chunk at (4212, 1296)Processing chunk at (2916, 108)
# Processing chunk at (3780, 540)Processing chunk at (1620, 2916)
#
#
# Processing chunk at (2484, 3348)Processing chunk at (3348, 3780)
# Processing chunk at (432, 1944)
#
# Processing chunk at (324, 5724)
# Processing chunk at (1296, 2376)Processing chunk at (4968, 1620)Processing chunk at (0, 5184)
#
# Processing chunk at (5832, 2052)
#
# Processing chunk at (5724, 5832)Processing chunk at (3672, 4428)
#
# Processing chunk at (4644, 1080)
# Processing chunk at (4536, 4860)Processing chunk at (5400, 5292)Processing chunk at (2052, 2700)
#
#
# Processing chunk at (5724, 1944)Processing chunk at (756, 5508)Processing chunk at (4536, 972)
#
# Processing chunk at (4428, 4752)
# Processing chunk at (108, 864)Processing chunk at (5400, 1404)
#
#
# Processing chunk at (5292, 5184)
# Processing chunk at (972, 1296)
# Processing chunk at (3240, 3780)
# Processing chunk at (4104, 4212)
# Processing chunk at (2916, 2592)
# Processing chunk at (864, 1188)
# Processing chunk at (3780, 3024)
# Processing chunk at (1728, 1620)
# Processing chunk at (1620, 5400)
# Processing chunk at (2592, 2052)
# Processing chunk at (2484, 5832)Processing chunk at (540, 648)
# Processing chunk at (432, 4428)
# Processing chunk at (1296, 4860)
#
# Processing chunk at (5076, 324)
# Processing chunk at (4968, 4104)
# Processing chunk at (5940, 756)
# Processing chunk at (5832, 4536)
# Processing chunk at (4644, 3564)Processing chunk at (2484, 1944)
#
# Processing chunk at (3348, 2376)Processing chunk at (324, 4320)
#
# Processing chunk at (1188, 4752)Processing chunk at (2052, 5184)
# Processing chunk at (0, 3780)Processing chunk at (4968, 216)
#
# Processing chunk at (5832, 648)Processing chunk at (5724, 4428)
#
# Processing chunk at (1404, 540)Processing chunk at (3672, 3024)
#
# Processing chunk at (4536, 3456)
# Processing chunk at (108, 3348)
#
# Processing chunk at (5400, 3888)
# Processing chunk at (2376, 5832)
# Processing chunk at (2160, 864)Processing chunk at (3024, 1296)
#
# Processing chunk at (2916, 5076)
# Processing chunk at (3888, 1728)
# Processing chunk at (864, 3672)Processing chunk at (1836, 324)
#
# Processing chunk at (1728, 4104)Processing chunk at (2592, 4536)
# Processing chunk at (540, 3132)Processing chunk at (4212, 2376)Processing chunk at (5076, 2808)
#
# Processing chunk at (2916, 1188)
#
# Processing chunk at (3780, 1620)
#
# Processing chunk at (1728, 216)
# Processing chunk at (1620, 3996)
# Processing chunk at (2592, 648)
# Processing chunk at (2484, 4428)Processing chunk at (432, 3024)Processing chunk at (3348, 4860)Processing chunk at (1296, 3456)
# Processing chunk at (4968, 2700)Processing chunk at (5832, 3132)
# Processing chunk at (3672, 5508)Processing chunk at (4644, 2160)
#
#
#
# Processing chunk at (4536, 5940)Processing chunk at (3456, 540)
#
#
# Processing chunk at (4320, 972)Processing chunk at (4428, 5832)Processing chunk at (2160, 3348)
#
#
# Processing chunk at (3132, 0)
# Processing chunk at (108, 1944)
#
# Processing chunk at (3024, 3780)
# Processing chunk at (972, 2376)Processing chunk at (1836, 2808)
#
# Processing chunk at (4104, 5292)
# Processing chunk at (5508, 2052)Processing chunk at (540, 5616)Processing chunk at (4212, 4860)Processing chunk at (2916, 3672)
# Processing chunk at (3888, 324)Processing chunk at (864, 2268)
# Processing chunk at (3780, 4104)
# Processing chunk at (1728, 2700)Processing chunk at (2592, 3132)
#
#
# Processing chunk at (540, 1728)Processing chunk at (432, 5508)
#
#
# Processing chunk at (1296, 5940)Processing chunk at (4212, 972)Processing chunk at (5076, 1404)
# Processing chunk at (4968, 5184)
#
#
# Processing chunk at (5940, 1836)
# Processing chunk at (5832, 5616)
# Processing chunk at (4644, 4644)
#
# Processing chunk at (216, 540)
# Processing chunk at (1080, 972)
# Processing chunk at (3348, 3456)Processing chunk at (4752, 216)Processing chunk at (1188, 5832)
#
# Processing chunk at (3456, 3024)
#
# Processing chunk at (5724, 5508)
#
# Processing chunk at (1404, 1620)Processing chunk at (2268, 2052)
#
# Processing chunk at (4536, 4536)
# Processing chunk at (108, 4428)
# Processing chunk at (5400, 4968)
# Processing chunk at (972, 4860)
# Processing chunk at (2160, 1944)Processing chunk at (3024, 2376)
# Processing chunk at (3888, 2808)Processing chunk at (972, 972)
#
#
# Processing chunk at (864, 4752)
# Processing chunk at (1836, 1404)Processing chunk at (1728, 5184)
# Processing chunk at (2592, 5616)
# Processing chunk at (5508, 648)Processing chunk at (540, 4212)Processing chunk at (4212, 3456)
#
#
#
# Processing chunk at (5076, 3888)Processing chunk at (5940, 4320)Processing chunk at (3780, 2700)
#
# Processing chunk at (1620, 5076)Processing chunk at (216, 3024)
# Processing chunk at (2484, 5508)
#
# Processing chunk at (3348, 5940)Processing chunk at (1296, 4536)
# Processing chunk at (2700, 1296)Processing chunk at (4968, 3780)
# Processing chunk at (5832, 4212)Processing chunk at (1512, 324)
#
#
# Processing chunk at (1404, 4104)
# Processing chunk at (4644, 3240)
#
#
# Processing chunk at (3456, 1620)
# Processing chunk at (1404, 216)
# Processing chunk at (4320, 2052)
# Processing chunk at (2268, 648)
# Processing chunk at (2160, 4428)
# Processing chunk at (3132, 1080)Processing chunk at (108, 3024)
# Processing chunk at (3024, 4860)
#
# Processing chunk at (972, 3456)Processing chunk at (3888, 5292)
#
# Processing chunk at (1836, 3888)
# Processing chunk at (5508, 3132)
# Processing chunk at (4212, 5940)Processing chunk at (648, 2268)Processing chunk at (2916, 4752)
#
# Processing chunk at (3888, 1404)
#
# Processing chunk at (3780, 5184)
# Processing chunk at (1728, 3780)Processing chunk at (2592, 4212)Processing chunk at (2808, 0)
# Processing chunk at (5076, 2484)
# Processing chunk at (5940, 2916)Processing chunk at (1512, 2808)
#
# Processing chunk at (4644, 5724)
# Processing chunk at (216, 1620)
#
# Processing chunk at (1080, 2052)Processing chunk at (4752, 1296)
#
# Processing chunk at (5616, 1728)Processing chunk at (3564, 324)
#
# Processing chunk at (3456, 4104)
# Processing chunk at (1404, 2700)
#
# Processing chunk at (2268, 3132)
# Processing chunk at (4320, 4536)
# Processing chunk at (3132, 3564)
# Processing chunk at (108, 5508)
# Processing chunk at (972, 5940)Processing chunk at (5508, 5616)
#
# Processing chunk at (4320, 648)Processing chunk at (2160, 3024)
# Processing chunk at (756, 972)
#
# Processing chunk at (3024, 3456)
# Processing chunk at (3888, 3888)Processing chunk at (864, 5832)Processing chunk at (1836, 2484)
#
# Processing chunk at (5508, 1728)Processing chunk at (540, 5292)Processing chunk at (1944, 2052)
#
#
# Processing chunk at (4212, 4536)
# Processing chunk at (5076, 4968)
# Processing chunk at (648, 864)
# Processing chunk at (5940, 5400)
# Processing chunk at (5184, 540)
#
# Processing chunk at (216, 4104)Processing chunk at (1080, 4536)Processing chunk at (4860, 0)
#
#
# Processing chunk at (4752, 3780)Processing chunk at (2700, 2376)Processing chunk at (3564, 2808)
# Processing chunk at (5832, 5292)Processing chunk at (1512, 1404)
# Processing chunk at (1404, 5184)
#
#
# Processing chunk at (2268, 5616)
# Processing chunk at (1080, 648)
#
# Processing chunk at (5616, 324)Processing chunk at (1188, 216)
#
# Processing chunk at (3456, 2700)
# Processing chunk at (4320, 3132)
# Processing chunk at (2268, 1728)
# Processing chunk at (2160, 5508)Processing chunk at (3132, 2160)Processing chunk at (108, 4104)
# Processing chunk at (3024, 5940)
#
#
# Processing chunk at (972, 4536)Processing chunk at (2376, 1296)Processing chunk at (1836, 4968)Processing chunk at (5508, 4212)
# Processing chunk at (648, 3348)
#
#
#
# Processing chunk at (2916, 5832)Processing chunk at (5184, 3024)
#
# Processing chunk at (2592, 5292)Processing chunk at (3996, 2052)
# Processing chunk at (1944, 648)
# Processing chunk at (4860, 2484)
# Processing chunk at (2808, 1080)Processing chunk at (2700, 4860)
# Processing chunk at (5940, 3996)Processing chunk at (1512, 3888)
# Processing chunk at (216, 2700)Processing chunk at (1080, 3132)
#
#
#
#
# Processing chunk at (4752, 2376)Processing chunk at (2700, 972)
#
# Processing chunk at (5616, 2808)Processing chunk at (3564, 1404)
# Processing chunk at (3456, 5184)
#
# Processing chunk at (1404, 3780)Processing chunk at (4320, 5616)
#
# Processing chunk at (2268, 4212)
# Processing chunk at (3132, 4644)
# Processing chunk at (756, 2052)Processing chunk at (3024, 4536)Processing chunk at (4428, 1296)
#
#
# Processing chunk at (3888, 4968)Processing chunk at (5292, 1728)
# Processing chunk at (3240, 324)
#
# Processing chunk at (4104, 756)Processing chunk at (1944, 3132)
# Processing chunk at (4212, 5616)
# Processing chunk at (2808, 3564)Processing chunk at (648, 1944)
# Processing chunk at (5184, 1620)
# Processing chunk at (216, 5184)
#
#
# Processing chunk at (1080, 5616)Processing chunk at (3996, 648)Processing chunk at (4860, 1080)Processing chunk at (4752, 4860)
#
# Processing chunk at (2700, 3456)
#
#
# Processing chunk at (5616, 5292)
# Processing chunk at (3564, 3888)
# Processing chunk at (1512, 2484)
# Processing chunk at (324, 864)Processing chunk at (5616, 1404)
#
# Processing chunk at (1188, 1296)Processing chunk at (3456, 3780)Processing chunk at (2052, 1728)
#
# Processing chunk at (4320, 4212)
#
# Processing chunk at (0, 324)
# Processing chunk at (5724, 972)Processing chunk at (3132, 3240)
#
# Processing chunk at (4536, 0)
# Processing chunk at (5400, 432)Processing chunk at (2376, 2376)Processing chunk at (3240, 2808)
# Processing chunk at (5508, 5292)
#
# Processing chunk at (756, 648)
# Processing chunk at (648, 4428)Processing chunk at (5292, 324)Processing chunk at (5184, 4104)
# Processing chunk at (3996, 3132)
#
#
# Processing chunk at (1944, 1728)
# Processing chunk at (4860, 3564)
#
# Processing chunk at (2808, 2160)Processing chunk at (2700, 5940)
# Processing chunk at (1512, 4968)Processing chunk at (216, 3780)
# Processing chunk at (1620, 540)
# Processing chunk at (1080, 4212)
# Processing chunk at (2484, 972)
#
#
# Processing chunk at (4752, 3456)
# Processing chunk at (324, 3348)
# Processing chunk at (5616, 3888)Processing chunk at (1296, 0)
#
# Processing chunk at (3564, 2484)Processing chunk at (0, 2808)
# Processing chunk at (2268, 5292)
# Processing chunk at (3672, 2052)Processing chunk at (3132, 5724)
# Processing chunk at (2052, 324)Processing chunk at (756, 3132)
#
#
# Processing chunk at (4428, 2376)Processing chunk at (2376, 972)Processing chunk at (5292, 2808)
#
# Processing chunk at (3240, 1404)
#
#
# Processing chunk at (4104, 1836)Processing chunk at (3996, 5616)Processing chunk at (1944, 4212)Processing chunk at (2808, 4644)
#
# Processing chunk at (648, 3024)
#
# Processing chunk at (2916, 216)Processing chunk at (5184, 2700)Processing chunk at (3996, 1728)
# Processing chunk at (4860, 2160)Processing chunk at (4752, 5940)Processing chunk at (432, 2052)
#
#
# Processing chunk at (2700, 4536)
# Processing chunk at (3564, 4968)
#
#
#
# Processing chunk at (1512, 3564)
# Processing chunk at (3348, 0)Processing chunk at (324, 1944)
#
# Processing chunk at (1188, 2376)Processing chunk at (2052, 2808)
#
# Processing chunk at (0, 1404)
# Processing chunk at (5724, 2052)
# Processing chunk at (756, 5616)
# Processing chunk at (3672, 648)Processing chunk at (4536, 1080)
# Processing chunk at (4428, 4860)
# Processing chunk at (5400, 1512)
#
# Processing chunk at (2376, 3456)Processing chunk at (3240, 3888)Processing chunk at (4104, 4320)
# Processing chunk at (756, 1728)
# Processing chunk at (648, 5508)
# Processing chunk at (4428, 972)
#
# Processing chunk at (5292, 1404)
#
# Processing chunk at (5184, 5184)
# Processing chunk at (864, 1296)
# Processing chunk at (4104, 432)
# Processing chunk at (3996, 4212)Processing chunk at (4860, 4644)
#
# Processing chunk at (1944, 2808)Processing chunk at (540, 756)
#
# Processing chunk at (2808, 3240)Processing chunk at (4212, 0)
#
# Processing chunk at (1620, 1620)Processing chunk at (2484, 2052)
#
# Processing chunk at (3348, 2484)
# Processing chunk at (432, 648)
# Processing chunk at (324, 4428)
# Processing chunk at (5616, 4968)
# Processing chunk at (1296, 1080)
# Processing chunk at (1188, 4860)
# Processing chunk at (4968, 324)
# Processing chunk at (0, 3888)Processing chunk at (5832, 756)
#
# Processing chunk at (3672, 3132)
# Processing chunk at (4536, 3564)
# Processing chunk at (2376, 5940)Processing chunk at (2052, 1404)Processing chunk at (5724, 648)Processing chunk at (756, 4212)
# Processing chunk at (5400, 108)Processing chunk at (4428, 3456)
#
# Processing chunk at (5292, 3888)
# Processing chunk at (2376, 2052)Processing chunk at (1188, 972)
# Processing chunk at (972, 0)
#
# Processing chunk at (3240, 2484)
#
# Processing chunk at (4104, 2916)Processing chunk at (1944, 5292)
# Processing chunk at (2808, 5724)
# Processing chunk at (2916, 1296)
#
#
# Processing chunk at (3780, 1728)Processing chunk at (1728, 324)
#
# Processing chunk at (1620, 4104)
# Processing chunk at (2592, 756)
# Processing chunk at (4860, 3240)
#
# Processing chunk at (432, 3132)Processing chunk at (1296, 3564)
#
# Processing chunk at (4968, 2808)
# Processing chunk at (1620, 216)
# Processing chunk at (4644, 2268)
# Processing chunk at (2484, 648)
# Processing chunk at (3348, 1080)Processing chunk at (324, 3024)
#
# Processing chunk at (1188, 3456)
# Processing chunk at (2052, 3888)Processing chunk at (0, 2484)Processing chunk at (5724, 3132)
#
# Processing chunk at (3672, 1728)Processing chunk at (4536, 2160)
# Processing chunk at (4428, 5940)
#
#
# Processing chunk at (5400, 2592)Processing chunk at (2376, 4536)Processing chunk at (3240, 4968)
# Processing chunk at (4104, 5400)
# Processing chunk at (3024, 0)Processing chunk at (5292, 2484)
#
# Processing chunk at (3888, 432)Processing chunk at (864, 2376)
#
#
#
# Processing chunk at (1728, 2808)Processing chunk at (3996, 5292)
#
# Processing chunk at (4860, 5724)
# Processing chunk at (540, 1836)Processing chunk at (432, 5616)Processing chunk at (4212, 1080)
#
# Processing chunk at (5076, 1512)
#
# Processing chunk at (3780, 324)
# Processing chunk at (1620, 2700)
# Processing chunk at (2484, 3132)Processing chunk at (3348, 3564)
#
# Processing chunk at (432, 1728)
# Processing chunk at (324, 5508)
# Processing chunk at (1296, 2160)
# Processing chunk at (1188, 5940)
# Processing chunk at (4968, 1404)Processing chunk at (0, 4968)Processing chunk at (5832, 1836)
# Processing chunk at (5724, 5616)
# Processing chunk at (3672, 4212)
# Processing chunk at (4644, 864)Processing chunk at (4536, 4644)
#
# Processing chunk at (5400, 5076)Processing chunk at (5724, 1728)
# Processing chunk at (756, 5292)
#
# Processing chunk at (2160, 2052)
#
# Processing chunk at (4428, 4536)
# Processing chunk at (108, 648)
#
# Processing chunk at (5400, 1188)Processing chunk at (5292, 4968)Processing chunk at (972, 1080)Processing chunk at (864, 4860)
#
#
#
# Processing chunk at (1836, 1512)Processing chunk at (4104, 3996)Processing chunk at (5508, 756)
# Processing chunk at (2916, 2376)
# Processing chunk at (864, 972)
#
# Processing chunk at (3780, 2808)Processing chunk at (1728, 1404)
# Processing chunk at (1620, 5184)
#
# Processing chunk at (2592, 1836)
#
# Processing chunk at (2484, 5616)Processing chunk at (540, 432)
# Processing chunk at (432, 4212)
#
# Processing chunk at (1296, 4644)
# Processing chunk at (5076, 108)
# Processing chunk at (4968, 3888)Processing chunk at (5940, 540)Processing chunk at (5832, 4320)Processing chunk at (4644, 3348)Processing chunk at (3348, 2160)
#
#
#
#
# Processing chunk at (1188, 4536)
# Processing chunk at (2052, 4968)
# Processing chunk at (5832, 432)Processing chunk at (5724, 4212)
# Processing chunk at (1404, 324)
# Processing chunk at (2268, 756)Processing chunk at (4536, 3240)Processing chunk at (108, 3132)
# Processing chunk at (5400, 3672)Processing chunk at (2376, 5616)
#
#
# Processing chunk at (2160, 648)
#
#
# Processing chunk at (3024, 1080)
# Processing chunk at (2916, 4860)Processing chunk at (3888, 1512)Processing chunk at (3780, 5292)
# Processing chunk at (1836, 108)
# Processing chunk at (1728, 3888)
# Processing chunk at (864, 3456)Processing chunk at (2592, 4320)
#
# Processing chunk at (540, 2916)
#
# Processing chunk at (4212, 2160)
# Processing chunk at (5076, 2592)
# Processing chunk at (2916, 972)
# Processing chunk at (5940, 3024)
# Processing chunk at (3780, 1404)
#
# Processing chunk at (1620, 3780)
# Processing chunk at (4644, 5832)
# Processing chunk at (2592, 432)
# Processing chunk at (2484, 4212)
# Processing chunk at (3348, 4644)Processing chunk at (1296, 3240)

# %%
da_stack_gfp = da.from_zarr(f"zt_stack_ch{1}.zarr")
da_stack_rfp = da.from_zarr(f"zt_stack_ch{2}.zarr")
v = napari.Viewer()
v.add_image(da_stack_gfp, name="gfp", contrast_limits = [0,2352], blending = 'additive', colormap= 'green')# colormap = 'g')
v.add_image(da_stack_rfp, name="rfp", contrast_limits = [103,164], blending = 'additive', colormap = 'magenta')
# Out:
# <Image layer 'rfp' at 0x7fdf4fbc3e80>

# %% [markdown]
# ### Testing GPU capacity

# %%
da_stack_gfp = da.from_zarr(f"data/zt_stack_ch{1}.zarr")

# %%
da_stack_gfp_gpu = da_stack_gfp.map_blocks(cp.asarray)
da_stack_gfp_gpu
# Out:
# dask.array<asarray, shape=(3, 75, 6048, 6048), dtype=uint16, chunksize=(1, 1, 2160, 2160), chunktype=cupy.ndarray>

# %%
da_stack_gfp
# Out:
# dask.array<from-zarr, shape=(3, 75, 6048, 6048), dtype=uint16, chunksize=(1, 1, 2160, 2160), chunktype=numpy.ndarray>

# %% [markdown]
# #### Would then need a reason to run an image manipulation on this ``dask_stack_gfp_gpu``
