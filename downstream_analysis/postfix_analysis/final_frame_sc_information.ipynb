# %% [markdown]
# # Saving out SC info for baptiste

# %%
import napari
from macrohet import dataio, tile, tools, visualise, colours
import os, glob
from tqdm.auto import tqdm
from skimage import io
import numpy as np
from macrohet.notify import send_sys_message as notify
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import zarr
import csv

palette = colours.expanded_piyg
sns.set_theme(style = 'white')
sns.set(font='Nimbus Sans', style = 'white')

# Define a function to remove outliers using IQR
def remove_outliers_iqr(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return series[(series >= lower_bound) & (series <= upper_bound)]

# %%
df = pd.read_pickle('/mnt/SYNO/macrohet_syno/results/dfs/sc_df.pkl')

# %%
df
# Out:
#                      ID  Time (hours)  Mtb Area (µm)  dMtb Area (µm)  \
# 138        1.3.2.ND0002           0.0       0.000000        0.000000
# 139        1.3.2.ND0002           0.5       0.000000        0.000000
# 140        1.3.2.ND0002           1.0       0.000000        0.000000
# 141        1.3.2.ND0002           1.5       0.000000        0.000000
# 142        1.3.2.ND0002           2.0       0.000000        0.000000
# ...                 ...           ...            ...             ...
# 1312257  998.5.5.ND0003          48.0       0.000000       -0.111742
# 1312258  998.5.5.ND0003          48.5       0.000000       -0.111742
# 1312259  998.5.5.ND0003          49.0       0.000000       -0.111742
# 1312260  998.5.5.ND0003          49.5       0.000000       -0.111742
# 1312261  998.5.5.ND0003          50.0       0.156439       -0.111742
#
#          Mphi Area (µm)  dMphi Area (µm) Infection Status  \
# 138         4649.351562      2080.574775              NaN
# 139         4973.001953      2080.574775              NaN
# 140         4687.857910      2080.574775              NaN
# 141         4209.064453      2080.574775              NaN
# 142         4061.855225      2080.574775            False
# ...                 ...              ...              ...
# 1312257      813.037051      -539.871799              NaN
# 1312258      745.745831      -539.871799              NaN
# 1312259      668.219016      -539.871799              NaN
# 1312260      662.609552      -539.871799              NaN
# 1312261      642.987603      -539.871799              NaN
#
#          Initial Infection Status  Final Infection Status           x  ...  \
# 138                         False                   False  107.845200  ...
# 139                         False                   False  113.264671  ...
# 140                         False                   False  116.562256  ...
# 141                         False                   False  111.890106  ...
# 142                         False                   False  114.113556  ...
# ...                           ...                     ...         ...  ...
# 1312257                     False                   False  868.403076  ...
# 1312258                     False                   False  868.194641  ...
# 1312259                     False                   False  872.108582  ...
# 1312260                     False                   False  871.521606  ...
# 1312261                     False                   False  871.464844  ...
#
#          Edge Status  Uptake  dMtb Area between frames (µm)  \
# 138            False   False                            NaN
# 139            False   False                       0.000000
# 140            False   False                       0.000000
# 141            False   False                       0.000000
# 142            False   False                       0.000000
# ...              ...     ...                            ...
# 1312257        False   False                       0.000000
# 1312258        False   False                       0.000000
# 1312259        False   False                       0.000000
# 1312260        False   False                       0.000000
# 1312261        False   False                       0.156439
#
#          Mtb Area Processed (µm)  Time Model (hours)  Mtb Area Model (µm)  \
# 138                          NaN                 NaN                  NaN
# 139                          NaN                 NaN                  NaN
# 140                          NaN                 NaN                  NaN
# 141                          NaN                 NaN                  NaN
# 142                          NaN                 0.0                  0.0
# ...                          ...                 ...                  ...
# 1312257                      0.0                 NaN                  NaN
# 1312258                      0.0                 NaN                  NaN
# 1312259                      0.0                 NaN                  NaN
# 1312260                      0.0                 NaN                  NaN
# 1312261                      0.0                 NaN                  NaN
#
#          mtb_origin Doubling Amounts Doubling Times    r2
# 138            None             None           None   1.0
# 139            None             None           None   1.0
# 140            None             None           None   1.0
# 141            None             None           None   1.0
# 142            None             None           None   1.0
# ...             ...              ...            ...   ...
# 1312257        None             None           None  0.78
# 1312258        None             None           None  0.78
# 1312259        None             None           None  0.78
# 1312260        None             None           None  0.78
# 1312261        None             None           None  0.78
#
# [1092545 rows x 34 columns]

# %%
sorted(df[df['Experiment ID'] == 'ND0003']['Acquisition ID'].unique())
# Out:
# [(3, 1),
#  (3, 2),
#  (3, 3),
#  (3, 4),
#  (3, 5),
#  (3, 6),
#  (3, 7),
#  (3, 8),
#  (3, 9),
#  (3, 10),
#  (4, 3),
#  (4, 4),
#  (4, 5),
#  (4, 6),
#  (4, 7),
#  (4, 8),
#  (4, 9),
#  (4, 10),
#  (5, 3),
#  (5, 4),
#  (5, 5),
#  (5, 6),
#  (5, 7),
#  (5, 8),
#  (5, 9),
#  (5, 10),
#  (6, 3),
#  (6, 4),
#  (6, 5),
#  (6, 6),
#  (6, 7),
#  (6, 8),
#  (6, 9),
#  (6, 10)]

# %%
for expt_ID in ['PS0000', 'ND0002', 'ND0003']:

    subset_df = df[df['Experiment ID'] == expt_ID]

    subset_df = subset_df.drop_duplicates(subset = 'ID', keep = 'last')
    
    # ensure that only the final frame measuremnets are included
    subset_df = subset_df[subset_df['Time (hours)'] == subset_df['Time (hours)'].max()]

    # Ensure the required columns are in the DataFrame
    columns_to_save = ['Mtb Area (µm)', 'ID', 'Acquisition ID', 'Compound', 'Concentration', 'Strain', 'mtb_origin', 'r2', 'Doubling Times', 'Doubling Amounts']
    
    # Save the subset DataFrame to a CSV file, including the index
    subset_df.to_csv(f'/mnt/SYNO/macrohet_syno/results/final_frame_mtb_values_csvs/{expt_ID}_final_frame_mtb_values.csv', columns=columns_to_save, index=True)

# %% [markdown]
# ### Troubleshooting ND3 5,3 -> 5,8

# %%
expt_ID = 'ND0003'

# %%
subset_df = df[df['Experiment ID'] == expt_ID]

# %%
df[(df['Experiment ID'] == 'ND0003') & (df['Acquisition ID'] ==(5, 3))]['Time (hours)'].max()
# Out:
# 74.5

# %%
sorted(subset_df['Acquisition ID'].unique())
# Out:
# [(3, 1),
#  (3, 2),
#  (3, 3),
#  (3, 4),
#  (3, 5),
#  (3, 6),
#  (3, 7),
#  (3, 8),
#  (3, 9),
#  (3, 10),
#  (4, 3),
#  (4, 4),
#  (4, 5),
#  (4, 6),
#  (4, 7),
#  (4, 8),
#  (4, 9),
#  (4, 10),
#  (5, 3),
#  (5, 4),
#  (5, 5),
#  (5, 6),
#  (5, 7),
#  (5, 8),
#  (5, 9),
#  (5, 10),
#  (6, 3),
#  (6, 4),
#  (6, 5),
#  (6, 6),
#  (6, 7),
#  (6, 8),
#  (6, 9),
#  (6, 10)]

# %%
subset_df = subset_df.drop_duplicates(subset = 'ID', keep = 'last')

# %%
sorted(subset_df['Acquisition ID'].unique())
# Out:
# [(3, 1),
#  (3, 2),
#  (3, 3),
#  (3, 4),
#  (3, 5),
#  (3, 6),
#  (3, 7),
#  (3, 8),
#  (3, 9),
#  (3, 10),
#  (4, 3),
#  (4, 4),
#  (4, 5),
#  (4, 6),
#  (4, 7),
#  (4, 8),
#  (4, 9),
#  (4, 10),
#  (5, 3),
#  (5, 4),
#  (5, 5),
#  (5, 6),
#  (5, 7),
#  (5, 8),
#  (5, 9),
#  (5, 10),
#  (6, 3),
#  (6, 4),
#  (6, 5),
#  (6, 6),
#  (6, 7),
#  (6, 8),
#  (6, 9),
#  (6, 10)]

# %%
# ensure that only the final frame measuremnets are included
subset_df = subset_df[subset_df['Time (hours)'] == subset_df['Time (hours)'].max()]

# %%
sorted(subset_df['Acquisition ID'].unique())
# Out:
# [(3, 1),
#  (3, 2),
#  (3, 3),
#  (3, 4),
#  (3, 5),
#  (3, 6),
#  (3, 7),
#  (3, 8),
#  (3, 9),
#  (3, 10),
#  (4, 3),
#  (4, 4),
#  (4, 5),
#  (4, 6),
#  (4, 7),
#  (4, 8),
#  (4, 9),
#  (4, 10),
#  (5, 8),
#  (5, 9),
#  (5, 10),
#  (6, 3),
#  (6, 4),
#  (6, 5),
#  (6, 6),
#  (6, 7),
#  (6, 8),
#  (6, 9),
#  (6, 10)]
