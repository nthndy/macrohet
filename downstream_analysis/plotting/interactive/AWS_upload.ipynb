# %%
import glob
import os
from macrohet import aws_tools
from tqdm.auto import tqdm

# %%
glimpse_dir = '/mnt/DATA/macrohet/results/glimpses/interactive_plots/time_series'

# %%
glimpse_fns = glob.glob(os.path.join(glimpse_dir, '*.png'))

# %%
len(glimpse_fns)
# Out:
# 11109

# %%
import boto3

# %%
ACCESS_KEY = 'AKIARABKOQCG7SA4ZY5J'
SECRET_KEY = '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'
aws_access_key_id=ACCESS_KEY
aws_secret_access_key=SECRET_KEY

# %%
def check_file_in_directory(bucket_name, aws_fn):
    # Create an S3 client
    s3 = boto3.client('s3')
    try:
        # Head the S3 object to check if it exists
        s3.head_object(Bucket=bucket_name, Key=aws_fn)
        return True  # File exists in the specified directory
    except:
        return False  # File does not exist or encountered an error

# Specify your AWS Lightsail bucket name
bucket_name = 'macrohet'

# Specify the directory and file you want to check
directory_name = 'time_series/all_glimpses'
file_name = 'glimpse_1035.3.9_t11.png'
aws_fn = f'{directory_name}/{file_name}'
# Call the function to check if the file exists
file_exists = check_file_in_directory(bucket_name, object_key)

if file_exists:
    print(f'The file "{file_name}" exists in the directory "{directory_name}".')
else:
    print(f'The file "{file_name}" does not exist in the directory "{directory_name}".')
# Out:
# The file "glimpse_1035.3.9_t11.png" exists in the directory "time_series/all_glimpses".

# %%
file_exists_list = list()

# %%
for file_name in tqdm(glimpse_fns):
    # Construct the full S3 object key
    aws_fn = f'{directory_name}/{os.path.basename(file_name)}'
    
    # Call the function to check if the file exists
    file_exists = check_file_in_directory(bucket_name, aws_fn)

    if file_exists:
        file_exists_list.append(aws_fn)
        continue
    else:
        aws_tools.upload(file_name, 
                         'macrohet', 
                          aws_fn, 
                         output_msg = True)
# Out:
#   0%|          | 0/11109 [00:00<?, ?it/s]

# %% [markdown]
# # Quicker method to update

# %%
glimpse_fns = glob.glob(os.path.join(glimpse_dir, '*.png'))

# %%
for file_name in tqdm(glimpse_fns):
    # Construct the full S3 object key
    aws_fn = f'{directory_name}/{os.path.basename(file_name)}'
    
    if aws_fn not in file_exists_list:
        aws_tools.upload(file_name, 
                         'macrohet', 
                          aws_fn, 
                         output_msg = True)
        
        file_exists_list.append(aws_fn)
# Out:
#   0%|          | 0/13421 [00:00<?, ?it/s]
# time_series/all_glimpses/glimpse_236.6.5_t60.png: Upload Successful
# time_series/all_glimpses/glimpse_849.5.7_t52.png: Upload Successful
# time_series/all_glimpses/glimpse_3.5.9_t57.png: Upload Successful
# time_series/all_glimpses/glimpse_279.6.8_t7.png: Upload Successful
# time_series/all_glimpses/glimpse_2164.5.7_t29.png: Upload Successful
# time_series/all_glimpses/glimpse_1404.5.6_t20.png: Upload Successful
# time_series/all_glimpses/glimpse_279.6.8_t35.png: Upload Successful
# time_series/all_glimpses/glimpse_396.5.5_t15.png: Upload Successful
# time_series/all_glimpses/glimpse_1134.4.9_t29.png: Upload Successful
# time_series/all_glimpses/glimpse_1065.5.4_t38.png: Upload Successful
# time_series/all_glimpses/glimpse_184.5.7_t47.png: Upload Successful
# time_series/all_glimpses/glimpse_187.5.5_t21.png: Upload Successful
# time_series/all_glimpses/glimpse_399.4.9_t32.png: Upload Successful
# ...

# %% [markdown]
# # Progress check

# %%
from macrohet import notify
import time

# %%
64.2153110047847*20900/100
# Out:
# 13421.000000000002

# %%
len(os.listdir('/mnt/DATA/macrohet/results/glimpses/interactive_plots/time_series'))
# Out:
# 13431

# %%
N = 20900
prev_prog = 13431/N *100
for i in range(0,48):
    n = len(os.listdir('/mnt/DATA/macrohet/results/glimpses/interactive_plots/time_series'))
    progress = n/N * 100 
    notify.send_sms(f'Progress update: {progress}% done')
    elapsed_prog = progress - prev_prog
    prog_per_hour = elapsed_prog / 0.25
    to_go = 100 - progress
    time_to_go = to_go/prog_per_hour
    notify.send_sms(f'Progress update: {progress}% done \n Estimated time to go:{time_to_go}')
    prev_prog = progress
    time.sleep(60*15)
