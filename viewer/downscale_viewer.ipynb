# %% [markdown]
# # Image viewer
#
# This notebook is for inspecting timelapse microscopy data, with associated sinhgle-cell labels and tracks, showing the infection of human macrophages with Mycobacterium Tuberculosis (Mtb), acquired on an Opera Phenix confocal microscope.

# %%
import napari
import os, glob
from macrohet import dataio #, visualise, notify
import numpy as np
import os
import re
import numpy as np
import cv2
import btrack
import zarr

# %% [markdown]
# ### Load experiment of choice
#
# The Opera Phenix is a high-throughput confocal microscope that acquires very large 5-dimensional (TCZXY) images over several fields of view in any one experiment. Therefore, a lazy-loading approach is chosen to mosaic, view and annotate these images. This approach depends upon Dask and DaskFusion. The first step is to load the main metadata file (typically called `Index.idx.xml` and located in the main `Images` directory) that contains the image filenames and associated TCXZY information used to organise the images.

# %%
# %%time
expt_ID = 'ND0005'

base_dir = f'/mnt/SYNO/macrohet_syno/data/{expt_ID}/'
# base_dir = f'/mnt/DATA/macrohet/{expt_ID}/'

metadata_fn = glob.glob(os.path.join(base_dir, 'acquisition/Images/Index*xml'))[0]
metadata = dataio.read_harmony_metadata(metadata_fn)  
metadata
# Out:
# Reading metadata XML file...
# 0it [00:00, ?it/s]
# Extracting metadata complete!
# CPU times: user 3.23 s, sys: 317 ms, total: 3.55 s
# Wall time: 4.34 s
#                    id State                               URL Row Col FieldID  \
# 0        0303K1F1P1R1    Ok    r03c03f01p01-ch1sk1fk1fl1.tiff   3   3       1
# 1        0303K1F1P1R2    Ok    r03c03f01p01-ch2sk1fk1fl1.tiff   3   3       1
# 2        0303K1F1P2R1    Ok    r03c03f01p02-ch1sk1fk1fl1.tiff   3   3       1
# 3        0303K1F1P2R2    Ok    r03c03f01p02-ch2sk1fk1fl1.tiff   3   3       1
# 4        0303K1F1P3R1    Ok    r03c03f01p03-ch1sk1fk1fl1.tiff   3   3       1
# ...               ...   ...                               ...  ..  ..     ...
# 31093  0404K192F9P1R2    Ok  r04c04f09p01-ch2sk192fk1fl1.tiff   4   4       9
# 31094  0404K192F9P2R1    Ok  r04c04f09p02-ch1sk192fk1fl1.tiff   4   4       9
# 31095  0404K192F9P2R2    Ok  r04c04f09p02-ch2sk192fk1fl1.tiff   4   4       9
# 31096  0404K192F9P3R1    Ok  r04c04f09p03-ch1sk192fk1fl1.tiff   4   4       9
# 31097  0404K192F9P3R2    Ok  r04c04f09p03-ch2sk192fk1fl1.tiff   4   4       9
#
#       PlaneID TimepointID ChannelID FlimID  ... PositionZ AbsPositionZ  \
# 0           1           0         1      1  ...         0  0.135257497
# 1           1           0         2      1  ...         0  0.135257497
# 2           2           0         1      1  ...     2E-06  0.135259494
# 3           2           0         2      1  ...     2E-06  0.135259494
# 4           3           0         1      1  ...     4E-06  0.135261506
# ...       ...         ...       ...    ...  ...       ...          ...
# 31093       1         191         2      1  ...         0  0.135189295
# 31094       2         191         1      1  ...     2E-06  0.135191306
# 31095       2         191         2      1  ...     2E-06  0.135191306
# 31096       3         191         1      1  ...     4E-06  0.135193303
# 31097       3         191         2      1  ...     4E-06  0.135193303
#
#       MeasurementTimeOffset                        AbsTime  \
# 0                         0  2024-10-06T18:14:34.337+01:00
# 1                         0   2024-10-06T18:14:34.57+01:00
# 2                         0  2024-10-06T18:14:34.913+01:00
# 3                         0  2024-10-06T18:14:35.133+01:00
# 4                         0  2024-10-06T18:14:35.477+01:00
# ...                     ...                            ...
# 31093              57306.39   2024-10-07T10:10:41.33+01:00
# 31094              57306.39  2024-10-07T10:10:41.677+01:00
# 31095              57306.39  2024-10-07T10:10:41.893+01:00
# 31096              57306.39  2024-10-07T10:10:42.237+01:00
# 31097              57306.39   2024-10-07T10:10:42.47+01:00
#
#       MainExcitationWavelength MainEmissionWavelength ObjectiveMagnification  \
# 0                          640                    706                     40
# 1                          488                    522                     40
# 2                          640                    706                     40
# 3                          488                    522                     40
# 4                          640                    706                     40
# ...                        ...                    ...                    ...
# 31093                      488                    522                     40
# 31094                      640                    706                     40
# 31095                      488                    522                     40
# 31096                      640                    706                     40
# 31097                      488                    522                     40
#
#       ObjectiveNA ExposureTime  \
# 0             1.1          0.2
# 1             1.1          0.1
# 2             1.1          0.2
# 3             1.1          0.1
# 4             1.1          0.2
# ...           ...          ...
# 31093         1.1          0.1
# 31094         1.1          0.2
# 31095         1.1          0.1
# 31096         1.1          0.2
# 31097         1.1          0.1
#
#                                        OrientationMatrix
# 0      [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
# 1      [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
# 2      [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
# 3      [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
# 4      [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
# ...                                                  ...
# 31093  [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
# 31094  [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
# 31095  [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
# 31096  [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
# 31097  [[0.999498,0,0,-8.1],[0,-0.999498,0,-1.0],[0,0...
#
# [31098 rows x 35 columns]

# %% [markdown]
# ### View assay layout and mask information (optional)
#
# The Opera Phenix acquires many time lapse series from a range of positions. The first step is to inspect the image metadata, presented in the form of an `Assaylayout/experiment_ID.xml` file, to show which positions correspond to which experimental assays.

# %%
metadata_path = glob.glob(os.path.join(base_dir, 'acquisition/Assaylayout/*.xml'))[0]
assay_layout = dataio.read_harmony_metadata(metadata_path, assay_layout=True,replicate_number=False)# mask_exist=True,  image_dir = image_dir, image_metadata = metadata)
assay_layout
# Out:
# Reading metadata XML file...
# Extracting metadata complete!
#            Strain Compound Concentration ConcentrationEC
# Row Column
# 3   1         UNI     CTRL             0             EC0
#     2         UNI     CTRL             0             EC0
#     3          WT     CTRL             0             EC0
#     4          WT     CTRL             0             EC0
#     5          WT      PZA            60            EC50
#     6          WT      PZA            60            EC50
#     7          WT      RIF           0.1            EC50
#     8          WT      RIF           0.1            EC50
#     9          WT      INH          0.04            EC50
#     10         WT      INH          0.04            EC50
#     11         WT      BDQ          0.02            EC50
#     12         WT      BDQ          0.02            EC50
# 4   3          WT     CTRL             0             EC0
#     4          WT     CTRL             0             EC0
#     5          WT      PZA           400            EC99
#     6          WT      PZA           400            EC99
#     7          WT      RIF             2            EC99
#     8          WT      RIF             2            EC99
#     9          WT      INH             2            EC99
#     10         WT      INH             2            EC99
#     11         WT      BDQ           2.5            EC99
#     12         WT      BDQ           2.5            EC99
# 5   3         RD1     CTRL             0             EC0
#     4         RD1     CTRL             0             EC0
#     5         RD1      PZA            60            EC50
#     6         RD1      PZA            60            EC50
#     7         RD1      RIF           0.1            EC50
#     8         RD1      RIF           0.1            EC50
#     9         RD1      INH          0.04            EC50
#     10        RD1      INH          0.04            EC50
#     11        RD1      BDQ          0.02            EC50
#     12        RD1      BDQ          0.02            EC50
# 6   3         RD1     CTRL             0             EC0
#     4         RD1     CTRL             0             EC0
#     5         RD1      PZA           400            EC99
#     6         RD1      PZA           400            EC99
#     7         RD1      RIF             2            EC99
#     8         RD1      RIF             2            EC99
#     9         RD1      INH             2            EC99
#     10        RD1      INH             2            EC99
#     11        RD1      BDQ           2.5            EC99
#     12        RD1      BDQ           2.5            EC99

# %% [markdown]
# ### Load using Zarr

# %%
expt_ID
# Out:
# 'ND0005'

# %%
acq_ID = (3, 4)

# %%
image_dir = os.path.join(base_dir, f'acquisition/zarr/{acq_ID}.zarr')

zarr_group = zarr.open(image_dir, mode='r')

# %%
# %%time
images = zarr_group.images[:,1,1,...]
images.shape
# Out:
# CPU times: user 9.75 s, sys: 4.12 s, total: 13.9 s
# Wall time: 3.67 s
# (150, 6048, 6048)

# %%
zarr_group.images
# Out:
# <zarr.core.Array '/images' (192, 2, 3, 6048, 6048) uint16 read-only>

# %%
# %%time
images_max_proj = np.max(zarr_group.images, axis = 2)
# Out:
# CPU times: user 1min 35s, sys: 1min 9s, total: 2min 44s
# Wall time: 8min 21s

# %%
images_max_proj.shape

# %%
images.shape
# Out:
# (150, 6048, 6048)

# %% [markdown]
# #### Load downscaled version from mp4 videos

# %%
mp4_video_height
# Out:
# 0

# %%
mp4_path = glob.glob(f'/mnt/SYNO/videos/macrohet_videos/{expt_ID}/{expt_ID}_{acq_ID}*')[0]

# %%
mp4_path#
# Out:
# '/mnt/SYNO/macrohet_syno/data/ND0005/acquisition/mp4/(3, 4).mp4'

# %%
/mnt/SYNO/macrohet_syno/data/ND0005/acquisition/mp4/(3, 4)

# %%
mp4_video_width / 1200
# Out:
# 1.6

# %%
# Load the MP4 video to get its width and height (assuming square frames)
mp4_path = f'/mnt/SYNO/macrohet_syno/data/{expt_ID}/acquisition/mp4/{acq_ID}/{acq_ID}.mp4'

# Open the video using OpenCV
cap = cv2.VideoCapture(mp4_path)

# Get video dimensions (assume width = height)
mp4_video_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
mp4_video_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Compute scale factor to rescale the tracks to fit the MP4 dimensions
scale_factor =  mp4_video_width / 1200

# Scale tuple for napari tracks
track_scale = (1, scale_factor, scale_factor)  # Assuming time is not scaled

# Print the computed scale tuple
print(f"Scale for napari tracks: {track_scale}")

# Code to load MP4 video frames as a stack of images
frames = []
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    # Convert the frame to grayscale (if needed)
    # frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Uncomment for grayscale
    frames.append(frame)

# Convert list of frames to a NumPy array (stack of images)
images_mp4 = np.stack(frames, axis=0)

# Release the video capture object
cap.release()
# Out:
# Scale for napari tracks: (1, 1.6, 1.6)

# %%
from tqdm.auto import tqdm

# %%
# Initialize an empty list to store the rescaled masks
rescaled_segmentations = []

# Iterate through the segmentation stack, rescaling each frame
for i in tqdm(range(segmentation.shape[0]), total = segmentation.shape[0], desc="Rescaling segmentations"):
    # Extract the 2D mask for the current time point
    mask = segmentation[i]
    
    # Rescale the mask to match the MP4 video dimensions
    rescaled_mask = cv2.resize(mask, (mp4_video_width, mp4_video_height), interpolation=cv2.INTER_NEAREST)
    
    # Append the rescaled mask to the list
    rescaled_segmentations.append(rescaled_mask)

# Convert the list of rescaled masks back into a NumPy array (3D stack)
rescaled_stack = np.stack(rescaled_segmentations, axis=0)

# Now `rescaled_stack` contains the resized segmentations that match the MP4 video dimensions
print(f"Rescaled segmentation stack shape: {rescaled_stack.shape}")
# Out:
# Rescaling segmentations:   0%|          | 0/192 [00:00<?, ?it/s]
# Rescaled segmentation stack shape: (192, 1920, 1920)

# %% [markdown]
# # Launch napari

# %%
viewer = napari.Viewer(title = f'{expt_ID, acq_ID}, max_proj')


viewer.add_image(images_max_proj,
                 channel_axis = 1, 
                 colormap=['magenta', 'green'],
                 blending = 'additive', 
                 contrast_limits=[[350, 1000],[0, 7000]]
                )

# %%
viewer = napari.Viewer(title = f'{expt_ID, acq_ID}, max_proj')


viewer.add_image(images_mp4
                )
# Out:
# <Image layer 'images_mp4' at 0x7f5106f42620>

# %%
with btrack.io.HDF5FileHandler(os.path.join(f'/mnt/SYNO/macrohet_syno/data/{expt_ID}/labels/cpv3/{acq_ID}.h5'), #macrohet_seg_model 
                                           'r', 
                                           obj_type='obj_type_1'
                                           ) as reader:
                segmentation = reader.segmentation
                tracks = reader.tracks
# Out:
# [INFO][2024/10/22 02:33:15 pm] Opening HDF file: /mnt/SYNO/macrohet_syno/data/ND0005/labels/cpv3/(3, 4).h5...
# [INFO][2024/10/22 02:33:39 pm] Loading segmentation (192, 6048, 6048)
# [INFO][2024/10/22 02:33:39 pm] Loading tracks/obj_type_1
# [INFO][2024/10/22 02:33:39 pm] Loading LBEP/obj_type_1
# [INFO][2024/10/22 02:33:40 pm] Loading objects/obj_type_1 (76971, 5) (76971 filtered: None)
# [INFO][2024/10/22 02:33:41 pm] Closing HDF file: /mnt/SYNO/macrohet_syno/data/ND0005/labels/cpv3/(3, 4).h5

# %% [markdown]
# ### Add tracks

# %%
filtered_tracks = [track for track in tracks if len(track) > 35]

# %%
# recoloured_seg = btrack.utils.update_segmentation(segmentation, filtered_tracks, scale = (5.04, 5.04))
recoloured_seg = btrack.utils.update_segmentation(rescaled_stack, tracks, scale = (1.6, 1.6))

# %%
# napari_tracks, _, _ = btrack.utils.tracks_to_napari(filtered_tracks, ndim = 2)
napari_tracks, _, _ = btrack.utils.tracks_to_napari(tracks, ndim = 2)

# %%
# tracks_scale = (1, 5.04, 5.04)
viewer.add_tracks(napari_tracks, scale=track_scale, name = 'tracks')
# Out:
# <Tracks layer 'tracks [1]' at 0x7f506536ee90>
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
# ...
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/camera.py", line 244, in viewbox_mouse_event
#     super().viewbox_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/perspective.py", line 233, in viewbox_mouse_event
#     self._update_rotation(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 65, in _update_rotation
#     Quaternion(*_arcball(self._event_value, wh)) *
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/cameras/arcball.py", line 101, in _arcball
#     x, y = xy
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 78, in scale
#     return self.mouse_event.scale
# AttributeError: 'MouseEvent' object has no attribute 'scale'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/backends/_qt.py", line 526, in mouseMoveEvent
#     self._vispy_mouse_move(
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/app/base.py", line 216, in _vispy_mouse_move
#     ev = self._vispy_canvas.events.mouse_move(**kwargs)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 469, in _invoke_callback
#     cb(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_vispy/canvas.py", line 55, in _process_mouse_event
#     super()._process_mouse_event(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/canvas.py", line 375, in _process_mouse_event
#     getattr(picked.events, event.type)(scene_event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 453, in __call__
#     self._invoke_callback(cb, event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 471, in _invoke_callback
#     _handle_exception(self.ignore_callback_errors,
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/logs.py", line 307, in _handle_exception
#     key = repr(cb) + repr(event)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/util/event.py", line 134, in __repr__
#     attr = getattr(self, name)
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/vispy/scene/events.py", line 81, in scale
#     raise TypeError(errmsg)
# TypeError: SceneMouseEvent type 'mouse_move' has no scale
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_qt/threads/status_checker.py:100, in StatusChecker.calculate_status(self=<napari._qt.threads.status_checker.StatusChecker object>)
#      97     return
#      99 try:
# --> 100     res = viewer._calc_status_from_cursor()
#         viewer = Viewer(camera=Camera(center=(486.12053448959847, 716.9323638321471, 1152.4819589408314), zoom=0.48356271157375297, angles=(0.393957687301852, 4.388437407546903, 129.56980303361428), perspective=0.0, mouse_pan=True, mouse_zoom=True), cursor=Cursor(position=(569.0103203910519, 851.1492648342622, 870.9827342919884), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0), dims=Dims(ndim=3, ndisplay=3, order=(0, 1, 2), axis_labels=('0', '1', '2'), rollable=(True, True, True), range=(RangeTuple(start=0.0, stop=191.0, step=1.0), RangeTuple(start=0.0, stop=6047.0, step=1.0), RangeTuple(start=0.0, stop=6047.0, step=1.0)), margin_left=(0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0), point=(0.0, 959.0, 959.0), last_used=0), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False), layers=[<Image layer 'images_mp4' at 0x7f5106f42620>, <Labels layer 'segmentation' at 0x7f50980ec280>, <Labels layer 'recoloured_seg' at 0x7f50980ec3a0>, <Tracks layer 'tracks [1]' at 0x7f506536ee90>], help='use <2> for transform', status={'layer_name': 'images_mp4', 'layer_base': 'images_mp4', 'source_type': '', 'plugin': '', 'coordinates': ' [255 587 -85]'}, tooltip=Tooltip(visible=False, text=''), theme='dark', title="('ND0005', (3, 4)), max_proj", mouse_over_canvas=True, mouse_move_callbacks=[], mouse_drag_callbacks=[], mouse_double_click_callbacks=[], mouse_wheel_callbacks=[<function dims_scroll at 0x7f51174a67a0>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, _keymap={})
#     101 except Exception as e:  # pragma: no cover # noqa: BLE001
#     102     # Our codebase is not threadsafe. It is possible that an
#     103     # ViewerModel or Layer state is changed while we are trying to
#    (...)
#     107     #
#     108     # We do not want to crash the thread to keep the status updates.
#     109     notification_manager.dispatch(Notification.from_exception(e))
#
# File ~/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/components/viewer_model.py:564, in ViewerModel._calc_status_from_cursor(self=Viewer(camera=Camera(center=(486.12053448959847,...use_drag_gen={}, _mouse_wheel_gen={}, _keymap={}))
#     562 active = self.layers.selection.active
#     563 if active is not None:
# --> 564     status = active.get_status(
#         active = <Image layer 'images_mp4' at 0x7f5106f42620>
#         self = Viewer(camera=Camera(center=(486.12053448959847, 716.9323638321471, 1152.4819589408314), zoom=0.48356271157375297, angles=(0.393957687301852, 4.388437407546903, 129.56980303361428), perspective=0.0, mouse_pan=True, mouse_zoom=True), cursor=Cursor(position=(569.0103203910519, 851.1492648342622, 870.9827342919884), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0), dims=Dims(ndim=3, ndisplay=3, order=(0, 1, 2), axis_labels=('0', '1', '2'), rollable=(True, True, True), range=(RangeTuple(start=0.0, stop=191.0, step=1.0), RangeTuple(start=0.0, stop=6047.0, step=1.0), RangeTuple(start=0.0, stop=6047.0, step=1.0)), margin_left=(0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0), point=(0.0, 959.0, 959.0), last_used=0), grid=GridCanvas(stride=1, shape=(-1, -1), enabled=False), layers=[<Image layer 'images_mp4' at 0x7f5106f42620>, <Labels layer 'segmentation' at 0x7f50980ec280>, <Labels layer 'recoloured_seg' at 0x7f50980ec3a0>, <Tracks layer 'tracks [1]' at 0x7f506536ee90>], help='use <2> for transform', status={'layer_name': 'images_mp4', 'layer_base': 'images_mp4', 'source_type': '', 'plugin': '', 'coordinates': ' [255 587 -85]'}, tooltip=Tooltip(visible=False, text=''), theme='dark', title="('ND0005', (3, 4)), max_proj", mouse_over_canvas=True, mouse_move_callbacks=[], mouse_drag_callbacks=[], mouse_double_click_callbacks=[], mouse_wheel_callbacks=[<function dims_scroll at 0x7f51174a67a0>], _persisted_mouse_event={}, _mouse_drag_gen={}, _mouse_wheel_gen={}, _keymap={})
#         self.cursor.position = (569.0103203910519, 851.1492648342622, 870.9827342919884)
#         self.cursor = Cursor(position=(569.0103203910519, 851.1492648342622, 870.9827342919884), scaled=True, style=<CursorStyle.STANDARD: 'standard'>, size=1.0)
#         self.cursor._view_direction = array([ 0.76859, -0.63515, -0.07652])
#         self.dims = Dims(ndim=3, ndisplay=3, order=(0, 1, 2), axis_labels=('0', '1', '2'), rollable=(True, True, True), range=(RangeTuple(start=0.0, stop=191.0, step=1.0), RangeTuple(start=0.0, stop=6047.0, step=1.0), RangeTuple(start=0.0, stop=6047.0, step=1.0)), margin_left=(0.0, 0.0, 0.0), margin_right=(0.0, 0.0, 0.0), point=(0.0, 959.0, 959.0), last_used=0)
#     565         self.cursor.position,
#     566         view_direction=self.cursor._view_direction,
#     567         dims_displayed=list(self.dims.displayed),
#     568         world=True,
#     569     )
#     571     if self.tooltip.visible:
#     572         tooltip_text = active._get_tooltip_text(
#     573             np.asarray(self.cursor.position),
#     574             view_direction=np.asarray(self.cursor._view_direction),
#     575             dims_displayed=list(self.dims.displayed),
#     576             world=True,
#     577         )
#
# File ~/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/layers/base/base.py:2137, in Layer.get_status(self=<Image layer 'images_mp4'>, position=array([328.73491, 658.76404,  54.44673]), view_direction=array([ 0.76859, -0.63515, -0.07652]), dims_displayed=[0, 1, 2], world=True)
#    2135 if position is not None:
#    2136     position = np.asarray(position)
# -> 2137     value = self.get_value(
#         self = <Image layer 'images_mp4' at 0x7f5106f42620>
#         position = array([328.73491, 658.76404,  54.44673])
#         view_direction = array([ 0.76859, -0.63515, -0.07652])
#         dims_displayed = [0, 1, 2]
#         world = True
#    2138         position,
#    2139         view_direction=view_direction,
#    2140         dims_displayed=dims_displayed,
#    2141         world=world,
#    2142     )
#    2143 else:
#    2144     value = None
#
# File ~/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/layers/base/base.py:1399, in Layer.get_value(self=<Image layer 'images_mp4'>, position=array([328.73491, 658.76404,  54.44673]), view_direction=array([ 0.76859, -0.63515, -0.07652]), dims_displayed=[0, 1, 2], world=True)
#    1392         view_direction = self._world_to_data_ray(view_direction)
#    1393         start_point, end_point = self.get_ray_intersections(
#    1394             position=position,
#    1395             view_direction=view_direction,
#    1396             dims_displayed=dims_displayed,
#    1397             world=False,
#    1398         )
# -> 1399         value = self._get_value_3d(
#         self = <Image layer 'images_mp4' at 0x7f5106f42620>
#         start_point = array([  0.     , 931.33871,  87.7241 ])
#         end_point = array([192.     , 772.67286,  68.60931])
#         dims_displayed = [0, 1, 2]
#    1400             start_point=start_point,
#    1401             end_point=end_point,
#    1402             dims_displayed=dims_displayed,
#    1403         )
#    1404 else:
#    1405     value = self._get_value(position)
#
# File ~/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/layers/_scalar_field/scalar_field.py:687, in ScalarFieldBase._get_value_3d(self=<Image layer 'images_mp4'>, start_point=array([  0.     , 931.33871,  87.7241 ]), end_point=array([192.     , 772.67286,  68.60931]), dims_displayed=[0, 1, 2])
#     664 def _get_value_3d(
#     665     self,
#     666     start_point: Optional[np.ndarray],
#     667     end_point: Optional[np.ndarray],
#     668     dims_displayed: list[int],
#     669 ) -> Optional[int]:
#     670     """Get the first non-background value encountered along a ray.
#     671
#     672     Parameters
#    (...)
#     685         non-zero value is not encountered, returns None.
#     686     """
# --> 687     return self._get_value_ray(
#         self = <Image layer 'images_mp4' at 0x7f5106f42620>
#         start_point = array([  0.     , 931.33871,  87.7241 ])
#         end_point = array([192.     , 772.67286,  68.60931])
#         dims_displayed = [0, 1, 2]
#     688         start_point=start_point,
#     689         end_point=end_point,
#     690         dims_displayed=dims_displayed,
#     691     )
#
# File ~/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/layers/_scalar_field/scalar_field.py:656, in ScalarFieldBase._get_value_ray(self=<Image layer 'images_mp4'>, start_point=array([  0.     , 931.33871,  87.7241 ]), end_point=array([192.     , 772.67286,  68.60931]), dims_displayed=[0, 1, 2])
#     651     clamped = clamp_point_to_bounding_box(
#     652         sample_points,
#     653         bounding_box,
#     654     ).astype(int)
#     655     values = im_slice[tuple(clamped.T)]
# --> 656     return self._calculate_value_from_ray(values)
#         values = array([[  0,   3,   0],
#        [  0,   3,   0],
#        ...,
#        [  0, 120,   0],
#        [  0, 120,   0]], dtype=uint8)
#         self = <Image layer 'images_mp4' at 0x7f5106f42620>
#     658 return None
#
# File ~/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/layers/image/image.py:735, in Image._calculate_value_from_ray(self=<Image layer 'images_mp4'>, values=array([[  0,   3,   0],
#        [  0,   3,   0],
# ... 120,   0],
#        [  0, 120,   0]], dtype=uint8))
#     729     sumval = (
#     730         step_size
#     731         * np.cumsum(np.clip(values_attenuated, 0, 1))
#     732         * len(values_attenuated)
#     733     )
#     734     scale = np.exp(-self.attenuation * (sumval - 1))
# --> 735     return values[np.nanargmin(values_attenuated * scale)]
#         values_attenuated = array([[0.     , 0.01176, 0.     ],
#        [0.     , 0.01176, 0.     ],
#        ...,
#        [0.     , 0.47059, 0.     ],
#        [0.     , 0.47059, 0.     ]])
#         scale = array([1.05127, 0.90777, ..., 0.     , 0.     ])
#         np = <module 'numpy' from '/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/numpy/__init__.py'>
#         values = array([[  0,   3,   0],
#        [  0,   3,   0],
#        ...,
#        [  0, 120,   0],
#        [  0, 120,   0]], dtype=uint8)
#         np.nanargmin = <function nanargmin at 0x7f512c2fafb0>
#     737 raise RuntimeError(  # pragma: no cover
#     738     f'ray value calculation not implemented for {self.rendering}'
#     739 )
#
# ValueError: operands could not be broadcast together with shapes (499,3) (1497,)
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_qt/threads/status_checker.py", line 86, in run
#     self.calculate_status()
#   File "/home/dayn/miniconda3/envs/godspeed/lib/python3.10/site-packages/napari/_qt/threads/status_checker.py", line 110, in calculate_status
#     self.status_and_tooltip_changed.emit(res)
# UnboundLocalError: local variable 'res' referenced before assignment

# %% [markdown]
# ### Add segmentation

# %%
viewer.add_labels(rescaled_stack) #segmentation)
viewer.add_labels(recoloured_seg)
# Out:
# <Labels layer 'recoloured_seg' at 0x7f508fa98ee0>

# %%
viewer.add_image(images_max_proj[-5],
                 channel_axis = 0, 
                 colormap=['green', 'magenta'],
                 blending = 'additive', 
                 contrast_limits=[[0, 2400],[0, 1000]]
                )
# Out:
# [<Image layer 'Image [4]' at 0x7fa481516460>,
#  <Image layer 'Image [5]' at 0x7fa4823087f0>]

# %%
viewer.camera.reset()

# %%
visualise.highlight_cell(126, viewer, filtered_tracks, scale_factor=5.02)
# Out:
# <Points layer 'cell 126' at 0x7f248be4fa60>

# %%
for layer in viewer.layers:
    viewer.layers[layer.name].scale = (10, 1, 1)

# %%
viewer.layers[2].name
# Out:
# 'filtered'

# %%
viewer.layers[2].scale = (10,5.04, 5.04)

# %% [markdown]
# # Saving out as a list of JPG files for SAM2 testing

# %%
from tqdm.auto import tqdm
from PIL import Image
import os
import cv2
import numpy as np

# Assuming `images_max_proj` is a numpy array of images with shape (n_images, channels, height, width)
output_dir = f"/mnt/SYNO/macrohet_syno/data/{expt_ID}/acquisition/jpegs/{acq_ID}"  # Directory to save the images
os.makedirs(output_dir, exist_ok=True)

# Ensure the MP4 output directory exists
mp4_dir = f"/mnt/SYNO/macrohet_syno/data/{expt_ID}/acquisition/mp4/{acq_ID}"
os.makedirs(mp4_dir, exist_ok=True)

# Set the MP4 output path
output_video_path = os.path.join(mp4_dir, f"{acq_ID}.mp4")

# Initialize video writer for the MP4 file using OpenCV
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # MP4 codec
fps = 10  # Set frames per second
downscaled_size = (1920, 1920)  # New size for downscaling to 1000x1000

video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, downscaled_size)

# Contrast limits for both channels
contrast_limits = [[350, 1000], [0, 7000]]

# Function to apply contrast stretching
def apply_contrast_limits(image, vmin, vmax):
    image = np.clip(image, vmin, vmax)
    image = (image - vmin) / (vmax - vmin) * 255
    return image.astype(np.uint8)

# Iterate over each image in both channels
for idx, (img_ch1, img_ch2) in enumerate(tqdm(zip(images_max_proj[:, 1, ...], images_max_proj[:, 0, ...]), total = 192, desc="Saving images and creating video")):
    # Apply contrast limits to both channels
    img_ch1_adjusted = apply_contrast_limits(img_ch1, *contrast_limits[1])
    img_ch2_adjusted = apply_contrast_limits(img_ch2, *contrast_limits[0])
    
    # Create an RGB image where channel 1 is green and channel 0 is magenta
    img_rgb = np.zeros((img_ch1.shape[0], img_ch1.shape[1], 3), dtype=np.uint8)
    img_rgb[..., 1] = img_ch1_adjusted  # Green channel for ch1
    img_rgb[..., 0] = img_ch2_adjusted  # Red channel for ch0 (magenta = red + blue)
    img_rgb[..., 2] = img_ch2_adjusted  # Blue channel for ch0

    # Downscale the image to 1000x1000 px
    img_downscaled = cv2.resize(img_rgb, downscaled_size, interpolation=cv2.INTER_AREA)
    
    # Save each downscaled image as a 5-digit frame number in jpg format
    frame_filename = os.path.join(output_dir, f"{idx:05d}.jpg")
    cv2.imwrite(frame_filename, img_downscaled)

    # Write the current downscaled frame to the video
    video_writer.write(cv2.imread(frame_filename))

# Release the video writer to finalize the video file
video_writer.release()
# Out:
# Saving images and creating video:   0%|          | 0/192 [00:00<?, ?it/s]
