# %%
import glob

import dask.array as da
from natsort import natsorted
from tqdm.auto import tqdm

zarr_addresses = glob.glob('/mnt/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/data/whole_slice/rep*/mouse_*/zarr/*.zarr')
zarr_addresses = natsorted([fn for fn in zarr_addresses if 'max_proj' in fn])

zarr_addresses
# Out:
# ['/mnt/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/data/whole_slice/rep1/mouse_1/zarr/rep_1_mouse_1_max_proj.zarr',
#  '/mnt/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/data/whole_slice/rep1/mouse_2/zarr/rep_1_mouse_2_max_proj.zarr',
#  '/mnt/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/data/whole_slice/rep1/mouse_3/zarr/rep_1_mouse_3_max_proj.zarr',
#  '/mnt/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/data/whole_slice/rep1/mouse_4/zarr/rep_1_mouse_4_max_proj.zarr',
#  '/mnt/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/data/whole_slice/rep1/mouse_5/zarr/rep_1_mouse_5_max_proj.zarr',
#  '/mnt/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/data/whole_slice/rep1/mouse_6/zarr/rep_1_mouse_6_bot_max_proj.zarr',
#  '/mnt/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/data/whole_slice/rep1/mouse_6/zarr/rep_1_mouse_6_top_max_proj.zarr',
# ...

# %%
import napari

# %%
image_stack = []
masks_stack = []

# viewer = napari.Viewer(title='testing zarr images')
for zarr_address in tqdm(zarr_addresses):

    images = da.from_zarr(f"{zarr_address}/0/0")
    # masks = da.from_zarr(f"{zarr_address}/labels/ground_truth_mtb/0")
    # viewer.add_image(images[0,0,0,...], name = zarr_address.split('rep2/')[1])
    image_stack.append(images)
    # masks_stack.append(masks)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
zarr_address
# Out:
# '/Volumes/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/whole_slice/rep2/mouse_16/zarr/20251109_40X_Mouse16_Timer_PZA-RIF_20251109_09.zarr'

# %%
image_stack
# Out:
# [dask.array<from-zarr, shape=(1, 3, 17, 45850, 52070), dtype=>u2, chunksize=(1, 1, 1, 1024, 1024), chunktype=numpy.ndarray>,
#  dask.array<from-zarr, shape=(1, 3, 17, 49997, 33408), dtype=>u2, chunksize=(1, 1, 1, 1024, 1024), chunktype=numpy.ndarray>,
#  dask.array<from-zarr, shape=(1, 3, 17, 43776, 35482), dtype=>u2, chunksize=(1, 1, 1, 1024, 1024), chunktype=numpy.ndarray>,
#  dask.array<from-zarr, shape=(1, 3, 15, 62438, 43776), dtype=>u2, chunksize=(1, 1, 1, 1024, 1024), chunktype=numpy.ndarray>,
#  dask.array<from-zarr, shape=(1, 3, 15, 56218, 35482), dtype=>u2, chunksize=(1, 1, 1, 1024, 1024), chunktype=numpy.ndarray>,
#  dask.array<from-zarr, shape=(1, 3, 11, 39629, 49997), dtype=>u2, chunksize=(1, 1, 1, 1024, 1024), chunktype=numpy.ndarray>,
#  dask.array<from-zarr, shape=(1, 3, 11, 39629, 52070), dtype=>u2, chunksize=(1, 1, 1, 1024, 1024), chunktype=numpy.ndarray>,
# ...

# %%
image_stack[-2]#.compute()
# Out:
# dask.array<from-zarr, shape=(1, 3, 1, 512, 451), dtype=uint8, chunksize=(1, 1, 1, 512, 451), chunktype=numpy.ndarray>

# %%
viewer2 = napari.Viewer()
viewer2.add_image(image_stack[-2].compute())
# Out:
# <Image layer 'Image' at 0x322205780>

# %%
image_stack[-1]
# Out:
# dask.array<from-zarr, shape=(1, 3, 15, 56218, 45850), dtype=>u2, chunksize=(1, 1, 1, 1024, 1024), chunktype=numpy.ndarray>
