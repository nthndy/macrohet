# %% [markdown]
# # Trying to segment individual Mtb using microSAM

# %%
import sys

import torch

print("python:", sys.executable)
print("torch:", torch.__version__, "cuda build:", torch.version.cuda)
print("cuda available:", torch.cuda.is_available())
# Out:
# python: /home/dayn/miniconda3/envs/godspee/bin/python
# torch: 2.5.1+cu121 cuda build: 12.1
# cuda available: True

# %%
import napari
import numpy as np
from skimage import io

# %%
image_fn = '/mnt/OPERA3/Nathan/data/macrohet/mtb_tissue_localisation/Training_Mouse10_zproj.tif'
image = io.imread(image_fn)
image.shape
# Out:
# (4424, 4349, 3)

# %%
viewer = napari.Viewer(title='microsam mtb tissue localisation')
viewer.add_image(image, channel_axis=-1)
# Out:
# [<Image layer 'Image' at 0x7ce27c2c86d0>,
#  <Image layer 'Image [1]' at 0x7ce218571d90>,
#  <Image layer 'Image [2]' at 0x7ce21847f490>]

# %%
break
# Out:
#   Cell In[5], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
psuedo_mtb_channel = image[...,1:].max(axis=-1)
viewer.add_image(psuedo_mtb_channel, colormap='green')

# %%
print()

# %%
np.save('mtb_manual_labels_temp.npy', viewer.layers['current_object'].data)

# %%
mtb_manual_labels = np.load('mtb_manual_labels_temp.npy')

# %%
mtb_manual_labels

# %%
layer = viewer.layers['current_object']
layer.data = np.zeros_like(mtb_manual_labels)

# %% [markdown]
# ### Loading a whole lung slice

# %%
tissue_image_fn = '/mnt/NEMO/home/shared/Shared - Baptiste Pradel/Histology/20250814_40X_TimerMtb_BP_mice10_DAPI_TimerG_TimerR_Multichannel Z-Stack_20250814_5375.vsi'

# %%
# Out:
# Traceback (most recent call last):
#   File "/home/dayn/miniconda3/envs/godspee/lib/python3.11/site-packages/npe2/_command_registry.py", line 32, in resolve
#     self.function = utils.import_python_name(self.python_name)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dayn/miniconda3/envs/godspee/lib/python3.11/site-packages/npe2/manifest/utils.py", line 260, in import_python_name
#     mod = import_module(module_name)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dayn/miniconda3/envs/godspee/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1126, in _find_and_load_unlocked
# ...
