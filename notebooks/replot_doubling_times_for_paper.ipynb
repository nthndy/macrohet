# %% [markdown]
# # Plot single-cell doubling times

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tqdm.auto import tqdm

from macrohet import plot

# Setup
sns.set(style="white", font="Helvetica Neue")
sns.set_palette(['#1a9641', '#a6d96a', '#978897', '#d1d1ca', '#f1b6da', '#d02c91'])
plt.rcParams["axes.spines.right"] = False
plt.rcParams["axes.spines.top"] = False

# %% [markdown]
# ### Load single-cell data

# %% [markdown]
# #### Using CSV

# %%
csv_path = "../data/single_cell_df.csv"
df = pd.read_csv(csv_path, index_col=0)
df
# Out:
#          Time (hours)  Mtb Area (µm)  dMtb Area (µm)  Mphi Area (µm)  \
# 405               0.0      46.797680      136.772588      660.776979
# 406               1.0      48.719647      136.772588      585.105086
# 407               2.0      52.206007      136.772588      582.020998
# 408               3.0      50.552221      136.772588      572.232372
# 409               4.0      54.463202      136.772588      590.669853
# ...               ...            ...             ...             ...
# 1089728          70.0       0.000000        0.000000     1060.881495
# 1089729          71.0       8.872339        0.000000      937.205106
# 1089730          72.0       0.000000        0.000000     1189.988561
# 1089731          73.0       0.000000        0.000000      975.934991
# 1089732          74.0       0.000000        0.000000     1045.170526
#
#          dMphi Area (µm) Infection Status  Initial Infection Status  \
# 405           -68.386294              NaN                       1.0
# 406           -68.386294              NaN                       1.0
# 407           -68.386294             True                       1.0
# 408           -68.386294             True                       1.0
# 409           -68.386294             True                       1.0
# ...                  ...              ...                       ...
# 1089728       -36.539736            False                       0.0
# 1089729       -36.539736            False                       0.0
# 1089730       -36.539736            False                       0.0
# 1089731       -36.539736              NaN                       0.0
# 1089732       -36.539736              NaN                       0.0
#
#          Final Infection Status           x           y  ...  Uptake  \
# 405                         1.0  519.922607  876.779602  ...   False
# 406                         1.0  522.290833  876.766357  ...   False
# 407                         1.0  524.336243  874.563110  ...   False
# 408                         1.0  516.952454  876.656799  ...   False
# 409                         1.0  521.947449  880.909363  ...   False
# ...                         ...         ...         ...  ...     ...
# 1089728                     0.0  599.478394  769.336914  ...   False
# 1089729                     0.0  594.419922  769.042297  ...   False
# 1089730                     0.0  604.841675  773.028931  ...   False
# 1089731                     0.0  600.207642  771.466614  ...   False
# 1089732                     0.0  607.132141  765.617859  ...   False
#
#          dMtb Area between frames (µm)  Mtb Area Processed (µm)  \
# 405                                NaN                      NaN
# 406                           1.921968                      NaN
# 407                           3.486360                      NaN
# 408                          -1.653786                      NaN
# 409                           3.910981                50.552221
# ...                                ...                      ...
# 1089728                       0.000000                 0.000000
# 1089729                       8.872339                 0.000000
# 1089730                      -8.872339                 0.000000
# 1089731                       0.000000                 0.000000
# 1089732                       0.000000                 0.000000
#
#          Time Model (hours)  Mtb Area Model (µm)  mtb_origin Doubling Amounts  \
# 405                     NaN                  NaN      Growth    [50.6, 101.2]
# 406                     NaN                  NaN      Growth    [50.6, 101.2]
# 407                     2.0            47.625714      Growth    [50.6, 101.2]
# 408                     3.0            49.099089      Growth    [50.6, 101.2]
# 409                     4.0            50.593160      Growth    [50.6, 101.2]
# ...                     ...                  ...         ...              ...
# 1089728                70.0             0.000000        Junk              NaN
# 1089729                71.0             0.000000        Junk              NaN
# 1089730                72.0             0.000000        Junk              NaN
# 1089731                 NaN                  NaN        Junk              NaN
# 1089732                 NaN                  NaN        Junk              NaN
#
#         Doubling Times    r2  Frame
# 405             [28.0]  0.97      0
# 406             [28.0]  0.97      1
# 407             [28.0]  0.97      2
# 408             [28.0]  0.97      3
# 409             [28.0]  0.97      4
# ...                ...   ...    ...
# 1089728            NaN -0.01     70
# 1089729            NaN -0.01     71
# 1089730            NaN -0.01     72
# 1089731            NaN -0.01     73
# 1089732            NaN -0.01     74
#
# [12654 rows x 35 columns]

# %% [markdown]
# #### Using Zarr

# %%
# Load from zarr or pickle
zarr_path = "../data/single_cell_df.zarr"
df = pd.read_zarr(zarr_path)

# %% [markdown]
# #### Filter out unreliable tracks

# %%
df = df[df['r2'] > 0.7]

# %% [markdown]
# ### Plot individual growth dynamics graph
# To inspect the LOWESS fit

# %%
# Choose a subset to plot
example_ids = df['ID'].dropna().unique()[:3]

# Plot
for ID in tqdm(example_ids, desc="Plotting growth curves"):
    sc_df = df[df['ID'] == ID].sort_values(by='Time Model (hours)')

    plt.figure(figsize=(6, 4))
    sns.scatterplot(data=sc_df, x='Time (hours)', y='Mtb Area Processed (µm)', label='Processed Mtb Signal', s=10)
    sns.lineplot(data=sc_df, x='Time Model (hours)', y='Mtb Area Model (µm)', label='LOWESS Fit', color='#d02c91')

    plt.title(f"Cell ID: {ID} | r² = {sc_df['r2'].iloc[0]:.2f}")
    plt.xlabel("Time (hours)")
    plt.ylabel("Mtb Area (µm²)")
    plt.grid(False)
    sns.despine(offset=10)
    plt.tight_layout()
    plt.show()
# Out:
# Plotting growth curves:   0%|          | 0/3 [00:00<?, ?it/s]
# /Users/dayn/miniforge3/envs/macrohet_env/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/dayn/miniforge3/envs/macrohet_env/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/dayn/miniforge3/envs/macrohet_env/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/dayn/miniforge3/envs/macrohet_env/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/dayn/miniforge3/envs/macrohet_env/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/dayn/miniforge3/envs/macrohet_env/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Plot with doubling time quantifications

# %%
plot.single_cell_growth(df, ID)

# %% [markdown]
# # Plot all intracellular single-cell growth dynamics
# As a series of colour coded line graphs.
#
# **Note** that the graphs generated with the example data will not look the same as in the publication as the example data only contains one wild-type Mtb untreated condition.

# %%
plot.population_dynamics_coloured(df)
# Out:
#   0%|          | 0/1795 [00:00<?, ?it/s]

# %% [markdown]
# # Plot distribution of doubling times
# Under different antibiotic conditions and Mtb strains.
#
# **Note** that the graphs generated with the example data will not look the same as in the publication as the example data only contains one wild-type Mtb untreated condition.

# %%
plot.doubling_times_boxplot(df)
# Out:
# /tmp/ipykernel_894048/21637500.py:38: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(

# %% [markdown]
# ### Plot doubling times distributions
# According to manual classification of Mtb growth phenotype
#
# **Note** that the graphs generated with the example data will not look the same as in the publication as the example data only contains one wild-type Mtb untreated condition.

# %%
df['ID'].unique()
# Out:
# array(['1.3.5.PS0000', '107.3.5.PS0000', '109.3.5.PS0000',
#        '115.3.5.PS0000', '117.3.5.PS0000', '134.3.5.PS0000',
#        '138.3.5.PS0000', '144.3.5.PS0000', '147.3.5.PS0000',
#        '15.3.5.PS0000', '150.3.5.PS0000', '161.3.5.PS0000',
#        '170.3.5.PS0000', '178.3.5.PS0000', '187.3.5.PS0000',
#        '19.3.5.PS0000', '194.3.5.PS0000', '197.3.5.PS0000',
#        '201.3.5.PS0000', '210.3.5.PS0000', '217.3.5.PS0000',
#        '218.3.5.PS0000', '226.3.5.PS0000', '227.3.5.PS0000',
#        '233.3.5.PS0000', '239.3.5.PS0000', '247.3.5.PS0000',
#        '250.3.5.PS0000', '252.3.5.PS0000', '254.3.5.PS0000',
#        '256.3.5.PS0000', '263.3.5.PS0000', '264.3.5.PS0000',
#        '268.3.5.PS0000', '272.3.5.PS0000', '289.3.5.PS0000',
#        '302.3.5.PS0000', '319.3.5.PS0000', '325.3.5.PS0000',
#        '327.3.5.PS0000', '329.3.5.PS0000', '330.3.5.PS0000',
#        '331.3.5.PS0000', '334.3.5.PS0000', '335.3.5.PS0000',
#        '336.3.5.PS0000', '337.3.5.PS0000', '341.3.5.PS0000',
#        '345.3.5.PS0000', '352.3.5.PS0000', '355.3.5.PS0000',
#        '36.3.5.PS0000', '361.3.5.PS0000', '363.3.5.PS0000',
#        '366.3.5.PS0000', '367.3.5.PS0000', '37.3.5.PS0000',
#        '373.3.5.PS0000', '374.3.5.PS0000', '380.3.5.PS0000',
#        '401.3.5.PS0000', '414.3.5.PS0000', '421.3.5.PS0000',
#        '427.3.5.PS0000', '430.3.5.PS0000', '437.3.5.PS0000',
#        '438.3.5.PS0000', '44.3.5.PS0000', '445.3.5.PS0000',
#        '447.3.5.PS0000', '450.3.5.PS0000', '452.3.5.PS0000',
#        '456.3.5.PS0000', '459.3.5.PS0000', '460.3.5.PS0000',
#        '463.3.5.PS0000', '466.3.5.PS0000', '470.3.5.PS0000',
#        '474.3.5.PS0000', '475.3.5.PS0000', '477.3.5.PS0000',
#        '481.3.5.PS0000', '483.3.5.PS0000', '484.3.5.PS0000',
#        '486.3.5.PS0000', '487.3.5.PS0000', '492.3.5.PS0000',
#        '495.3.5.PS0000', '501.3.5.PS0000', '503.3.5.PS0000',
#        '507.3.5.PS0000', '508.3.5.PS0000', '513.3.5.PS0000',
#        '515.3.5.PS0000', '517.3.5.PS0000', '518.3.5.PS0000',
#        '521.3.5.PS0000', '525.3.5.PS0000', '527.3.5.PS0000',
#        '528.3.5.PS0000', '530.3.5.PS0000', '536.3.5.PS0000',
#        '537.3.5.PS0000', '539.3.5.PS0000', '542.3.5.PS0000',
#        '544.3.5.PS0000', '552.3.5.PS0000', '558.3.5.PS0000',
#        '56.3.5.PS0000', '564.3.5.PS0000', '565.3.5.PS0000',
#        '577.3.5.PS0000', '579.3.5.PS0000', '581.3.5.PS0000',
#        '584.3.5.PS0000', '586.3.5.PS0000', '598.3.5.PS0000',
#        '601.3.5.PS0000', '602.3.5.PS0000', '608.3.5.PS0000',
#        '610.3.5.PS0000', '617.3.5.PS0000', '624.3.5.PS0000',
#        '665.3.5.PS0000', '670.3.5.PS0000', '702.3.5.PS0000',
#        '75.3.5.PS0000', '802.3.5.PS0000', '810.3.5.PS0000',
#        '823.3.5.PS0000', '840.3.5.PS0000', '869.3.5.PS0000',
#        '892.3.5.PS0000', '893.3.5.PS0000', '90.3.5.PS0000'], dtype=object)

# %%
plot.growth_dynamics_by_origin(df)
# Out:
# /tmp/ipykernel_70986/2761496271.py:30: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(

# %% [markdown]
# ### Plot doubling times distributions
# Across all antibiotic conditions and concentrations
#
# **Note** that the graphs generated with the example data will not look the same as in the publication as the example data only contains one wild-type Mtb untreated condition.

# %% [markdown]
# ##### To-do: change to stacked bar charts as in the publication and replot with publication data

# %%
plot.doubling_times_with_piecharts(df)
# Out:
# /tmp/ipykernel_70986/2962595637.py:38: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(
# /tmp/ipykernel_70986/2962595637.py:54: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(
# /tmp/ipykernel_70986/2962595637.py:54: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(
# /tmp/ipykernel_70986/2962595637.py:54: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   sns.stripplot(
# /tmp/ipykernel_70986/2962595637.py:89: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_counts = subset_df.groupby(['Mtb Strain or Drug Compound', 'Concentration', 'Growth Category', 'CTRL Type']).size()
# /tmp/ipykernel_70986/2962595637.py:149: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_counts = subset_df.groupby(['Mtb Strain or Drug Compound', 'Concentration', 'Growth Category']).size()
# /tmp/ipykernel_70986/2962595637.py:204: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
