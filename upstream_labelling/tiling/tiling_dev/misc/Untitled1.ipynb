# %%
from skimage.io import imread

# %%
import matplotlib.pyplot as plt

# %%
import os, glob

# %%
for fn in glob.glob('/mnt/DATA/cell_comp/results/k-func/final_results/*.jpg'):
    img = imread(fn)
    plt.imshow(img)
    plt.axis('off')
    plt.savefig(fn.replace('jpg', 'pdf'), bbox_inches = 'tight', dpi = 314)
