# %% [markdown]
# # Load segmentation, localise and save as h5
#
# Segment a stack of images and then manually label a couple, then check how well the model segmented them.

# %%
import napari
import cellpose
from octopuslite import utils, tile
import numpy as np

import sys
sys.path.append('macrohet/')
from notify import send_sms

def view(img):
    return napari.Viewer().add_image(img)

from tqdm.auto import tqdm

import btrack
import dask.array as da

# %% [markdown]
# ### Load experiment of choice
#
# The Opera Phenix is a high-throughput confocal microscope that acquires very large 5-dimensional (TCZXY) images over several fields of view in any one experiment. Therefore, a lazy-loading approach is chosen to mosaic, view and annotate these images. This approach depends upon Dask and DaskFusion. The first step is to load the main metadata file (typically called `Index.idx.xml` and located in the main `Images` directory) that contains the image filenames and associated TCXZY information used to organise the images.

# %%
image_dir = '/mnt/DATA/sandbox/pierre_live_cell_data/outputs/Replication_IPSDM_GFP/Images/'
metadata_fn = '/mnt/DATA/sandbox/pierre_live_cell_data/outputs/Replication_IPSDM_GFP/Index.idx.xml'
metadata = utils.read_harmony_metadata(metadata_fn)
# Out:
# Reading metadata XML file...
# Extracting HarmonyV5 metadata:   0%|          | 0/113400 [00:00<?, ?it/s]
# Extracting metadata complete!

# %% [markdown]
# ### View assay layout and mask information (optional)
#
# The Opera Phenix acquires many time lapse series from a range of positions. The first step is to inspect the image metadata, presented in the form of an `Assaylayout/experiment_ID.xml` file, to show which positions correspond to which experimental assays.

# %%
metadata_path = '/mnt/DATA/sandbox/pierre_live_cell_data/outputs/Replication_IPSDM_GFP/Assaylayout/20210602_Live_cell_IPSDMGFP_ATB.xml'
utils.read_harmony_metadata(metadata_path, assay_layout=True)
# Out:
# Reading metadata XML file...
# Extracting metadata complete!
#     Strain Compound Concentration ConcentrationEC
# 3 4    RD1     CTRL             0             EC0
#   5     WT     CTRL             0             EC0
#   6     WT      PZA            60            EC50
#   7     WT      RIF           0.1            EC50
#   8     WT      INH          0.04            EC50
#   9     WT      BDQ          0.02            EC50
# 4 4    RD1     CTRL             0             EC0
#   5     WT     CTRL             0             EC0
#   6     WT      PZA            60            EC50
#   7     WT      RIF           0.1            EC50
#   8     WT      INH          0.04            EC50
#   9     WT      BDQ          0.02            EC50
# 5 4    RD1     CTRL             0             EC0
#   5     WT     CTRL             0             EC0
#   6     WT      PZA           400            EC99
#   7     WT      RIF             2            EC99
#   8     WT      INH             2            EC99
#   9     WT      BDQ           2.5            EC99
# 6 4    RD1     CTRL             0             EC0
#   5     WT     CTRL             0             EC0
#   6     WT      PZA           400            EC99
#   7     WT      RIF             2            EC99
#   8     WT      INH             2            EC99
#   9     WT      BDQ           2.5            EC99

# %% [markdown]
# ### Define row and column of choice

# %%
row = '6'
column = '9'

# %% [markdown]
# ### Now to lazily mosaic the images using Dask prior to viewing them.
#
# 1x (75,2,3) [TCZ] image stack takes approximately 1 minute to stitch together, so only load the one field of view I want.

# %%
images = tile.compile_mosaic(image_dir, 
                             metadata, 
                             row, 
                             column, 
                             #set_channel=1, 
                             set_plane = 'sum_proj',
#                              set_time = 1
                         )#.astype(uint8)

# %% [markdown]
# #### Reorder the channel axis for localisation

# %%
gfp = images[:,0,...]
rfp = images[:,1,...]
images = da.stack([gfp,rfp], axis = -1)
images
# Out:
# dask.array<stack, shape=(75, 6048, 6048, 2), dtype=uint64, chunksize=(1, 2016, 2016, 1), chunktype=numpy.ndarray>

# %% [markdown]
# ### Load masks

# %%
masks = np.load('/mnt/DATA/macrohet/segmentation/[6,9]_masks.npy')

# %%
masks = da.asarray(masks)

# %%
masks
# Out:
# dask.array<array, shape=(75, 6048, 6048), dtype=uint16, chunksize=(75, 864, 864), chunktype=numpy.ndarray>

# %% [markdown]
# # Localise raw masks
#
# Include size filter and measurements of fluorescence

# %%
feat = [
      "area",
      "major_axis_length",
      "minor_axis_length",
      "orientation",
      "mean_intensity",
        ]

# %%
objects = btrack.utils.segmentation_to_objects(
    masks, 
    images,
    properties = tuple(feat),
    use_weighted_centroid = False, 
)
# Out:
# [INFO][2023/01/24 11:00:14 AM] Localizing objects from segmentation...
# [INFO][2023/01/24 11:00:14 AM] Found intensity_image data
# [INFO][2023/01/24 11:17:52 AM] Objects are of type: <class 'dict'>
# [INFO][2023/01/24 11:17:52 AM] ...Found 89235 objects in 75 frames.

# %%
objects = [o for o in objects if o.properties['area'] > 2500]

# %%
with btrack.dataio.HDF5FileHandler(
     '/mnt/DATA/macrohet/segmentation/[6,9]_masks.h5', 'w', obj_type='obj_type_1',
) as hdf:
    hdf.write_segmentation(masks)
    hdf.write_objects(objects)
# Out:
# [INFO][2023/01/24 11:17:53 AM] Opening HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_masks.h5...
# [INFO][2023/01/24 11:18:32 AM] Writing objects/obj_type_1
# [INFO][2023/01/24 11:18:32 AM] Writing labels/obj_type_1
# [INFO][2023/01/24 11:18:32 AM] Loading objects/obj_type_1 (40381, 5) (40381 filtered: None)
# [INFO][2023/01/24 11:18:33 AM] Writing properties/obj_type_1/area (40381,)
# [INFO][2023/01/24 11:18:33 AM] Writing properties/obj_type_1/major_axis_length (40381,)
# [INFO][2023/01/24 11:18:33 AM] Writing properties/obj_type_1/minor_axis_length (40381,)
# [INFO][2023/01/24 11:18:33 AM] Writing properties/obj_type_1/orientation (40381,)
# [INFO][2023/01/24 11:18:33 AM] Writing properties/obj_type_1/mean_intensity-0 (40381,)
# [INFO][2023/01/24 11:18:33 AM] Writing properties/obj_type_1/mean_intensity-1 (40381,)
# [INFO][2023/01/24 11:18:33 AM] Closing HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_masks.h5

# %%
objects[0]
# Out:
# {'ID': 0, 'x': 257.8385644029397, 'y': 104.5392053931591, 'z': 0.0, 't': 0, 'dummy': False, 'states': 7, 'label': 5, 'area': 36194, 'major_axis_length': 244.63142988672934, 'minor_axis_length': 204.21778412309249, 'orientation': -0.6250412899536294, 'mean_intensity-0': 1751.473890700116, 'mean_intensity-1': 343.58830192849643}

# %% [markdown]
# # Load h5

# %%
with btrack.dataio.HDF5FileHandler(
     '/mnt/DATA/macrohet/segmentation/[6,9]_masks.h5', 'r', obj_type='obj_type_1',
) as hdf:
    loaded_masks = hdf.segmentation
    loaded_objects = hdf.objects
# Out:
# [INFO][2023/01/24 02:04:47 pm] Opening HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_masks.h5...
# 24-Jan-23 14:04:47 - btrack.dataio - INFO     - Opening HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_masks.h5...
# [INFO][2023/01/24 02:05:00 pm] Loading segmentation (75, 6048, 6048)
# 24-Jan-23 14:05:00 - btrack.dataio - INFO     - Loading segmentation (75, 6048, 6048)
# [INFO][2023/01/24 02:05:00 pm] Loading objects/obj_type_1 (40381, 5) (40381 filtered: None)
# 24-Jan-23 14:05:00 - btrack.dataio - INFO     - Loading objects/obj_type_1 (40381, 5) (40381 filtered: None)
# [INFO][2023/01/24 02:05:01 pm] Closing HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_masks.h5
# 24-Jan-23 14:05:01 - btrack.dataio - INFO     - Closing HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_masks.h5

# %%
loaded_objects[0]
# Out:
# {'ID': 0, 'x': 257.83856201171875, 'y': 104.5392074584961, 'z': 0.0, 't': 0, 'dummy': False, 'states': 7, 'label': 5, 'area': 36194.0, 'major_axis_length': 244.63142, 'mean_intensity-0': 1751.4739, 'mean_intensity-1': 343.5883, 'minor_axis_length': 204.21779, 'orientation': -0.6250413}

# %%
objects = loaded_objects

# %% [markdown]
# # Track

# %%
from btrack import datasets

# %%
config = '/home/dayn/analysis/BayesianTracker/models/particle_config.json'

# %%
features = list(objects[0].properties.keys())

# %%
# initialise a tracker session using a context manager
with btrack.BayesianTracker() as tracker:

    # configure the tracker using a config file
    tracker.configure(config)
    tracker.max_search_radius = 250
    tracker.tracking_updates = ["MOTION", "VISUAL"]
    tracker.features = features

    # append the objects to be tracked
    tracker.append(objects)

    # set the tracking volume
    tracker.volume=((0, masks.shape[-2]), (0, masks.shape[-1]))

    # track them (in interactive mode)
    tracker.track(step_size=5)

    # generate hypotheses and run the global optimizer
    tracker.optimize()

    # get the tracks in a format for napari visualization
    data, properties, graph = tracker.to_napari()
    
    # store the tracks
    tracks = tracker.tracks
    
    # store the configuration
    cfg = tracker.configuration
    
    # export the track data 
    tracker.export("/mnt/DATA/macrohet/segmentation/[6,9]_tracks.h5", obj_type="obj_type_1")
# Out:
# [INFO][2023/01/24 02:40:00 pm] Loaded btrack: /home/dayn/analysis/BayesianTracker/btrack/libs/libtracker.so
# 24-Jan-23 14:40:00 - btrack.libwrapper - INFO     - Loaded btrack: /home/dayn/analysis/BayesianTracker/btrack/libs/libtracker.so
# [INFO][2023/01/24 02:40:00 pm] btrack (v0.5.0) library imported
# 24-Jan-23 14:40:00 - btrack.core - INFO     - btrack (v0.5.0) library imported
# [INFO][2023/01/24 02:40:00 pm] Starting BayesianTracker session
# 24-Jan-23 14:40:00 - btrack.core - INFO     - Starting BayesianTracker session
# [INFO][2023/01/24 02:40:00 pm] Loading configuration file: /home/dayn/analysis/BayesianTracker/models/particle_config.json
# 24-Jan-23 14:40:00 - btrack.config - INFO     - Loading configuration file: /home/dayn/analysis/BayesianTracker/models/particle_config.json
# [INFO][2023/01/24 02:40:00 pm] Objects are of type: <class 'list'>
# 24-Jan-23 14:40:00 - btrack.dataio - INFO     - Objects are of type: <class 'list'>
# [INFO][2023/01/24 02:40:01 pm] Starting tracking...
# 24-Jan-23 14:40:01 - btrack.core - INFO     - Starting tracking...
# [INFO][2023/01/24 02:40:01 pm] Update using: ['VISUAL', 'MOTION']
# 24-Jan-23 14:40:01 - btrack.core - INFO     - Update using: ['VISUAL', 'MOTION']
# [INFO][2023/01/24 02:40:02 pm] Tracking objects in frames 0 to 4 (of 75)...
# 24-Jan-23 14:40:02 - btrack.core - INFO     - Tracking objects in frames 0 to 4 (of 75)...
# [INFO][2023/01/24 02:40:07 pm]  - Timing (Bayesian updates: 397.45ms, Linking: 10.61ms)
# 24-Jan-23 14:40:07 - btrack.utils - INFO     -  - Timing (Bayesian updates: 397.45ms, Linking: 10.61ms)
# [INFO][2023/01/24 02:40:07 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:07 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:07 pm]  - Stats (Active: 2176, Lost: 5856, Conflicts resolved: 780)
# 24-Jan-23 14:40:07 - btrack.utils - INFO     -  - Stats (Active: 2176, Lost: 5856, Conflicts resolved: 780)
# [INFO][2023/01/24 02:40:07 pm] Tracking objects in frames 5 to 9 (of 75)...
# 24-Jan-23 14:40:07 - btrack.core - INFO     - Tracking objects in frames 5 to 9 (of 75)...
# [INFO][2023/01/24 02:40:13 pm]  - Timing (Bayesian updates: 446.96ms, Linking: 12.03ms)
# 24-Jan-23 14:40:13 - btrack.utils - INFO     -  - Timing (Bayesian updates: 446.96ms, Linking: 12.03ms)
# [INFO][2023/01/24 02:40:13 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:13 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:13 pm]  - Stats (Active: 2345, Lost: 13365, Conflicts resolved: 1940)
# 24-Jan-23 14:40:13 - btrack.utils - INFO     -  - Stats (Active: 2345, Lost: 13365, Conflicts resolved: 1940)
# [INFO][2023/01/24 02:40:13 pm] Tracking objects in frames 10 to 14 (of 75)...
# 24-Jan-23 14:40:13 - btrack.core - INFO     - Tracking objects in frames 10 to 14 (of 75)...
# [INFO][2023/01/24 02:40:21 pm]  - Timing (Bayesian updates: 455.73ms, Linking: 12.54ms)
# 24-Jan-23 14:40:21 - btrack.utils - INFO     -  - Timing (Bayesian updates: 455.73ms, Linking: 12.54ms)
# [INFO][2023/01/24 02:40:21 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:21 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:21 pm]  - Stats (Active: 2331, Lost: 21102, Conflicts resolved: 3050)
# 24-Jan-23 14:40:21 - btrack.utils - INFO     -  - Stats (Active: 2331, Lost: 21102, Conflicts resolved: 3050)
# [INFO][2023/01/24 02:40:21 pm] Tracking objects in frames 15 to 19 (of 75)...
# 24-Jan-23 14:40:21 - btrack.core - INFO     - Tracking objects in frames 15 to 19 (of 75)...
# [INFO][2023/01/24 02:40:27 pm]  - Timing (Bayesian updates: 418.47ms, Linking: 11.77ms)
# 24-Jan-23 14:40:27 - btrack.utils - INFO     -  - Timing (Bayesian updates: 418.47ms, Linking: 11.77ms)
# [INFO][2023/01/24 02:40:27 pm]  - Probabilities (Link: 1.00000, Lost: 0.84897)
# 24-Jan-23 14:40:27 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 0.84897)
# [INFO][2023/01/24 02:40:27 pm]  - Stats (Active: 2210, Lost: 28466, Conflicts resolved: 4192)
# 24-Jan-23 14:40:27 - btrack.utils - INFO     -  - Stats (Active: 2210, Lost: 28466, Conflicts resolved: 4192)
# [INFO][2023/01/24 02:40:27 pm] Tracking objects in frames 20 to 24 (of 75)...
# 24-Jan-23 14:40:27 - btrack.core - INFO     - Tracking objects in frames 20 to 24 (of 75)...
# [INFO][2023/01/24 02:40:33 pm]  - Timing (Bayesian updates: 372.35ms, Linking: 11.10ms)
# 24-Jan-23 14:40:33 - btrack.utils - INFO     -  - Timing (Bayesian updates: 372.35ms, Linking: 11.10ms)
# [INFO][2023/01/24 02:40:33 pm]  - Probabilities (Link: 0.97728, Lost: 1.00000)
# 24-Jan-23 14:40:33 - btrack.utils - INFO     -  - Probabilities (Link: 0.97728, Lost: 1.00000)
# [INFO][2023/01/24 02:40:33 pm]  - Stats (Active: 2087, Lost: 35259, Conflicts resolved: 5366)
# 24-Jan-23 14:40:33 - btrack.utils - INFO     -  - Stats (Active: 2087, Lost: 35259, Conflicts resolved: 5366)
# [INFO][2023/01/24 02:40:33 pm] Tracking objects in frames 25 to 29 (of 75)...
# 24-Jan-23 14:40:33 - btrack.core - INFO     - Tracking objects in frames 25 to 29 (of 75)...
# [INFO][2023/01/24 02:40:38 pm]  - Timing (Bayesian updates: 344.40ms, Linking: 10.55ms)
# 24-Jan-23 14:40:38 - btrack.utils - INFO     -  - Timing (Bayesian updates: 344.40ms, Linking: 10.55ms)
# [INFO][2023/01/24 02:40:38 pm]  - Probabilities (Link: 0.99995, Lost: 1.00000)
# 24-Jan-23 14:40:38 - btrack.utils - INFO     -  - Probabilities (Link: 0.99995, Lost: 1.00000)
# [INFO][2023/01/24 02:40:38 pm]  - Stats (Active: 1973, Lost: 41500, Conflicts resolved: 6486)
# 24-Jan-23 14:40:38 - btrack.utils - INFO     -  - Stats (Active: 1973, Lost: 41500, Conflicts resolved: 6486)
# [INFO][2023/01/24 02:40:38 pm] Tracking objects in frames 30 to 34 (of 75)...
# 24-Jan-23 14:40:38 - btrack.core - INFO     - Tracking objects in frames 30 to 34 (of 75)...
# [INFO][2023/01/24 02:40:42 pm]  - Timing (Bayesian updates: 283.15ms, Linking: 9.49ms)
# 24-Jan-23 14:40:42 - btrack.utils - INFO     -  - Timing (Bayesian updates: 283.15ms, Linking: 9.49ms)
# [INFO][2023/01/24 02:40:42 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:42 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:42 pm]  - Stats (Active: 1842, Lost: 47208, Conflicts resolved: 7628)
# 24-Jan-23 14:40:42 - btrack.utils - INFO     -  - Stats (Active: 1842, Lost: 47208, Conflicts resolved: 7628)
# [INFO][2023/01/24 02:40:42 pm] Tracking objects in frames 35 to 39 (of 75)...
# 24-Jan-23 14:40:42 - btrack.core - INFO     - Tracking objects in frames 35 to 39 (of 75)...
# [INFO][2023/01/24 02:40:46 pm]  - Timing (Bayesian updates: 205.87ms, Linking: 8.34ms)
# 24-Jan-23 14:40:46 - btrack.utils - INFO     -  - Timing (Bayesian updates: 205.87ms, Linking: 8.34ms)
# [INFO][2023/01/24 02:40:46 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:46 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:46 pm]  - Stats (Active: 1642, Lost: 52305, Conflicts resolved: 8671)
# 24-Jan-23 14:40:46 - btrack.utils - INFO     -  - Stats (Active: 1642, Lost: 52305, Conflicts resolved: 8671)
# [INFO][2023/01/24 02:40:46 pm] Tracking objects in frames 40 to 44 (of 75)...
# 24-Jan-23 14:40:46 - btrack.core - INFO     - Tracking objects in frames 40 to 44 (of 75)...
# [INFO][2023/01/24 02:40:48 pm]  - Timing (Bayesian updates: 189.04ms, Linking: 7.08ms)
# 24-Jan-23 14:40:48 - btrack.utils - INFO     -  - Timing (Bayesian updates: 189.04ms, Linking: 7.08ms)
# [INFO][2023/01/24 02:40:48 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:48 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:48 pm]  - Stats (Active: 1433, Lost: 56673, Conflicts resolved: 9672)
# 24-Jan-23 14:40:48 - btrack.utils - INFO     -  - Stats (Active: 1433, Lost: 56673, Conflicts resolved: 9672)
# [INFO][2023/01/24 02:40:48 pm] Tracking objects in frames 45 to 49 (of 75)...
# 24-Jan-23 14:40:48 - btrack.core - INFO     - Tracking objects in frames 45 to 49 (of 75)...
# [INFO][2023/01/24 02:40:50 pm]  - Timing (Bayesian updates: 124.58ms, Linking: 5.97ms)
# 24-Jan-23 14:40:50 - btrack.utils - INFO     -  - Timing (Bayesian updates: 124.58ms, Linking: 5.97ms)
# [INFO][2023/01/24 02:40:50 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:50 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:50 pm]  - Stats (Active: 1269, Lost: 60562, Conflicts resolved: 10529)
# 24-Jan-23 14:40:50 - btrack.utils - INFO     -  - Stats (Active: 1269, Lost: 60562, Conflicts resolved: 10529)
# [INFO][2023/01/24 02:40:50 pm] Tracking objects in frames 50 to 54 (of 75)...
# 24-Jan-23 14:40:50 - btrack.core - INFO     - Tracking objects in frames 50 to 54 (of 75)...
# [INFO][2023/01/24 02:40:52 pm]  - Timing (Bayesian updates: 85.65ms, Linking: 4.78ms)
# 24-Jan-23 14:40:52 - btrack.utils - INFO     -  - Timing (Bayesian updates: 85.65ms, Linking: 4.78ms)
# [INFO][2023/01/24 02:40:52 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:52 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:52 pm]  - Stats (Active: 1083, Lost: 63772, Conflicts resolved: 11321)
# 24-Jan-23 14:40:52 - btrack.utils - INFO     -  - Stats (Active: 1083, Lost: 63772, Conflicts resolved: 11321)
# [INFO][2023/01/24 02:40:52 pm] Tracking objects in frames 55 to 59 (of 75)...
# 24-Jan-23 14:40:52 - btrack.core - INFO     - Tracking objects in frames 55 to 59 (of 75)...
# [INFO][2023/01/24 02:40:53 pm]  - Timing (Bayesian updates: 62.21ms, Linking: 3.89ms)
# 24-Jan-23 14:40:53 - btrack.utils - INFO     -  - Timing (Bayesian updates: 62.21ms, Linking: 3.89ms)
# [INFO][2023/01/24 02:40:53 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:53 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:53 pm]  - Stats (Active: 1001, Lost: 66692, Conflicts resolved: 11965)
# 24-Jan-23 14:40:53 - btrack.utils - INFO     -  - Stats (Active: 1001, Lost: 66692, Conflicts resolved: 11965)
# [INFO][2023/01/24 02:40:53 pm] Tracking objects in frames 60 to 64 (of 75)...
# 24-Jan-23 14:40:53 - btrack.core - INFO     - Tracking objects in frames 60 to 64 (of 75)...
# [INFO][2023/01/24 02:40:54 pm]  - Timing (Bayesian updates: 49.05ms, Linking: 3.57ms)
# 24-Jan-23 14:40:54 - btrack.utils - INFO     -  - Timing (Bayesian updates: 49.05ms, Linking: 3.57ms)
# [INFO][2023/01/24 02:40:54 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:54 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:54 pm]  - Stats (Active: 903, Lost: 69442, Conflicts resolved: 12574)
# 24-Jan-23 14:40:54 - btrack.utils - INFO     -  - Stats (Active: 903, Lost: 69442, Conflicts resolved: 12574)
# [INFO][2023/01/24 02:40:54 pm] Tracking objects in frames 65 to 69 (of 75)...
# 24-Jan-23 14:40:54 - btrack.core - INFO     - Tracking objects in frames 65 to 69 (of 75)...
# [INFO][2023/01/24 02:40:55 pm]  - Timing (Bayesian updates: 40.10ms, Linking: 3.19ms)
# 24-Jan-23 14:40:55 - btrack.utils - INFO     -  - Timing (Bayesian updates: 40.10ms, Linking: 3.19ms)
# [INFO][2023/01/24 02:40:55 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:55 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:55 pm]  - Stats (Active: 849, Lost: 71977, Conflicts resolved: 13119)
# 24-Jan-23 14:40:55 - btrack.utils - INFO     -  - Stats (Active: 849, Lost: 71977, Conflicts resolved: 13119)
# [INFO][2023/01/24 02:40:55 pm] Tracking objects in frames 70 to 74 (of 75)...
# 24-Jan-23 14:40:55 - btrack.core - INFO     - Tracking objects in frames 70 to 74 (of 75)...
# [INFO][2023/01/24 02:40:55 pm]  - Timing (Bayesian updates: 33.83ms, Linking: 2.94ms)
# 24-Jan-23 14:40:55 - btrack.utils - INFO     -  - Timing (Bayesian updates: 33.83ms, Linking: 2.94ms)
# [INFO][2023/01/24 02:40:55 pm]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# 24-Jan-23 14:40:55 - btrack.utils - INFO     -  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/01/24 02:40:55 pm] SUCCESS.
# 24-Jan-23 14:40:55 - btrack.core - INFO     - SUCCESS.
# [INFO][2023/01/24 02:40:55 pm]  - Found 10024 tracks in 75 frames (in 0.0s)
# 24-Jan-23 14:40:55 - btrack.core - INFO     -  - Found 10024 tracks in 75 frames (in 0.0s)
# [INFO][2023/01/24 02:40:55 pm]  - Inserted 34274 dummy objects to fill tracking gaps
# 24-Jan-23 14:40:55 - btrack.core - INFO     -  - Inserted 34274 dummy objects to fill tracking gaps
# [INFO][2023/01/24 02:40:55 pm] Loading hypothesis model: particle_hypothesis
# 24-Jan-23 14:40:55 - btrack.core - INFO     - Loading hypothesis model: particle_hypothesis
# [INFO][2023/01/24 02:40:55 pm] Calculating hypotheses (relax: True)...
# 24-Jan-23 14:40:55 - btrack.core - INFO     - Calculating hypotheses (relax: True)...
# [INFO][2023/01/24 02:40:55 pm] Setting up constraints matrix for global optimisation...
# 24-Jan-23 14:40:55 - btrack.optimise.optimiser - INFO     - Setting up constraints matrix for global optimisation...
# [INFO][2023/01/24 02:40:55 pm] Using GLPK options: {'tm_lim': 60000}...
# 24-Jan-23 14:40:55 - btrack.optimise.optimiser - INFO     - Using GLPK options: {'tm_lim': 60000}...
# [INFO][2023/01/24 02:40:56 pm] Optimizing...
# 24-Jan-23 14:40:56 - btrack.optimise.optimiser - INFO     - Optimizing...
# [INFO][2023/01/24 02:41:01 pm] Optimization complete. (Solution: optimal)
# 24-Jan-23 14:41:01 - btrack.optimise.optimiser - INFO     - Optimization complete. (Solution: optimal)
# [INFO][2023/01/24 02:41:02 pm]  - Fates.FALSE_POSITIVE: 3304 (of 10024)
# 24-Jan-23 14:41:02 - btrack.core - INFO     -  - Fates.FALSE_POSITIVE: 3304 (of 10024)
# [INFO][2023/01/24 02:41:02 pm]  - Fates.LINK: 1830 (of 2415)
# 24-Jan-23 14:41:02 - btrack.core - INFO     -  - Fates.LINK: 1830 (of 2415)
# [INFO][2023/01/24 02:41:02 pm]  - Fates.INITIALIZE_BORDER: 3 (of 13)
# 24-Jan-23 14:41:02 - btrack.core - INFO     -  - Fates.INITIALIZE_BORDER: 3 (of 13)
# [INFO][2023/01/24 02:41:02 pm]  - Fates.INITIALIZE_FRONT: 1455 (of 1976)
# 24-Jan-23 14:41:02 - btrack.core - INFO     -  - Fates.INITIALIZE_FRONT: 1455 (of 1976)
# [INFO][2023/01/24 02:41:02 pm]  - Fates.INITIALIZE_LAZY: 3432 (of 8035)
# 24-Jan-23 14:41:02 - btrack.core - INFO     -  - Fates.INITIALIZE_LAZY: 3432 (of 8035)
# [INFO][2023/01/24 02:41:02 pm]  - Fates.TERMINATE_BORDER: 6 (of 18)
# 24-Jan-23 14:41:02 - btrack.core - INFO     -  - Fates.TERMINATE_BORDER: 6 (of 18)
# [INFO][2023/01/24 02:41:02 pm]  - Fates.TERMINATE_BACK: 496 (of 722)
# 24-Jan-23 14:41:02 - btrack.core - INFO     -  - Fates.TERMINATE_BACK: 496 (of 722)
# [INFO][2023/01/24 02:41:02 pm]  - Fates.TERMINATE_LAZY: 4388 (of 9284)
# 24-Jan-23 14:41:02 - btrack.core - INFO     -  - Fates.TERMINATE_LAZY: 4388 (of 9284)
# [INFO][2023/01/24 02:41:02 pm]  - TOTAL: 32487 hypotheses
# 24-Jan-23 14:41:02 - btrack.core - INFO     -  - TOTAL: 32487 hypotheses
# [INFO][2023/01/24 02:41:02 pm] Completed optimization with 8194 tracks
# 24-Jan-23 14:41:02 - btrack.core - INFO     - Completed optimization with 8194 tracks
# GLPK Integer Optimizer 5.0
# 40096 rows, 32487 columns, 44926 non-zeros
# 32487 integer variables, all of which are binary
# Preprocessing...
# 20048 rows, 32487 columns, 44926 non-zeros
# 32487 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 20048
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 20048 rows, 32487 columns, 44926 non-zeros
# *     0: obj =   1.170319066e+05 inf =   0.000e+00 (6696)
# Perturbing LP to avoid stalling [2507]...
# *  6268: obj =   7.381611874e+04 inf =   0.000e+00 (434)
# Removing LP perturbation [6716]...
# *  6716: obj =   7.344274620e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +  6716: mip =     not found yet >=              -inf        (1; 0)
# +  6716: >>>>>   7.344274620e+04 >=   7.344274620e+04   0.0% (1; 0)
# +  6716: mip =   7.344274620e+04 >=     tree is empty   0.0% (0; 1)
# INTEGER OPTIMAL SOLUTION FOUND
# [INFO][2023/01/24 02:41:03 pm] Opening HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_tracks.h5...
# 24-Jan-23 14:41:03 - btrack.dataio - INFO     - Opening HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_tracks.h5...
# [INFO][2023/01/24 02:41:04 pm] Writing objects/obj_type_1
# 24-Jan-23 14:41:04 - btrack.dataio - INFO     - Writing objects/obj_type_1
# [INFO][2023/01/24 02:41:04 pm] Writing labels/obj_type_1
# 24-Jan-23 14:41:04 - btrack.dataio - INFO     - Writing labels/obj_type_1
# [INFO][2023/01/24 02:41:04 pm] Loading objects/obj_type_1 (40381, 5) (40381 filtered: None)
# 24-Jan-23 14:41:04 - btrack.dataio - INFO     - Loading objects/obj_type_1 (40381, 5) (40381 filtered: None)
# [INFO][2023/01/24 02:41:04 pm] Writing properties/obj_type_1/area (40381,)
# 24-Jan-23 14:41:04 - btrack.dataio - INFO     - Writing properties/obj_type_1/area (40381,)
# [INFO][2023/01/24 02:41:04 pm] Writing properties/obj_type_1/major_axis_length (40381,)
# 24-Jan-23 14:41:04 - btrack.dataio - INFO     - Writing properties/obj_type_1/major_axis_length (40381,)
# [INFO][2023/01/24 02:41:04 pm] Writing properties/obj_type_1/mean_intensity-0 (40381,)
# 24-Jan-23 14:41:04 - btrack.dataio - INFO     - Writing properties/obj_type_1/mean_intensity-0 (40381,)
# [INFO][2023/01/24 02:41:04 pm] Writing properties/obj_type_1/mean_intensity-1 (40381,)
# 24-Jan-23 14:41:04 - btrack.dataio - INFO     - Writing properties/obj_type_1/mean_intensity-1 (40381,)
# [INFO][2023/01/24 02:41:04 pm] Writing properties/obj_type_1/minor_axis_length (40381,)
# 24-Jan-23 14:41:04 - btrack.dataio - INFO     - Writing properties/obj_type_1/minor_axis_length (40381,)
# [INFO][2023/01/24 02:41:04 pm] Writing properties/obj_type_1/orientation (40381,)
# 24-Jan-23 14:41:04 - btrack.dataio - INFO     - Writing properties/obj_type_1/orientation (40381,)
# [INFO][2023/01/24 02:41:06 pm] Writing tracks/obj_type_1
# 24-Jan-23 14:41:06 - btrack.dataio - INFO     - Writing tracks/obj_type_1
# [INFO][2023/01/24 02:41:06 pm] Writing dummies/obj_type_1
# 24-Jan-23 14:41:06 - btrack.dataio - INFO     - Writing dummies/obj_type_1
# [INFO][2023/01/24 02:41:06 pm] Writing LBEP/obj_type_1
# 24-Jan-23 14:41:06 - btrack.dataio - INFO     - Writing LBEP/obj_type_1
# [INFO][2023/01/24 02:41:06 pm] Writing fates/obj_type_1
# 24-Jan-23 14:41:06 - btrack.dataio - INFO     - Writing fates/obj_type_1
# [INFO][2023/01/24 02:41:06 pm] Closing HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_tracks.h5
# 24-Jan-23 14:41:06 - btrack.dataio - INFO     - Closing HDF file: /mnt/DATA/macrohet/segmentation/[6,9]_tracks.h5
# [INFO][2023/01/24 02:41:06 pm] Ending BayesianTracker session
# 24-Jan-23 14:41:06 - btrack.core - INFO     - Ending BayesianTracker session

# %%
images
# Out:
# dask.array<stack, shape=(75, 6048, 6048, 2), dtype=uint64, chunksize=(1, 2016, 2016, 1), chunktype=numpy.ndarray>

# %%
masks
# Out:
# dask.array<array, shape=(75, 6048, 6048), dtype=uint16, chunksize=(75, 864, 864), chunktype=numpy.ndarray>

# %%
v = napari.Viewer()
v.add_image(images, 
            channel_axis = -1, 
            colormap=['green', 'magenta'], 
            contrast_limits=[[100,6000],[0,3000]])
# for key in masks_dict.keys():
#     v.add_labels(masks_dict[key][0], name = key)
v.add_labels(masks, name = 'masks')
v.add_tracks(
                    data, 
                    properties=properties, 
                    graph=graph, 
                    name="Tracks", 
                    blending="translucent",
                    visible=False,
                )
# Out:
# /home/dayn/miniconda3/envs/aero/lib/python3.9/site-packages/napari_tools_menu/__init__.py:194: FutureWarning: Public access to Window.qt_viewer is deprecated and will be removed in
# v0.5.0. It is considered an "implementation detail" of the napari
# application, not part of the napari viewer model. If your use case
# requires access to qt_viewer, please open an issue to discuss.
#   self.tools_menu = ToolsMenu(self, self.qt_viewer.viewer)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 9>()
#       6 # for key in masks_dict.keys():
#       7 #     v.add_labels(masks_dict[key][0], name = key)
#       8 v.add_labels(masks, name = 'masks')
# ----> 9 viewer.add_tracks(
#      10                     data,
#      11                     properties=properties,
#      12                     graph=graph,
#      13                     name="Tracks",
#      14                     blending="translucent",
#      15                     visible=False,
#      16                 )
#
# NameError: name 'viewer' is not defined
