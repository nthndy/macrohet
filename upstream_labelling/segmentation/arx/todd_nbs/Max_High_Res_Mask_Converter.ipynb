# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.io
from cellpose import models
from cellpose import plot
import skimage.io as skio
from PIL import Image
# Out:
# 2022-01-19 09:20:01,792 [INFO] WRITING LOG OUTPUT TO /camp/home/fallest/.cellpose/run.log

# %%
masks=np.load('masks_high_res.npy')

# %%
big_mask_arr = np.array(masks,np.uint16)

# %%
big_mask_arr.shape
# Out:
# (75, 6048, 6048)

# %%
from PIL import Image
big_mask_arr[0,:,:].shape
plt.imshow(big_mask_arr[0,:,:])

# %%
big_image_tp1=big_mask_arr[0,:,:]
big_image_tp1 = np.reshape(big_image_tp1, (6048, 6048))
big_image_tp1.shape
# Out:
# (6048, 6048)

# %%
#https://pypi.org/project/tifffile/
im = Image.fromarray(big_image_tp1)
im.save('big_image_tp1.tiff')

# %%
# Out:
# 4
